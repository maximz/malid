# %%
from summarynb import show, indexed_csv, plaintext, chunks, table
from malid import config, logger, helpers
from malid.datamodels import (
    TargetObsColumnEnum,
    SampleWeightStrategy,
    combine_classification_option_names,
)
from slugify import slugify
import pandas as pd

# %%
from IPython.display import display, Markdown

# %%
# TODO: bring back sequence level model evaluation too.

# %% [markdown]
# # Predict disease/age/sex/ethnicity from sequences only (language model only)
#
# We train sequence model on train-smaller and eval on validation set. Then we rollup (with optional tuning) and eval on test set. That's below
#
# Note: run on same CV folds but subset to specimens without clear age/sex/ethnicity biases. But we kept same fine-tuned unirep, which was created from train-smaller + validation with more specimens than just this subset. This is OK.

# %%
model_names = [
    "lasso_multiclass",
    "lasso_multiclass-rollup_tuned",
    "dummy_stratified",
    "dummy_most_frequent",
    "dummy_stratified-rollup_tuned",
    "dummy_most_frequent-rollup_tuned",
]
for gene_locus in config.gene_loci_used:
    for target_obs_column in config.classification_targets:
        for sample_weight_strategy in [
            SampleWeightStrategy.ISOTYPE_USAGE,
        ]:
            display(
                Markdown(
                    f"### {gene_locus}, {target_obs_column}, {sample_weight_strategy}"
                )
            )
            try:
                show(
                    [
                        [
                            config.paths.sequence_models_output_dir
                            / gene_locus.name
                            / "rollup_models"
                            / combine_classification_option_names(
                                target_obs_column=target_obs_column,
                                sample_weight_strategy=sample_weight_strategy,
                            )
                            / f"sequence_prediction_rollup.{model_name}.train_smaller_model.report.txt"
                            for model_name in model_names
                        ],
                        [
                            config.paths.sequence_models_output_dir
                            / gene_locus.name
                            / "rollup_models"
                            / combine_classification_option_names(
                                target_obs_column=target_obs_column,
                                sample_weight_strategy=sample_weight_strategy,
                            )
                            / f"sequence_prediction_rollup.{model_name}.train_smaller_model.confusion_matrix.png"
                            for model_name in model_names
                        ],
                    ],
                    headers=model_names,
                    max_width=400,
                )
            except FileNotFoundError as err:
                logger.warning(f"Not run: {err}")
# Out:
# ### GeneLocus.BCR, TargetObsColumnEnum.disease, SampleWeightStrategy.ISOTYPE_USAGE
# <table><tr><th style="text-align: center">lasso_multiclass</th>
# <th style="text-align: center">lasso_multiclass-rollup_tuned</th>
# <th style="text-align: center">dummy_stratified</th>
# <th style="text-align: center">dummy_most_frequent</th>
# <th style="text-align: center">dummy_stratified-rollup_tuned</th>
# <th style="text-align: center">dummy_most_frequent-rollup_tuned</th></tr><tr><td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.829 +/- 0.032 (in 3 folds)
# ROC-AUC (macro OvO): 0.833 +/- 0.034 (in 3 folds)
# au-PRC (weighted OvO): 0.835 +/- 0.026 (in 3 folds)
# au-PRC (macro OvO): 0.846 +/- 0.026 (in 3 folds)
# Accuracy: 0.687 +/- 0.042 (in 3 folds)
# MCC: 0.556 +/- 0.067 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.688
# MCC: 0.557
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.85      0.65      0.74        63
#                HIV       0.55      0.92      0.69        98
# Healthy/Background       0.73      0.72      0.73       221
#              Lupus       0.78      0.41      0.54        98
#
#           accuracy                           0.69       480
#          macro avg       0.73      0.67      0.67       480
#       weighted avg       0.72      0.69      0.68       480
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.829 +/- 0.032 (in 3 folds)
# ROC-AUC (macro OvO): 0.833 +/- 0.034 (in 3 folds)
# au-PRC (weighted OvO): 0.835 +/- 0.026 (in 3 folds)
# au-PRC (macro OvO): 0.846 +/- 0.026 (in 3 folds)
# Accuracy: 0.679 +/- 0.020 (in 3 folds)
# MCC: 0.543 +/- 0.003 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.679
# MCC: 0.534
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.84      0.67      0.74        63
#                HIV       0.58      0.80      0.67        98
# Healthy/Background       0.71      0.73      0.72       221
#              Lupus       0.66      0.46      0.54        98
#
#           accuracy                           0.68       480
#          macro avg       0.70      0.66      0.67       480
#       weighted avg       0.69      0.68      0.68       480
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.433 +/- 0.014 (in 3 folds)
# ROC-AUC (macro OvO): 0.444 +/- 0.010 (in 3 folds)
# au-PRC (weighted OvO): 0.479 +/- 0.001 (in 3 folds)
# au-PRC (macro OvO): 0.482 +/- 0.001 (in 3 folds)
# Accuracy: 0.460 +/- 0.006 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.460
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.00      0.00      0.00        63
#                HIV       0.00      0.00      0.00        98
# Healthy/Background       0.46      1.00      0.63       221
#              Lupus       0.00      0.00      0.00        98
#
#           accuracy                           0.46       480
#          macro avg       0.12      0.25      0.16       480
#       weighted avg       0.21      0.46      0.29       480
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# Accuracy: 0.460 +/- 0.006 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.460
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.00      0.00      0.00        63
#                HIV       0.00      0.00      0.00        98
# Healthy/Background       0.46      1.00      0.63       221
#              Lupus       0.00      0.00      0.00        98
#
#           accuracy                           0.46       480
#          macro avg       0.12      0.25      0.16       480
#       weighted avg       0.21      0.46      0.29       480
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.433 +/- 0.014 (in 3 folds)
# ROC-AUC (macro OvO): 0.444 +/- 0.010 (in 3 folds)
# au-PRC (weighted OvO): 0.479 +/- 0.001 (in 3 folds)
# au-PRC (macro OvO): 0.482 +/- 0.001 (in 3 folds)
# Accuracy: 0.369 +/- 0.126 (in 3 folds)
# MCC: 0.022 +/- 0.040 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.369
# MCC: 0.014
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.00      0.00      0.00        63
#                HIV       0.24      0.34      0.28        98
# Healthy/Background       0.46      0.60      0.52       221
#              Lupus       0.23      0.11      0.15        98
#
#           accuracy                           0.37       480
#          macro avg       0.23      0.26      0.24       480
#       weighted avg       0.30      0.37      0.33       480
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# Accuracy: 0.460 +/- 0.006 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.460
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.00      0.00      0.00        63
#                HIV       0.00      0.00      0.00        98
# Healthy/Background       0.46      1.00      0.63       221
#              Lupus       0.00      0.00      0.00        98
#
#           accuracy                           0.46       480
#          macro avg       0.12      0.25      0.16       480
#       weighted avg       0.21      0.46      0.29       480
# </pre></td></tr>
# <tr><td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/disease_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/disease_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/disease_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/disease_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollu
# ### GeneLocus.BCR, TargetObsColumnEnum.disease_all_demographics_present, SampleWeightStrategy.ISOTYPE_USAGE
# <table><tr><th style="text-align: center">lasso_multiclass</th>
# <th style="text-align: center">lasso_multiclass-rollup_tuned</th>
# <th style="text-align: center">dummy_stratified</th>
# <th style="text-align: center">dummy_most_frequent</th>
# <th style="text-align: center">dummy_stratified-rollup_tuned</th>
# <th style="text-align: center">dummy_most_frequent-rollup_tuned</th></tr><tr><td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.832 +/- 0.024 (in 3 folds)
# ROC-AUC (macro OvO): 0.837 +/- 0.025 (in 3 folds)
# au-PRC (weighted OvO): 0.838 +/- 0.021 (in 3 folds)
# au-PRC (macro OvO): 0.851 +/- 0.020 (in 3 folds)
# Accuracy: 0.674 +/- 0.019 (in 3 folds)
# MCC: 0.542 +/- 0.028 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.674
# MCC: 0.543
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.79      0.55      0.65        47
#                HIV       0.55      0.98      0.70        87
# Healthy/Background       0.73      0.70      0.72       191
#              Lupus       0.78      0.40      0.53        95
#
#           accuracy                           0.67       420
#          macro avg       0.71      0.66      0.65       420
#       weighted avg       0.71      0.67      0.66       420
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.832 +/- 0.024 (in 3 folds)
# ROC-AUC (macro OvO): 0.837 +/- 0.025 (in 3 folds)
# au-PRC (weighted OvO): 0.838 +/- 0.021 (in 3 folds)
# au-PRC (macro OvO): 0.851 +/- 0.020 (in 3 folds)
# Accuracy: 0.676 +/- 0.027 (in 3 folds)
# MCC: 0.541 +/- 0.024 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.676
# MCC: 0.534
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.83      0.62      0.71        47
#                HIV       0.56      0.85      0.68        87
# Healthy/Background       0.71      0.73      0.72       191
#              Lupus       0.75      0.43      0.55        95
#
#           accuracy                           0.68       420
#          macro avg       0.71      0.66      0.66       420
#       weighted avg       0.70      0.68      0.67       420
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.446 +/- 0.006 (in 3 folds)
# ROC-AUC (macro OvO): 0.458 +/- 0.006 (in 3 folds)
# au-PRC (weighted OvO): 0.492 +/- 0.003 (in 3 folds)
# au-PRC (macro OvO): 0.495 +/- 0.006 (in 3 folds)
# Accuracy: 0.455 +/- 0.033 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.455
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.00      0.00      0.00        47
#                HIV       0.00      0.00      0.00        87
# Healthy/Background       0.45      1.00      0.63       191
#              Lupus       0.00      0.00      0.00        95
#
#           accuracy                           0.45       420
#          macro avg       0.11      0.25      0.16       420
#       weighted avg       0.21      0.45      0.28       420
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# Accuracy: 0.455 +/- 0.033 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.455
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.00      0.00      0.00        47
#                HIV       0.00      0.00      0.00        87
# Healthy/Background       0.45      1.00      0.63       191
#              Lupus       0.00      0.00      0.00        95
#
#           accuracy                           0.45       420
#          macro avg       0.11      0.25      0.16       420
#       weighted avg       0.21      0.45      0.28       420
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.446 +/- 0.006 (in 3 folds)
# ROC-AUC (macro OvO): 0.458 +/- 0.006 (in 3 folds)
# au-PRC (weighted OvO): 0.492 +/- 0.003 (in 3 folds)
# au-PRC (macro OvO): 0.495 +/- 0.006 (in 3 folds)
# Accuracy: 0.445 +/- 0.033 (in 3 folds)
# MCC: 0.061 +/- 0.032 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.445
# MCC: 0.058
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.00      0.00      0.00        47
#                HIV       0.00      0.00      0.00        87
# Healthy/Background       0.46      0.86      0.60       191
#              Lupus       0.45      0.24      0.32        95
#
#           accuracy                           0.45       420
#          macro avg       0.23      0.28      0.23       420
#       weighted avg       0.31      0.45      0.34       420
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# Accuracy: 0.455 +/- 0.033 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.455
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.00      0.00      0.00        47
#                HIV       0.00      0.00      0.00        87
# Healthy/Background       0.45      1.00      0.63       191
#              Lupus       0.00      0.00      0.00        95
#
#           accuracy                           0.45       420
#          macro avg       0.11      0.25      0.16       420
#       weighted avg       0.21      0.45      0.28       420
# </pre></td></tr>
# <tr><td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/disease_all_demographics_present_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/disease_all_demographics_present_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/disease_all_demographics_present_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/disease_all_demographics_present_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;"
# ### GeneLocus.BCR, TargetObsColumnEnum.ethnicity_condensed_healthy_only, SampleWeightStrategy.ISOTYPE_USAGE
# <table><tr><th style="text-align: center">lasso_multiclass</th>
# <th style="text-align: center">lasso_multiclass-rollup_tuned</th>
# <th style="text-align: center">dummy_stratified</th>
# <th style="text-align: center">dummy_most_frequent</th>
# <th style="text-align: center">dummy_stratified-rollup_tuned</th>
# <th style="text-align: center">dummy_most_frequent-rollup_tuned</th></tr><tr><td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.748 +/- 0.042 (in 3 folds)
# ROC-AUC (macro OvO): 0.755 +/- 0.025 (in 3 folds)
# au-PRC (weighted OvO): 0.754 +/- 0.046 (in 3 folds)
# au-PRC (macro OvO): 0.771 +/- 0.041 (in 3 folds)
# Accuracy: 0.604 +/- 0.077 (in 3 folds)
# MCC: 0.377 +/- 0.092 (in 3 folds)
#
# Global scores:
# Accuracy: 0.602
# MCC: 0.381
#
# Global classification report:
#                  precision    recall  f1-score   support
#
#         African       0.73      0.98      0.83        44
#           Asian       0.21      0.31      0.25        32
#       Caucasian       0.73      0.57      0.64       109
# Hispanic/Latino       0.00      0.00      0.00         6
#
#        accuracy                           0.60       191
#       macro avg       0.42      0.46      0.43       191
#    weighted avg       0.62      0.60      0.60       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.748 +/- 0.042 (in 3 folds)
# ROC-AUC (macro OvO): 0.755 +/- 0.025 (in 3 folds)
# au-PRC (weighted OvO): 0.754 +/- 0.046 (in 3 folds)
# au-PRC (macro OvO): 0.771 +/- 0.041 (in 3 folds)
# Accuracy: 0.728 +/- 0.015 (in 3 folds)
# MCC: 0.514 +/- 0.088 (in 3 folds)
#
# Global scores:
# Accuracy: 0.728
# MCC: 0.514
#
# Global classification report:
#                  precision    recall  f1-score   support
#
#         African       0.77      0.84      0.80        44
#           Asian       0.00      0.00      0.00        32
#       Caucasian       0.71      0.94      0.81       109
# Hispanic/Latino       0.00      0.00      0.00         6
#
#        accuracy                           0.73       191
#       macro avg       0.37      0.44      0.40       191
#    weighted avg       0.58      0.73      0.65       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.463 +/- 0.085 (in 3 folds)
# ROC-AUC (macro OvO): 0.472 +/- 0.071 (in 3 folds)
# au-PRC (weighted OvO): 0.507 +/- 0.034 (in 3 folds)
# au-PRC (macro OvO): 0.511 +/- 0.028 (in 3 folds)
# Accuracy: 0.567 +/- 0.081 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores:
# Accuracy: 0.571
# MCC: 0.000
#
# Global classification report:
#                  precision    recall  f1-score   support
#
#         African       0.00      0.00      0.00        44
#           Asian       0.00      0.00      0.00        32
#       Caucasian       0.57      1.00      0.73       109
# Hispanic/Latino       0.00      0.00      0.00         6
#
#        accuracy                           0.57       191
#       macro avg       0.14      0.25      0.18       191
#    weighted avg       0.33      0.57      0.41       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# Accuracy: 0.567 +/- 0.081 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores:
# Accuracy: 0.571
# MCC: 0.000
#
# Global classification report:
#                  precision    recall  f1-score   support
#
#         African       0.00      0.00      0.00        44
#           Asian       0.00      0.00      0.00        32
#       Caucasian       0.57      1.00      0.73       109
# Hispanic/Latino       0.00      0.00      0.00         6
#
#        accuracy                           0.57       191
#       macro avg       0.14      0.25      0.18       191
#    weighted avg       0.33      0.57      0.41       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.463 +/- 0.085 (in 3 folds)
# ROC-AUC (macro OvO): 0.472 +/- 0.071 (in 3 folds)
# au-PRC (weighted OvO): 0.507 +/- 0.034 (in 3 folds)
# au-PRC (macro OvO): 0.511 +/- 0.028 (in 3 folds)
# Accuracy: 0.366 +/- 0.257 (in 3 folds)
# MCC: -0.040 +/- 0.104 (in 3 folds)
#
# Global scores:
# Accuracy: 0.372
# MCC: 0.030
#
# Global classification report:
#                  precision    recall  f1-score   support
#
#         African       0.00      0.00      0.00        44
#           Asian       0.17      0.53      0.25        32
#       Caucasian       0.61      0.50      0.55       109
# Hispanic/Latino       0.00      0.00      0.00         6
#
#        accuracy                           0.37       191
#       macro avg       0.19      0.26      0.20       191
#    weighted avg       0.37      0.37      0.35       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# Accuracy: 0.567 +/- 0.081 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores:
# Accuracy: 0.571
# MCC: 0.000
#
# Global classification report:
#                  precision    recall  f1-score   support
#
#         African       0.00      0.00      0.00        44
#           Asian       0.00      0.00      0.00        32
#       Caucasian       0.57      1.00      0.73       109
# Hispanic/Latino       0.00      0.00      0.00         6
#
#        accuracy                           0.57       191
#       macro avg       0.14      0.25      0.18       191
#    weighted avg       0.33      0.57      0.41       191
# </pre></td></tr>
# <tr><td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/ethnicity_condensed_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/ethnicity_condensed_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/ethnicity_condensed_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/ethnicity_condensed_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/ethnicity_condensed_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/ethnicity_condensed_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td></tr></table>
# ### GeneLocus.BCR, TargetObsColumnEnum.age_group_healthy_only, SampleWeightStrategy.ISOTYPE_USAGE
# <table><tr><th style="text-align: center">lasso_multiclass</th>
# <th style="text-align: center">lasso_multiclass-rollup_tuned</th>
# <th style="text-align: center">dummy_stratified</th>
# <th style="text-align: center">dummy_most_frequent</th>
# <th style="text-align: center">dummy_stratified-rollup_tuned</th>
# <th style="text-align: center">dummy_most_frequent-rollup_tuned</th></tr><tr><td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.643 +/- 0.011 (in 3 folds)
# ROC-AUC (macro OvO): 0.630 +/- 0.032 (in 3 folds)
# au-PRC (weighted OvO): 0.680 +/- 0.025 (in 3 folds)
# au-PRC (macro OvO): 0.668 +/- 0.043 (in 3 folds)
# Accuracy: 0.333 +/- 0.055 (in 3 folds)
# MCC: 0.211 +/- 0.063 (in 3 folds)
#
# Global scores:
# Accuracy: 0.330
# MCC: 0.199
#
# Global classification report:
#               precision    recall  f1-score   support
#
#        20-30       0.41      0.46      0.43        35
#        30-40       0.21      0.17      0.19        23
#        40-50       0.08      0.07      0.08        28
#        50-60       0.40      0.26      0.31        39
#        60-70       0.18      0.19      0.18        27
#        70-80       0.00      0.00      0.00         4
#          <20       0.51      0.74      0.60        35
#
#     accuracy                           0.33       191
#    macro avg       0.26      0.27      0.26       191
# weighted avg       0.31      0.33      0.31       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.643 +/- 0.011 (in 3 folds)
# ROC-AUC (macro OvO): 0.630 +/- 0.032 (in 3 folds)
# au-PRC (weighted OvO): 0.680 +/- 0.025 (in 3 folds)
# au-PRC (macro OvO): 0.668 +/- 0.043 (in 3 folds)
# Accuracy: 0.320 +/- 0.022 (in 3 folds)
# MCC: 0.210 +/- 0.042 (in 3 folds)
#
# Global scores:
# Accuracy: 0.319
# MCC: 0.204
#
# Global classification report:
#               precision    recall  f1-score   support
#
#        20-30       0.44      0.34      0.39        35
#        30-40       0.31      0.22      0.26        23
#        40-50       0.00      0.00      0.00        28
#        50-60       0.67      0.10      0.18        39
#        60-70       0.23      0.56      0.32        27
#        70-80       0.00      0.00      0.00         4
#          <20       0.33      0.71      0.45        35
#
#     accuracy                           0.32       191
#    macro avg       0.28      0.28      0.23       191
# weighted avg       0.35      0.32      0.27       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.547 +/- 0.035 (in 3 folds)
# ROC-AUC (macro OvO): 0.546 +/- 0.028 (in 3 folds)
# au-PRC (weighted OvO): 0.583 +/- 0.025 (in 3 folds)
# au-PRC (macro OvO): 0.582 +/- 0.022 (in 3 folds)
# Accuracy: 0.174 +/- 0.133 (in 3 folds)
# MCC: 0.041 +/- 0.072 (in 3 folds)
#
# Global scores:
# Accuracy: 0.168
# MCC: -0.023
#
# Global classification report:
#               precision    recall  f1-score   support
#
#        20-30       0.00      0.00      0.00        35
#        30-40       0.00      0.00      0.00        23
#        40-50       1.00      0.04      0.07        28
#        50-60       0.20      0.64      0.31        39
#        60-70       0.09      0.22      0.13        27
#        70-80       0.00      0.00      0.00         4
#          <20       0.00      0.00      0.00        35
#
#     accuracy                           0.17       191
#    macro avg       0.18      0.13      0.07       191
# weighted avg       0.20      0.17      0.09       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# Accuracy: 0.169 +/- 0.123 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores:
# Accuracy: 0.162
# MCC: -0.032
#
# Global classification report:
#               precision    recall  f1-score   support
#
#        20-30       0.00      0.00      0.00        35
#        30-40       0.00      0.00      0.00        23
#        40-50       0.00      0.00      0.00        28
#        50-60       0.20      0.64      0.31        39
#        60-70       0.09      0.22      0.13        27
#        70-80       0.00      0.00      0.00         4
#          <20       0.00      0.00      0.00        35
#
#     accuracy                           0.16       191
#    macro avg       0.04      0.12      0.06       191
# weighted avg       0.05      0.16      0.08       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.547 +/- 0.035 (in 3 folds)
# ROC-AUC (macro OvO): 0.546 +/- 0.028 (in 3 folds)
# au-PRC (weighted OvO): 0.583 +/- 0.025 (in 3 folds)
# au-PRC (macro OvO): 0.582 +/- 0.022 (in 3 folds)
# Accuracy: 0.123 +/- 0.064 (in 3 folds)
# MCC: -0.023 +/- 0.016 (in 3 folds)
#
# Global scores:
# Accuracy: 0.126
# MCC: -0.081
#
# Global classification report:
#               precision    recall  f1-score   support
#
#        20-30       0.00      0.00      0.00        35
#        30-40       0.07      0.17      0.10        23
#        40-50       0.00      0.00      0.00        28
#        50-60       0.15      0.46      0.22        39
#        60-70       0.00      0.00      0.00        27
#        70-80       0.00      0.00      0.00         4
#          <20       0.17      0.06      0.09        35
#
#     accuracy                           0.13       191
#    macro avg       0.05      0.10      0.06       191
# weighted avg       0.07      0.13      0.07       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# Accuracy: 0.169 +/- 0.123 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores:
# Accuracy: 0.162
# MCC: -0.032
#
# Global classification report:
#               precision    recall  f1-score   support
#
#        20-30       0.00      0.00      0.00        35
#        30-40       0.00      0.00      0.00        23
#        40-50       0.00      0.00      0.00        28
#        50-60       0.20      0.64      0.31        39
#        60-70       0.09      0.22      0.13        27
#        70-80       0.00      0.00      0.00         4
#          <20       0.00      0.00      0.00        35
#
#     accuracy                           0.16       191
#    macro avg       0.04      0.12      0.06       191
# weighted avg       0.05      0.16      0.08       191
# </pre></td></tr>
# <tr><td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td styl
# ### GeneLocus.BCR, TargetObsColumnEnum.age_group_binary_healthy_only, SampleWeightStrategy.ISOTYPE_USAGE
# <table><tr><th style="text-align: center">lasso_multiclass</th>
# <th style="text-align: center">lasso_multiclass-rollup_tuned</th>
# <th style="text-align: center">dummy_stratified</th>
# <th style="text-align: center">dummy_most_frequent</th>
# <th style="text-align: center">dummy_stratified-rollup_tuned</th>
# <th style="text-align: center">dummy_most_frequent-rollup_tuned</th></tr><tr><td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.696 +/- 0.070 (in 3 folds)
# ROC-AUC (macro OvO): 0.696 +/- 0.070 (in 3 folds)
# au-PRC (weighted OvO): 0.803 +/- 0.108 (in 3 folds)
# au-PRC (macro OvO): 0.803 +/- 0.108 (in 3 folds)
# Accuracy: 0.658 +/- 0.051 (in 3 folds)
# MCC: 0.280 +/- 0.097 (in 3 folds)
#
# Global scores:
# Accuracy: 0.660
# MCC: 0.274
#
# Global classification report:
#               precision    recall  f1-score   support
#
#          50+       0.53      0.56      0.55        70
#     under 50       0.74      0.72      0.73       121
#
#     accuracy                           0.66       191
#    macro avg       0.64      0.64      0.64       191
# weighted avg       0.66      0.66      0.66       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.696 +/- 0.070 (in 3 folds)
# ROC-AUC (macro OvO): 0.696 +/- 0.070 (in 3 folds)
# au-PRC (weighted OvO): 0.803 +/- 0.108 (in 3 folds)
# au-PRC (macro OvO): 0.803 +/- 0.108 (in 3 folds)
# Accuracy: 0.596 +/- 0.076 (in 3 folds)
# MCC: 0.182 +/- 0.123 (in 3 folds)
#
# Global scores:
# Accuracy: 0.597
# MCC: 0.183
#
# Global classification report:
#               precision    recall  f1-score   support
#
#          50+       0.46      0.59      0.52        70
#     under 50       0.72      0.60      0.65       121
#
#     accuracy                           0.60       191
#    macro avg       0.59      0.59      0.59       191
# weighted avg       0.62      0.60      0.60       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.643 +/- 0.080 (in 3 folds)
# ROC-AUC (macro OvO): 0.643 +/- 0.080 (in 3 folds)
# au-PRC (weighted OvO): 0.741 +/- 0.136 (in 3 folds)
# au-PRC (macro OvO): 0.741 +/- 0.136 (in 3 folds)
# Accuracy: 0.625 +/- 0.064 (in 3 folds)
# MCC: -0.028 +/- 0.049 (in 3 folds)
#
# Global scores:
# Accuracy: 0.628
# MCC: -0.055
#
# Global classification report:
#               precision    recall  f1-score   support
#
#          50+       0.00      0.00      0.00        70
#     under 50       0.63      0.99      0.77       121
#
#     accuracy                           0.63       191
#    macro avg       0.32      0.50      0.39       191
# weighted avg       0.40      0.63      0.49       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.630 +/- 0.069 (in 3 folds)
# au-PRC (macro OvO): 0.630 +/- 0.069 (in 3 folds)
# Accuracy: 0.630 +/- 0.069 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores:
# Accuracy: 0.634
# MCC: 0.000
#
# Global classification report:
#               precision    recall  f1-score   support
#
#          50+       0.00      0.00      0.00        70
#     under 50       0.63      1.00      0.78       121
#
#     accuracy                           0.63       191
#    macro avg       0.32      0.50      0.39       191
# weighted avg       0.40      0.63      0.49       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.643 +/- 0.080 (in 3 folds)
# ROC-AUC (macro OvO): 0.643 +/- 0.080 (in 3 folds)
# au-PRC (weighted OvO): 0.741 +/- 0.136 (in 3 folds)
# au-PRC (macro OvO): 0.741 +/- 0.136 (in 3 folds)
# Accuracy: 0.556 +/- 0.134 (in 3 folds)
# MCC: 0.181 +/- 0.031 (in 3 folds)
#
# Global scores:
# Accuracy: 0.555
# MCC: 0.084
#
# Global classification report:
#               precision    recall  f1-score   support
#
#          50+       0.41      0.50      0.45        70
#     under 50       0.67      0.59      0.63       121
#
#     accuracy                           0.55       191
#    macro avg       0.54      0.54      0.54       191
# weighted avg       0.58      0.55      0.56       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.630 +/- 0.069 (in 3 folds)
# au-PRC (macro OvO): 0.630 +/- 0.069 (in 3 folds)
# Accuracy: 0.630 +/- 0.069 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores:
# Accuracy: 0.634
# MCC: 0.000
#
# Global classification report:
#               precision    recall  f1-score   support
#
#          50+       0.00      0.00      0.00        70
#     under 50       0.63      1.00      0.78       121
#
#     accuracy                           0.63       191
#    macro avg       0.32      0.50      0.39       191
# weighted avg       0.40      0.63      0.49       191
# </pre></td></tr>
# <tr><td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_binary_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_binary_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_binary_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_binary_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_binary_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_binary_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td></tr></table>
# ### GeneLocus.BCR, TargetObsColumnEnum.age_group_pediatric_healthy_only, SampleWeightStrategy.ISOTYPE_USAGE
# 2023-01-19 05:11:38,097 - summary.model3.ipynb - WARNING - Not run: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/out/unirep_fine_tuned/sequence_models/BCR/rollup_models/age_group_pediatric_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass.train_smaller_model.report.txt'
# ### GeneLocus.BCR, TargetObsColumnEnum.sex_healthy_only, SampleWeightStrategy.ISOTYPE_USAGE
# <table><tr><th style="text-align: center">lasso_multiclass</th>
# <th style="text-align: center">lasso_multiclass-rollup_tuned</th>
# <th style="text-align: center">dummy_stratified</th>
# <th style="text-align: center">dummy_most_frequent</th>
# <th style="text-align: center">dummy_stratified-rollup_tuned</th>
# <th style="text-align: center">dummy_most_frequent-rollup_tuned</th></tr><tr><td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.411 +/- 0.074 (in 3 folds)
# ROC-AUC (macro OvO): 0.411 +/- 0.074 (in 3 folds)
# au-PRC (weighted OvO): 0.463 +/- 0.112 (in 3 folds)
# au-PRC (macro OvO): 0.463 +/- 0.112 (in 3 folds)
# Accuracy: 0.426 +/- 0.053 (in 3 folds)
# MCC: -0.142 +/- 0.107 (in 3 folds)
#
# Global scores:
# Accuracy: 0.424
# MCC: -0.153
#
# Global classification report:
#               precision    recall  f1-score   support
#
#            F       0.44      0.43      0.44        99
#            M       0.40      0.41      0.41        92
#
#     accuracy                           0.42       191
#    macro avg       0.42      0.42      0.42       191
# weighted avg       0.42      0.42      0.42       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.411 +/- 0.074 (in 3 folds)
# ROC-AUC (macro OvO): 0.411 +/- 0.074 (in 3 folds)
# au-PRC (weighted OvO): 0.463 +/- 0.112 (in 3 folds)
# au-PRC (macro OvO): 0.463 +/- 0.112 (in 3 folds)
# Accuracy: 0.460 +/- 0.015 (in 3 folds)
# MCC: 0.026 +/- 0.028 (in 3 folds)
#
# Global scores:
# Accuracy: 0.461
# MCC: -0.071
#
# Global classification report:
#               precision    recall  f1-score   support
#
#            F       0.47      0.31      0.38        99
#            M       0.46      0.62      0.53        92
#
#     accuracy                           0.46       191
#    macro avg       0.46      0.47      0.45       191
# weighted avg       0.46      0.46      0.45       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.539 +/- 0.062 (in 3 folds)
# ROC-AUC (macro OvO): 0.539 +/- 0.062 (in 3 folds)
# au-PRC (weighted OvO): 0.509 +/- 0.105 (in 3 folds)
# au-PRC (macro OvO): 0.509 +/- 0.105 (in 3 folds)
# Accuracy: 0.485 +/- 0.059 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores:
# Accuracy: 0.482
# MCC: 0.000
#
# Global classification report:
#               precision    recall  f1-score   support
#
#            F       0.00      0.00      0.00        99
#            M       0.48      1.00      0.65        92
#
#     accuracy                           0.48       191
#    macro avg       0.24      0.50      0.33       191
# weighted avg       0.23      0.48      0.31       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.485 +/- 0.059 (in 3 folds)
# au-PRC (macro OvO): 0.485 +/- 0.059 (in 3 folds)
# Accuracy: 0.485 +/- 0.059 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores:
# Accuracy: 0.482
# MCC: 0.000
#
# Global classification report:
#               precision    recall  f1-score   support
#
#            F       0.00      0.00      0.00        99
#            M       0.48      1.00      0.65        92
#
#     accuracy                           0.48       191
#    macro avg       0.24      0.50      0.33       191
# weighted avg       0.23      0.48      0.31       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.539 +/- 0.062 (in 3 folds)
# ROC-AUC (macro OvO): 0.539 +/- 0.062 (in 3 folds)
# au-PRC (weighted OvO): 0.509 +/- 0.105 (in 3 folds)
# au-PRC (macro OvO): 0.509 +/- 0.105 (in 3 folds)
# Accuracy: 0.490 +/- 0.069 (in 3 folds)
# MCC: 0.012 +/- 0.076 (in 3 folds)
#
# Global scores:
# Accuracy: 0.487
# MCC: 0.007
#
# Global classification report:
#               precision    recall  f1-score   support
#
#            F       0.53      0.09      0.16        99
#            M       0.48      0.91      0.63        92
#
#     accuracy                           0.49       191
#    macro avg       0.51      0.50      0.39       191
# weighted avg       0.51      0.49      0.38       191
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 3 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 3 folds)
# au-PRC (weighted OvO): 0.485 +/- 0.059 (in 3 folds)
# au-PRC (macro OvO): 0.485 +/- 0.059 (in 3 folds)
# Accuracy: 0.485 +/- 0.059 (in 3 folds)
# MCC: 0.000 +/- 0.000 (in 3 folds)
#
# Global scores:
# Accuracy: 0.482
# MCC: 0.000
#
# Global classification report:
#               precision    recall  f1-score   support
#
#            F       0.00      0.00      0.00        99
#            M       0.48      1.00      0.65        92
#
#     accuracy                           0.48       191
#    macro avg       0.24      0.50      0.33       191
# weighted avg       0.23      0.48      0.31       191
# </pre></td></tr>
# <tr><td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/sex_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/sex_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/sex_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/sex_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/sex_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/BCR/rollup_models/sex_healthy_only_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td></tr></table>
# ### GeneLocus.BCR, TargetObsColumnEnum.covid_vs_healthy, SampleWeightStrategy.ISOTYPE_USAGE
# <table><tr><th style="text-align: center">lasso_multiclass</th>
# <th style="text-align: center">lasso_multiclass-rollup_tuned</th>
# <th style="text-align: center">dummy_stratified</th>
# <th style="text-align: center">dummy_most_frequent</th>
# <th style="text-align: center">dummy_stratified-rollup_tuned</th>
# <th style="text-align: center">dummy_most_frequent-rollup_tuned</th></tr><tr><td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.862 +/- 0.110 (in 3 folds)
# ROC-AUC (macro OvO): 0.862 +/- 0.110 (in 3 folds)
# au-PRC (weighted OvO): 0.935 +/- 0.064 (in 3 folds)
# au-PRC (macro OvO): 0.935 +/- 0.064 (in 3 folds)
# Accuracy: 0.897 +/- 0.039 (in 3 folds)
# MCC: 0.681 +/- 0.130 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.898
# MCC: 0.685
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#            Covid19       0.90      0.60      0.72        63
# Healthy/Background       0.90      0.98      0.94       221
#
#           accuracy                           0.90       284
#          macro avg       0.90      0.79      0.83       284
#       weighted avg       0.90      0.90      0.89       284
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.862 +/- 0.110 (in 3 folds)
# ROC-AUC (macro OvO): 0.862 +/- 0.110 (in 3 folds)
# au-PRC (weighted OvO): 0.935 +/- 0.064 (in 3 folds)
# au-PRC (macro OvO): 0.935 +/- 0.064 (in 3 folds)
# Accuracy: 0.897 +/- 0.039 (in 3 folds)
# MCC: 0.688 +/- 0.120 (in 3 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.898
# MCC: 0.692
# Global evaluation column name: disease.separate_past_exposures
#
# ...
# ### GeneLocus.TCR, TargetObsColumnEnum.hiv_vs_healthy, SampleWeightStrategy.ISOTYPE_USAGE
# <table><tr><th style="text-align: center">lasso_multiclass</th>
# <th style="text-align: center">lasso_multiclass-rollup_tuned</th>
# <th style="text-align: center">dummy_stratified</th>
# <th style="text-align: center">dummy_most_frequent</th>
# <th style="text-align: center">dummy_stratified-rollup_tuned</th>
# <th style="text-align: center">dummy_most_frequent-rollup_tuned</th></tr><tr><td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.928 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.928 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.970 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.970 +/- 0.000 (in 1 folds)
# Accuracy: 0.875 +/- 0.000 (in 1 folds)
# MCC: 0.757 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.875
# MCC: 0.757
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#                HIV       0.74      0.97      0.84        32
# Healthy/Background       0.98      0.83      0.90        64
#
#           accuracy                           0.88        96
#          macro avg       0.86      0.90      0.87        96
#       weighted avg       0.90      0.88      0.88        96
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.928 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.928 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.970 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.970 +/- 0.000 (in 1 folds)
# Accuracy: 0.875 +/- 0.000 (in 1 folds)
# MCC: 0.757 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.875
# MCC: 0.757
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#                HIV       0.74      0.97      0.84        32
# Healthy/Background       0.98      0.83      0.90        64
#
#           accuracy                           0.88        96
#          macro avg       0.86      0.90      0.87        96
#       weighted avg       0.90      0.88      0.88        96
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.488 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.488 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.689 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.689 +/- 0.000 (in 1 folds)
# Accuracy: 0.667 +/- 0.000 (in 1 folds)
# MCC: 0.000 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.667
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#                HIV       0.00      0.00      0.00        32
# Healthy/Background       0.67      1.00      0.80        64
#
#           accuracy                           0.67        96
#          macro avg       0.33      0.50      0.40        96
#       weighted avg       0.44      0.67      0.53        96
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.667 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.667 +/- 0.000 (in 1 folds)
# Accuracy: 0.667 +/- 0.000 (in 1 folds)
# MCC: 0.000 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.667
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#                HIV       0.00      0.00      0.00        32
# Healthy/Background       0.67      1.00      0.80        64
#
#           accuracy                           0.67        96
#          macro avg       0.33      0.50      0.40        96
#       weighted avg       0.44      0.67      0.53        96
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.488 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.488 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.689 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.689 +/- 0.000 (in 1 folds)
# Accuracy: 0.667 +/- 0.000 (in 1 folds)
# MCC: 0.000 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.667
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#                HIV       0.00      0.00      0.00        32
# Healthy/Background       0.67      1.00      0.80        64
#
#           accuracy                           0.67        96
#          macro avg       0.33      0.50      0.40        96
#       weighted avg       0.44      0.67      0.53        96
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.667 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.667 +/- 0.000 (in 1 folds)
# Accuracy: 0.667 +/- 0.000 (in 1 folds)
# MCC: 0.000 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.667
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
#                HIV       0.00      0.00      0.00        32
# Healthy/Background       0.67      1.00      0.80        64
#
#           accuracy                           0.67        96
#          macro avg       0.33      0.50      0.40        96
#       weighted avg       0.44      0.67      0.53        96
# </pre></td></tr>
# <tr><td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/hiv_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/hiv_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/hiv_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/hiv_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/hiv_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/hiv_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td></tr></table>
# ### GeneLocus.TCR, TargetObsColumnEnum.lupus_vs_healthy, SampleWeightStrategy.ISOTYPE_USAGE
# <table><tr><th style="text-align: center">lasso_multiclass</th>
# <th style="text-align: center">lasso_multiclass-rollup_tuned</th>
# <th style="text-align: center">dummy_stratified</th>
# <th style="text-align: center">dummy_most_frequent</th>
# <th style="text-align: center">dummy_stratified-rollup_tuned</th>
# <th style="text-align: center">dummy_most_frequent-rollup_tuned</th></tr><tr><td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.946 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.946 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.903 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.903 +/- 0.000 (in 1 folds)
# Accuracy: 0.812 +/- 0.000 (in 1 folds)
# MCC: 0.566 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.812
# MCC: 0.566
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
# Healthy/Background       0.93      0.81      0.87        64
#              Lupus       0.59      0.81      0.68        21
#
#           accuracy                           0.81        85
#          macro avg       0.76      0.81      0.77        85
#       weighted avg       0.84      0.81      0.82        85
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.946 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.946 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.903 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.903 +/- 0.000 (in 1 folds)
# Accuracy: 0.906 +/- 0.000 (in 1 folds)
# MCC: 0.740 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.906
# MCC: 0.740
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
# Healthy/Background       0.92      0.95      0.94        64
#              Lupus       0.84      0.76      0.80        21
#
#           accuracy                           0.91        85
#          macro avg       0.88      0.86      0.87        85
#       weighted avg       0.90      0.91      0.90        85
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.417 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.417 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.229 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.229 +/- 0.000 (in 1 folds)
# Accuracy: 0.753 +/- 0.000 (in 1 folds)
# MCC: 0.000 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.753
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
# Healthy/Background       0.75      1.00      0.86        64
#              Lupus       0.00      0.00      0.00        21
#
#           accuracy                           0.75        85
#          macro avg       0.38      0.50      0.43        85
#       weighted avg       0.57      0.75      0.65        85
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.247 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.247 +/- 0.000 (in 1 folds)
# Accuracy: 0.753 +/- 0.000 (in 1 folds)
# MCC: 0.000 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.753
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
# Healthy/Background       0.75      1.00      0.86        64
#              Lupus       0.00      0.00      0.00        21
#
#           accuracy                           0.75        85
#          macro avg       0.38      0.50      0.43        85
#       weighted avg       0.57      0.75      0.65        85
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.417 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.417 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.229 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.229 +/- 0.000 (in 1 folds)
# Accuracy: 0.753 +/- 0.000 (in 1 folds)
# MCC: 0.000 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.753
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
# Healthy/Background       0.75      1.00      0.86        64
#              Lupus       0.00      0.00      0.00        21
#
#           accuracy                           0.75        85
#          macro avg       0.38      0.50      0.43        85
#       weighted avg       0.57      0.75      0.65        85
# </pre></td>
# <td style="text-align: center"><pre>Per-fold scores:
# ROC-AUC (weighted OvO): 0.500 +/- 0.000 (in 1 folds)
# ROC-AUC (macro OvO): 0.500 +/- 0.000 (in 1 folds)
# au-PRC (weighted OvO): 0.247 +/- 0.000 (in 1 folds)
# au-PRC (macro OvO): 0.247 +/- 0.000 (in 1 folds)
# Accuracy: 0.753 +/- 0.000 (in 1 folds)
# MCC: 0.000 +/- 0.000 (in 1 folds)
#
# Global scores using column name disease.separate_past_exposures:
# Accuracy: 0.753
# MCC: 0.000
# Global evaluation column name: disease.separate_past_exposures
#
# Global classification report using column name disease.separate_past_exposures:
#                     precision    recall  f1-score   support
#
# Healthy/Background       0.75      1.00      0.86        64
#              Lupus       0.00      0.00      0.00        21
#
#           accuracy                           0.75        85
#          macro avg       0.38      0.50      0.43        85
#       weighted avg       0.57      0.75      0.65        85
# </pre></td></tr>
# <tr><td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/lupus_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/lupus_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.lasso_multiclass-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/lupus_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/lupus_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/lupus_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_stratified-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td>
# <td style="text-align: center"><img src="../out/unirep_fine_tuned/sequence_models/TCR/rollup_models/lupus_vs_healthy_sample_weight_strategy_ISOTYPE_USAGE/sequence_prediction_rollup.dummy_most_frequent-rollup_tuned.train_smaller_model.confusion_matrix.png" style="max-width: 400px; max-height: 800px;" /></td></tr></table>
