# %% [markdown]
# # Tune "train-smaller" repertoire stats model decision thresholds on validation set, and report performance (with and without tuning) on test set
#
# This is run using train-smaller+validation+test, not train+test sets.
#
# Use trained model APIs to do this.

# %%
from malid import config
from malid.train.training_utils import (
    evaluate_original_and_tuned_on_test_set,
    tune_on_validation_set,
)
from malid.trained_model_wrappers import RepertoireClassifier
from malid.datamodels import (
    combine_classification_option_names,
)

# %%
# Run
for gene_locus in config.gene_loci_used:
    map_targets_to_output_dir = {
        target_obs_column: (
            config.paths.repertoire_stats_classifier_output_dir
            / gene_locus.name
            / combine_classification_option_names(target_obs_column)
        )  # output base dir should already exist
        for target_obs_column in config.classification_targets
    }
    print(gene_locus)
    clfs = tune_on_validation_set(
        gene_locus=gene_locus,
        targets=map_targets_to_output_dir,
        model_names=[
            "lasso_multiclass",
            "lasso_cv",
            "ridge_cv",
            "elasticnet_cv",
            "rf_multiclass",
            "xgboost",
            "linearsvm_ovr",
        ],
        model_class=RepertoireClassifier,
    )
    evaluate_original_and_tuned_on_test_set(
        clfs=clfs, gene_locus=gene_locus, targets=map_targets_to_output_dir
    )
# Out:
# 2022-12-30 23:37:26,740 - malid.external.scratch_cache - INFO - Reading network file from local machine cache: /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/fold.0.validation.h5ad -> /srv/scratch/maximz/cache/1a7cd102c4a71eb472da3636203a91984ec407adbc0812ffba2c07c5.0.validation.h5ad
# GeneLocus.BCR
# WARNING: Your filename has more than two extensions: ['.0', '.validation', '.h5ad'].
# Only considering the two last: ['.validation', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.0', '.validation', '.h5ad'].
# Only considering the two last: ['.validation', '.h5ad'].
# 2022-12-30 23:38:27,103 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.0.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-30 23:41:37,601 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.0.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-30 23:44:43,223 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.0.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-30 23:45:37,324 - malid.helpers - INFO - Target TargetObsColumnEnum.covid_vs_healthy: filtering to specimens from diseases ['Covid19', 'Healthy/Background'] only; removed 46 specimens
# 2022-12-30 23:47:11,199 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.0.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-30 23:47:39,640 - malid.helpers - INFO - Target TargetObsColumnEnum.hiv_vs_healthy: filtering to specimens from diseases ['HIV', 'Healthy/Background'] only; removed 40 specimens
# 2022-12-30 23:49:29,504 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.0.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-30 23:49:59,990 - malid.helpers - INFO - Target TargetObsColumnEnum.lupus_vs_healthy: filtering to specimens from diseases ['Lupus', 'Healthy/Background'] only; removed 36 specimens
# 2022-12-30 23:52:00,141 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.0.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-30 23:52:35,148 - malid.helpers - INFO - Target TargetObsColumnEnum.ethnicity_condensed_healthy_only: filtered to specimens with defined ethnicity_condensed column - removed 12 specimens (365758 rows)
# 2022-12-30 23:52:45,023 - malid.helpers - INFO - Target TargetObsColumnEnum.ethnicity_condensed_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 56 specimens
# 2022-12-30 23:54:13,779 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.0.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-30 23:54:49,562 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_healthy_only: filtered to specimens with defined age_group column - removed 2 specimens (20035 rows)
# 2022-12-30 23:55:00,505 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 60 specimens
# 2022-12-30 23:57:02,503 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.0.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-30 23:57:38,971 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_binary_healthy_only: filtered to specimens with defined age_group_binary column - removed 2 specimens (20035 rows)
# 2022-12-30 23:57:49,488 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_binary_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 60 specimens
# 2022-12-30 23:59:13,894 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.0.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-30 23:59:48,891 - malid.helpers - INFO - Target TargetObsColumnEnum.sex_healthy_only: filtered to specimens with defined sex column - removed 1 specimens (13078 rows)
# 2022-12-30 23:59:59,716 - malid.helpers - INFO - Target TargetObsColumnEnum.sex_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 61 specimens
# 2022-12-31 00:01:15,877 - malid.external.scratch_cache - INFO - Reading network file from local machine cache: /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/fold.1.validation.h5ad -> /srv/scratch/maximz/cache/9c85c2a266a883a684e8c5d509b8321d4689380ae1339b1d3a20c9e8.1.validation.h5ad
# WARNING: Your filename has more than two extensions: ['.1', '.validation', '.h5ad'].
# Only considering the two last: ['.validation', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.1', '.validation', '.h5ad'].
# Only considering the two last: ['.validation', '.h5ad'].
# 2022-12-31 00:02:20,512 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:05:23,082 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:08:23,341 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:08:47,479 - malid.helpers - INFO - Target TargetObsColumnEnum.covid_vs_healthy: filtering to specimens from diseases ['Covid19', 'Healthy/Background'] only; removed 42 specimens
# 2022-12-31 00:10:20,067 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:10:47,056 - malid.helpers - INFO - Target TargetObsColumnEnum.hiv_vs_healthy: filtering to specimens from diseases ['HIV', 'Healthy/Background'] only; removed 33 specimens
# 2022-12-31 00:12:44,839 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:13:12,604 - malid.helpers - INFO - Target TargetObsColumnEnum.lupus_vs_healthy: filtering to specimens from diseases ['Lupus', 'Healthy/Background'] only; removed 35 specimens
# 2022-12-31 00:15:05,974 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:16:25,796 - malid.helpers - INFO - Target TargetObsColumnEnum.ethnicity_condensed_healthy_only: filtered to specimens with defined ethnicity_condensed column - removed 11 specimens (332120 rows)
# 2022-12-31 00:16:36,196 - malid.helpers - INFO - Target TargetObsColumnEnum.ethnicity_condensed_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 48 specimens
# 2022-12-31 00:18:11,004 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:18:43,009 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_healthy_only: filtered to specimens with defined age_group column - removed 1 specimens (5035 rows)
# 2022-12-31 00:18:53,964 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 54 specimens
# 2022-12-31 00:20:57,967 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:21:29,247 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_binary_healthy_only: filtered to specimens with defined age_group_binary column - removed 1 specimens (5035 rows)
# 2022-12-31 00:21:39,584 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_binary_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 54 specimens
# 2022-12-31 00:23:08,875 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:23:30,839 - malid.helpers - INFO - Target TargetObsColumnEnum.sex_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 55 specimens
# 2022-12-31 00:24:41,600 - malid.external.scratch_cache - INFO - Reading network file from local machine cache: /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/fold.2.validation.h5ad -> /srv/scratch/maximz/cache/08c1068072d49c0e446bca7b2515cc6904c1583e869886f65b95c2db.2.validation.h5ad
# WARNING: Your filename has more than two extensions: ['.2', '.validation', '.h5ad'].
# Only considering the two last: ['.validation', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.2', '.validation', '.h5ad'].
# Only considering the two last: ['.validation', '.h5ad'].
# 2022-12-31 00:25:40,543 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.2.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:28:54,987 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.2.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:32:19,061 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.2.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:32:53,332 - malid.helpers - INFO - Target TargetObsColumnEnum.covid_vs_healthy: filtering to specimens from diseases ['Covid19', 'Healthy/Background'] only; removed 44 specimens
# 2022-12-31 00:34:42,917 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.2.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:35:14,302 - malid.helpers - INFO - Target TargetObsColumnEnum.hiv_vs_healthy: filtering to specimens from diseases ['HIV', 'Healthy/Background'] only; removed 37 specimens
# 2022-12-31 00:37:08,941 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.2.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:37:42,925 - malid.helpers - INFO - Target TargetObsColumnEnum.lupus_vs_healthy: filtering to specimens from diseases ['Lupus', 'Healthy/Background'] only; removed 35 specimens
# 2022-12-31 00:39:57,377 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.2.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:40:34,602 - malid.helpers - INFO - Target TargetObsColumnEnum.ethnicity_condensed_healthy_only: filtered to specimens with defined ethnicity_condensed column - removed 13 specimens (345033 rows)
# 2022-12-31 00:40:51,416 - malid.helpers - INFO - Target TargetObsColumnEnum.ethnicity_condensed_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 51 specimens
# 2022-12-31 00:43:25,887 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.2.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:44:05,529 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_healthy_only: filtered to specimens with defined age_group column - removed 3 specimens (59403 rows)
# 2022-12-31 00:44:18,899 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 56 specimens
# 2022-12-31 00:47:53,286 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.2.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:48:33,497 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_binary_healthy_only: filtered to specimens with defined age_group_binary column - removed 3 specimens (59403 rows)
# 2022-12-31 00:48:46,344 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_binary_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 56 specimens
# 2022-12-31 00:50:31,268 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.2.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:51:09,466 - malid.helpers - INFO - Target TargetObsColumnEnum.sex_healthy_only: filtered to specimens with defined sex column - removed 2 specimens (35834 rows)
# 2022-12-31 00:51:22,354 - malid.helpers - INFO - Target TargetObsColumnEnum.sex_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 57 specimens
# 2022-12-31 00:52:47,898 - malid.external.scratch_cache - INFO - Reading network file from local machine cache: /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/fold.-1.validation.h5ad -> /srv/scratch/maximz/cache/d12efe0f72cdefa66ff3f9089960fc16b89c64c2837b4b81d55fb8ed.-1.validation.h5ad
# WARNING: Your filename has more than two extensions: ['.-1', '.validation', '.h5ad'].
# Only considering the two last: ['.validation', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.-1', '.validation', '.h5ad'].
# Only considering the two last: ['.validation', '.h5ad'].
# 2022-12-31 00:54:27,261 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.-1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 00:56:46,677 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.-1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 01:03:10,074 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.-1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 01:05:08,593 - malid.helpers - INFO - Target TargetObsColumnEnum.covid_vs_healthy: filtering to specimens from diseases ['Covid19', 'Healthy/Background'] only; removed 66 specimens
# 2022-12-31 01:06:42,924 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.-1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 01:07:47,272 - malid.helpers - INFO - Target TargetObsColumnEnum.hiv_vs_healthy: filtering to specimens from diseases ['HIV', 'Healthy/Background'] only; removed 53 specimens
# 2022-12-31 01:09:15,000 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.-1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 01:10:12,607 - malid.helpers - INFO - Target TargetObsColumnEnum.lupus_vs_healthy: filtering to specimens from diseases ['Lupus', 'Healthy/Background'] only; removed 53 specimens
# 2022-12-31 01:11:43,730 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.-1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 01:12:58,580 - malid.helpers - INFO - Target TargetObsColumnEnum.ethnicity_condensed_healthy_only: filtered to specimens with defined ethnicity_condensed column - removed 20 specimens (485965 rows)
# 2022-12-31 01:16:34,518 - malid.helpers - INFO - Target TargetObsColumnEnum.ethnicity_condensed_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 75 specimens
# IOStream.flush timed out
# 2022-12-31 01:27:44,411 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.-1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 01:28:47,510 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_healthy_only: filtered to specimens with defined age_group column - removed 2 specimens (35185 rows)
# 2022-12-31 01:29:08,576 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 84 specimens
# 2022-12-31 01:39:07,274 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.-1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 01:40:06,417 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_binary_healthy_only: filtered to specimens with defined age_group_binary column - removed 2 specimens (35185 rows)
# 2022-12-31 01:40:27,227 - malid.helpers - INFO - Target TargetObsColumnEnum.age_group_binary_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 84 specimens
# 2022-12-31 01:42:30,843 - malid.helpers - WARNING - Not marking any sequences as confident_sequence because those annotations weren't found: [Errno 2] No such file or directory: '/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/anndatas_scaled/BCR/neighborhoods/knn_neighborhood.-1.validation.IGHG.embedded_onto.train_smaller.combined_data.filtered.tsv.gz'
# 2022-12-31 01:43:29,498 - malid.helpers - INFO - Target TargetObsColumnEnum.sex_healthy_only: filtered to specimens with defined sex column - removed 1 specimens (11616 rows)
# 2022-12-31 01:43:50,176 - malid.helpers - INFO - Target TargetObsColumnEnum.sex_healthy_only: filtering to specimens from diseases ['Healthy/Background'] only; removed 85 specimens
# GeneLocus.BCR TargetObsColumnEnum.disease
#                                            ROC-AUC (weighted OvO) per fold  \
# lasso_multiclass                              0.938 +/- 0.014 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned    0.938 +/- 0.014 (in 3 folds)
# rf_multiclass                                 0.922 +/- 0.008 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned       0.922 +/- 0.008 (in 3 folds)
# linearsvm_ovr                                 0.918 +/- 0.010 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned       0.918 +/- 0.010 (in 3 folds)
# xgboost                                       0.910 +/- 0.029 (in 3 folds)
# xgboost.decision_thresholds_tuned             0.910 +/- 0.029 (in 3 folds)
# ridge_cv                                      0.907 +/- 0.019 (in 3 folds)
# ridge_cv.decision_thresholds_tuned            0.907 +/- 0.019 (in 3 folds)
# elasticnet_cv                                 0.907 +/- 0.016 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned       0.907 +/- 0.016 (in 3 folds)
# lasso_cv                                      0.896 +/- 0.019 (in 3 folds)
# lasso_cv.decision_thresholds_tuned            0.896 +/- 0.019 (in 3 folds)
#
#                                             ROC-AUC (macro OvO) per fold  \
# lasso_multiclass                            0.940 +/- 0.016 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  0.940 +/- 0.016 (in 3 folds)
# rf_multiclass                               0.923 +/- 0.009 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     0.923 +/- 0.009 (in 3 folds)
# linearsvm_ovr                               0.918 +/- 0.014 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     0.918 +/- 0.014 (in 3 folds)
# xgboost                                     0.909 +/- 0.031 (in 3 folds)
# xgboost.decision_thresholds_tuned           0.909 +/- 0.031 (in 3 folds)
# ridge_cv                                    0.900 +/- 0.024 (in 3 folds)
# ridge_cv.decision_thresholds_tuned          0.900 +/- 0.024 (in 3 folds)
# elasticnet_cv                               0.900 +/- 0.017 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     0.900 +/- 0.017 (in 3 folds)
# lasso_cv                                    0.889 +/- 0.019 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          0.889 +/- 0.019 (in 3 folds)
#
#                                            au-PRC (weighted OvO) per fold  \
# lasso_multiclass                             0.937 +/- 0.017 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned   0.937 +/- 0.017 (in 3 folds)
# rf_multiclass                                0.929 +/- 0.008 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned      0.929 +/- 0.008 (in 3 folds)
# linearsvm_ovr                                0.916 +/- 0.014 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned      0.916 +/- 0.014 (in 3 folds)
# xgboost                                      0.918 +/- 0.029 (in 3 folds)
# xgboost.decision_thresholds_tuned            0.918 +/- 0.029 (in 3 folds)
# ridge_cv                                     0.907 +/- 0.022 (in 3 folds)
# ridge_cv.decision_thresholds_tuned           0.907 +/- 0.022 (in 3 folds)
# elasticnet_cv                                0.906 +/- 0.013 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned      0.906 +/- 0.013 (in 3 folds)
# lasso_cv                                     0.892 +/- 0.016 (in 3 folds)
# lasso_cv.decision_thresholds_tuned           0.892 +/- 0.016 (in 3 folds)
#
#                                              au-PRC (macro OvO) per fold  \
# lasso_multiclass                            0.941 +/- 0.018 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  0.941 +/- 0.018 (in 3 folds)
# rf_multiclass                               0.932 +/- 0.010 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     0.932 +/- 0.010 (in 3 folds)
# linearsvm_ovr                               0.920 +/- 0.016 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     0.920 +/- 0.016 (in 3 folds)
# xgboost                                     0.922 +/- 0.031 (in 3 folds)
# xgboost.decision_thresholds_tuned           0.922 +/- 0.031 (in 3 folds)
# ridge_cv                                    0.906 +/- 0.027 (in 3 folds)
# ridge_cv.decision_thresholds_tuned          0.906 +/- 0.027 (in 3 folds)
# elasticnet_cv                               0.906 +/- 0.015 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     0.906 +/- 0.015 (in 3 folds)
# lasso_cv                                    0.892 +/- 0.018 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          0.892 +/- 0.018 (in 3 folds)
#
#                                                        Accuracy per fold  \
# lasso_multiclass                            0.805 +/- 0.023 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  0.845 +/- 0.002 (in 3 folds)
# rf_multiclass                               0.768 +/- 0.051 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     0.839 +/- 0.020 (in 3 folds)
# linearsvm_ovr                               0.783 +/- 0.005 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     0.830 +/- 0.005 (in 3 folds)
# xgboost                                     0.783 +/- 0.019 (in 3 folds)
# xgboost.decision_thresholds_tuned           0.823 +/- 0.010 (in 3 folds)
# ridge_cv                                    0.575 +/- 0.202 (in 3 folds)
# ridge_cv.decision_thresholds_tuned          0.793 +/- 0.083 (in 3 folds)
# elasticnet_cv                               0.755 +/- 0.046 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     0.827 +/- 0.049 (in 3 folds)
# lasso_cv                                    0.762 +/- 0.072 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          0.818 +/- 0.049 (in 3 folds)
#
#                                                             MCC per fold  \
# lasso_multiclass                            0.719 +/- 0.031 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  0.776 +/- 0.006 (in 3 folds)
# rf_multiclass                               0.659 +/- 0.068 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     0.767 +/- 0.028 (in 3 folds)
# linearsvm_ovr                               0.685 +/- 0.011 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     0.754 +/- 0.007 (in 3 folds)
# xgboost                                     0.682 +/- 0.031 (in 3 folds)
# xgboost.decision_thresholds_tuned           0.740 +/- 0.014 (in 3 folds)
# ridge_cv                                    0.238 +/- 0.412 (in 3 folds)
# ridge_cv.decision_thresholds_tuned          0.698 +/- 0.114 (in 3 folds)
# elasticnet_cv                               0.641 +/- 0.059 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     0.754 +/- 0.057 (in 3 folds)
# lasso_cv                                    0.650 +/- 0.100 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          0.738 +/- 0.061 (in 3 folds)
#
#                                            Accuracy global MCC global  \
# lasso_multiclass                                     0.805      0.718
# lasso_multiclass.decision_thresholds_tuned           0.845      0.773
# rf_multiclass                                        0.768      0.658
# rf_multiclass.decision_thresholds_tuned              0.839      0.765
# linearsvm_ovr                                        0.783      0.683
# linearsvm_ovr.decision_thresholds_tuned              0.830      0.750
# xgboost                                              0.783      0.681
# xgboost.decision_thresholds_tuned                    0.824      0.739
# ridge_cv                                             0.576      0.358
# ridge_cv.decision_thresholds_tuned                   0.793      0.695
# elasticnet_cv                                        0.755      0.638
# elasticnet_cv.decision_thresholds_tuned              0.827      0.748
# lasso_cv                                             0.762      0.646
# lasso_cv.decision_thresholds_tuned                   0.817      0.733
#
#                                             sample_size  n_abstentions  \
# lasso_multiclass                                    323              0
# lasso_multiclass.decision_thresholds_tuned          323              0
# rf_multiclass                                       323              0
# rf_multiclass.decision_thresholds_tuned             323              0
# linearsvm_ovr                                       323              0
# linearsvm_ovr.decision_thresholds_tuned             323              0
# xgboost                                             323              0
# xgboost.decision_thresholds_tuned                   323              0
# ridge_cv                                            323              0
# ridge_cv.decision_thresholds_tuned                  323              0
# elasticnet_cv                                       323              0
# elasticnet_cv.decision_thresholds_tuned             323              0
# lasso_cv                                            323              0
# lasso_cv.decision_thresholds_tuned                  323              0
#
#                                             sample_size including abstentions  \
# lasso_multiclass                                                          323
# lasso_multiclass.decision_thresholds_tuned                                323
# rf_multiclass                                                             323
# rf_multiclass.decision_thresholds_tuned                                   323
# linearsvm_ovr                                                             323
# linearsvm_ovr.decision_thresholds_tuned                                   323
# xgboost                                                                   323
# xgboost.decision_thresholds_tuned                                         323
# ridge_cv                                                                  323
# ridge_cv.decision_thresholds_tuned                                        323
# elasticnet_cv                                                             323
# elasticnet_cv.decision_thresholds_tuned                                   323
# lasso_cv                                                                  323
# lasso_cv.decision_thresholds_tuned                                        323
#
#                                             abstention_rate  missing_classes
# lasso_multiclass                                        0.0            False
# lasso_multiclass.decision_thresholds_tuned              0.0            False
# rf_multiclass                                           0.0            False
# rf_multiclass.decision_thresholds_tuned                 0.0            False
# linearsvm_ovr                                           0.0            False
# linearsvm_ovr.decision_thresholds_tuned                 0.0            False
# xgboost                                                 0.0            False
# xgboost.decision_thresholds_tuned                       0.0            False
# ridge_cv                                                0.0            False
# ridge_cv.decision_thresholds_tuned                      0.0            False
# elasticnet_cv                                           0.0            False
# elasticnet_cv.decision_thresholds_tuned                 0.0            False
# lasso_cv                                                0.0            False
# lasso_cv.decision_thresholds_tuned                      0.0            False
# GeneLocus.BCR TargetObsColumnEnum.disease_all_demographics_present
#                                            ROC-AUC (weighted OvO) per fold  \
# lasso_multiclass                              0.938 +/- 0.012 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned    0.938 +/- 0.012 (in 3 folds)
# rf_multiclass                                 0.918 +/- 0.004 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned       0.918 +/- 0.004 (in 3 folds)
# xgboost                                       0.913 +/- 0.018 (in 3 folds)
# xgboost.decision_thresholds_tuned             0.913 +/- 0.018 (in 3 folds)
# linearsvm_ovr                                 0.912 +/- 0.010 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned       0.912 +/- 0.010 (in 3 folds)
# ridge_cv                                      0.910 +/- 0.015 (in 3 folds)
# ridge_cv.decision_thresholds_tuned            0.910 +/- 0.015 (in 3 folds)
# elasticnet_cv                                 0.904 +/- 0.009 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned       0.904 +/- 0.009 (in 3 folds)
# lasso_cv                                      0.891 +/- 0.021 (in 3 folds)
# lasso_cv.decision_thresholds_tuned            0.891 +/- 0.021 (in 3 folds)
#
#                                             ROC-AUC (macro OvO) per fold  \
# lasso_multiclass                            0.939 +/- 0.012 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  0.939 +/- 0.012 (in 3 folds)
# rf_multiclass                               0.918 +/- 0.006 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     0.918 +/- 0.006 (in 3 folds)
# xgboost                                     0.911 +/- 0.018 (in 3 folds)
# xgboost.decision_thresholds_tuned           0.911 +/- 0.018 (in 3 folds)
# linearsvm_ovr                               0.910 +/- 0.010 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     0.910 +/- 0.010 (in 3 folds)
# ridge_cv                                    0.903 +/- 0.022 (in 3 folds)
# ridge_cv.decision_thresholds_tuned          0.903 +/- 0.022 (in 3 folds)
# elasticnet_cv                               0.898 +/- 0.008 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     0.898 +/- 0.008 (in 3 folds)
# lasso_cv                                    0.885 +/- 0.021 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          0.885 +/- 0.021 (in 3 folds)
#
#                                            au-PRC (weighted OvO) per fold  \
# lasso_multiclass                             0.938 +/- 0.015 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned   0.938 +/- 0.015 (in 3 folds)
# rf_multiclass                                0.923 +/- 0.004 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned      0.923 +/- 0.004 (in 3 folds)
# xgboost                                      0.925 +/- 0.015 (in 3 folds)
# xgboost.decision_thresholds_tuned            0.925 +/- 0.015 (in 3 folds)
# linearsvm_ovr                                0.908 +/- 0.007 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned      0.908 +/- 0.007 (in 3 folds)
# ridge_cv                                     0.911 +/- 0.018 (in 3 folds)
# ridge_cv.decision_thresholds_tuned           0.911 +/- 0.018 (in 3 folds)
# elasticnet_cv                                0.908 +/- 0.013 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned      0.908 +/- 0.013 (in 3 folds)
# lasso_cv                                     0.896 +/- 0.017 (in 3 folds)
# lasso_cv.decision_thresholds_tuned           0.896 +/- 0.017 (in 3 folds)
#
#                                              au-PRC (macro OvO) per fold  \
# lasso_multiclass                            0.941 +/- 0.014 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  0.941 +/- 0.014 (in 3 folds)
# rf_multiclass                               0.926 +/- 0.003 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     0.926 +/- 0.003 (in 3 folds)
# xgboost                                     0.927 +/- 0.014 (in 3 folds)
# xgboost.decision_thresholds_tuned           0.927 +/- 0.014 (in 3 folds)
# linearsvm_ovr                               0.910 +/- 0.010 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     0.910 +/- 0.010 (in 3 folds)
# ridge_cv                                    0.910 +/- 0.024 (in 3 folds)
# ridge_cv.decision_thresholds_tuned          0.910 +/- 0.024 (in 3 folds)
# elasticnet_cv                               0.909 +/- 0.011 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     0.909 +/- 0.011 (in 3 folds)
# lasso_cv                                    0.896 +/- 0.017 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          0.896 +/- 0.017 (in 3 folds)
#
#                                                        Accuracy per fold  \
# lasso_multiclass                            0.800 +/- 0.008 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  0.842 +/- 0.029 (in 3 folds)
# rf_multiclass                               0.748 +/- 0.062 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     0.818 +/- 0.042 (in 3 folds)
# xgboost                                     0.754 +/- 0.032 (in 3 folds)
# xgboost.decision_thresholds_tuned           0.824 +/- 0.008 (in 3 folds)
# linearsvm_ovr                               0.772 +/- 0.048 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     0.814 +/- 0.029 (in 3 folds)
# ridge_cv                                    0.654 +/- 0.159 (in 3 folds)
# ridge_cv.decision_thresholds_tuned          0.720 +/- 0.197 (in 3 folds)
# elasticnet_cv                               0.780 +/- 0.076 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     0.839 +/- 0.052 (in 3 folds)
# lasso_cv                                    0.759 +/- 0.090 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          0.818 +/- 0.059 (in 3 folds)
#
#                                                             MCC per fold  \
# lasso_multiclass                            0.708 +/- 0.007 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  0.775 +/- 0.034 (in 3 folds)
# rf_multiclass                               0.629 +/- 0.075 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     0.742 +/- 0.037 (in 3 folds)
# xgboost                                     0.640 +/- 0.038 (in 3 folds)
# xgboost.decision_thresholds_tuned           0.742 +/- 0.018 (in 3 folds)
# linearsvm_ovr                               0.668 +/- 0.064 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     0.735 +/- 0.033 (in 3 folds)
# ridge_cv                                    0.421 +/- 0.375 (in 3 folds)
# ridge_cv.decision_thresholds_tuned          0.507 +/- 0.440 (in 3 folds)
# elasticnet_cv                               0.677 +/- 0.101 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     0.770 +/- 0.060 (in 3 folds)
# lasso_cv                                    0.644 +/- 0.123 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          0.738 +/- 0.073 (in 3 folds)
#
#                                            Accuracy global MCC global  \
# lasso_multiclass                                     0.800      0.707
# lasso_multiclass.decision_thresholds_tuned           0.842      0.769
# rf_multiclass                                        0.747      0.626
# rf_multiclass.decision_thresholds_tuned              0.818      0.733
# xgboost                                              0.754      0.635
# xgboost.decision_thresholds_tuned                    0.825      0.740
# linearsvm_ovr                                        0.772      0.664
# linearsvm_ovr.decision_thresholds_tuned              0.814      0.724
# ridge_cv                                             0.656      0.498
# ridge_cv.decision_thresholds_tuned                   0.723      0.586
# elasticnet_cv                                        0.779      0.671
# elasticnet_cv.decision_thresholds_tuned              0.839      0.764
# lasso_cv                                             0.758      0.639
# lasso_cv.decision_thresholds_tuned                   0.818      0.733
#
#                                             sample_size  n_abstentions  \
# lasso_multiclass                                    285              0
# lasso_multiclass.decision_thresholds_tuned          285              0
# rf_multiclass                                       285              0
# rf_multiclass.decision_thresholds_tuned             285              0
# xgboost                                             285              0
# xgboost.decision_thresholds_tuned                   285              0
# linearsvm_ovr                                       285              0
# linearsvm_ovr.decision_thresholds_tuned             285              0
# ridge_cv                                            285              0
# ridge_cv.decision_thresholds_tuned                  285              0
# elasticnet_cv                                       285              0
# elasticnet_cv.decision_thresholds_tuned             285              0
# lasso_cv                                            285              0
# lasso_cv.decision_thresholds_tuned                  285              0
#
#                                             sample_size including abstentions  \
# lasso_multiclass                                                          285
# lasso_multiclass.decision_thresholds_tuned                                285
# rf_multiclass                                                             285
# rf_multiclass.decision_thresholds_tuned                                   285
# xgboost                                                                   285
# xgboost.decision_thresholds_tuned                                         285
# linearsvm_ovr                                                             285
# linearsvm_ovr.decision_thresholds_tuned                                   285
# ridge_cv                                                                  285
# ridge_cv.decision_thresholds_tuned                                        285
# elasticnet_cv                                                             285
# elasticnet_cv.decision_thresholds_tuned                                   285
# lasso_cv                                                                  285
# lasso_cv.decision_thresholds_tuned                                        285
#
#                                             abstention_rate  missing_classes
# lasso_multiclass                                        0.0            False
# lasso_multiclass.decision_thresholds_tuned              0.0            False
# rf_multiclass                                           0.0            False
# ...
# elasticnet_cv                                        0.667      0.185
# elasticnet_cv.decision_thresholds_tuned              0.600      0.408
# lasso_cv                                             0.667      0.185
# lasso_cv.decision_thresholds_tuned                   0.624      0.410
# ridge_cv                                             0.673      0.185
# ridge_cv.decision_thresholds_tuned                   0.618      0.112
#
#                                             sample_size  n_abstentions  \
# linearsvm_ovr                                       165              0
# linearsvm_ovr.decision_thresholds_tuned             165              0
# lasso_multiclass                                    165              0
# lasso_multiclass.decision_thresholds_tuned          165              0
# rf_multiclass                                       165              0
# rf_multiclass.decision_thresholds_tuned             165              0
# xgboost                                             165              0
# xgboost.decision_thresholds_tuned                   165              0
# elasticnet_cv                                       165              0
# elasticnet_cv.decision_thresholds_tuned             165              0
# lasso_cv                                            165              0
# lasso_cv.decision_thresholds_tuned                  165              0
# ridge_cv                                            165              0
# ridge_cv.decision_thresholds_tuned                  165              0
#
#                                             sample_size including abstentions  \
# linearsvm_ovr                                                             165
# linearsvm_ovr.decision_thresholds_tuned                                   165
# lasso_multiclass                                                          165
# lasso_multiclass.decision_thresholds_tuned                                165
# rf_multiclass                                                             165
# rf_multiclass.decision_thresholds_tuned                                   165
# xgboost                                                                   165
# xgboost.decision_thresholds_tuned                                         165
# elasticnet_cv                                                             165
# elasticnet_cv.decision_thresholds_tuned                                   165
# lasso_cv                                                                  165
# lasso_cv.decision_thresholds_tuned                                        165
# ridge_cv                                                                  165
# ridge_cv.decision_thresholds_tuned                                        165
#
#                                             abstention_rate  missing_classes
# linearsvm_ovr                                           0.0            False
# linearsvm_ovr.decision_thresholds_tuned                 0.0            False
# lasso_multiclass                                        0.0            False
# lasso_multiclass.decision_thresholds_tuned              0.0            False
# rf_multiclass                                           0.0            False
# rf_multiclass.decision_thresholds_tuned                 0.0            False
# xgboost                                                 0.0            False
# xgboost.decision_thresholds_tuned                       0.0            False
# elasticnet_cv                                           0.0            False
# elasticnet_cv.decision_thresholds_tuned                 0.0            False
# lasso_cv                                                0.0            False
# lasso_cv.decision_thresholds_tuned                      0.0            False
# ridge_cv                                                0.0            False
# ridge_cv.decision_thresholds_tuned                      0.0            False
# /users/maximz/code/boyd-immune-repertoire-classification/out/repertoire_stats/TCR/age_group_binary_healthy_only/train_smaller_model.compare_model_scores.test_set_performance.tsv
# GeneLocus.TCR TargetObsColumnEnum.sex_healthy_only --> /users/maximz/code/boyd-immune-repertoire-classification/out/repertoire_stats/TCR/sex_healthy_only
#                                            ROC-AUC (weighted OvO) per fold  \
# lasso_cv                                      0.495 +/- 0.009 (in 3 folds)
# lasso_cv.decision_thresholds_tuned            0.495 +/- 0.009 (in 3 folds)
# ridge_cv                                      0.490 +/- 0.017 (in 3 folds)
# ridge_cv.decision_thresholds_tuned            0.490 +/- 0.017 (in 3 folds)
# elasticnet_cv                                 0.467 +/- 0.045 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned       0.467 +/- 0.045 (in 3 folds)
# linearsvm_ovr                                 0.464 +/- 0.033 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned       0.464 +/- 0.033 (in 3 folds)
# lasso_multiclass                              0.457 +/- 0.053 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned    0.457 +/- 0.053 (in 3 folds)
# rf_multiclass                                 0.433 +/- 0.074 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned       0.433 +/- 0.074 (in 3 folds)
# xgboost                                       0.429 +/- 0.019 (in 3 folds)
# xgboost.decision_thresholds_tuned             0.429 +/- 0.019 (in 3 folds)
#
#                                             ROC-AUC (macro OvO) per fold  \
# lasso_cv                                    0.495 +/- 0.009 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          0.495 +/- 0.009 (in 3 folds)
# ridge_cv                                    0.490 +/- 0.017 (in 3 folds)
# ridge_cv.decision_thresholds_tuned          0.490 +/- 0.017 (in 3 folds)
# elasticnet_cv                               0.467 +/- 0.045 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     0.467 +/- 0.045 (in 3 folds)
# linearsvm_ovr                               0.464 +/- 0.033 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     0.464 +/- 0.033 (in 3 folds)
# lasso_multiclass                            0.457 +/- 0.053 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  0.457 +/- 0.053 (in 3 folds)
# rf_multiclass                               0.433 +/- 0.074 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     0.433 +/- 0.074 (in 3 folds)
# xgboost                                     0.429 +/- 0.019 (in 3 folds)
# xgboost.decision_thresholds_tuned           0.429 +/- 0.019 (in 3 folds)
#
#                                            au-PRC (weighted OvO) per fold  \
# lasso_cv                                     0.556 +/- 0.056 (in 3 folds)
# lasso_cv.decision_thresholds_tuned           0.556 +/- 0.056 (in 3 folds)
# ridge_cv                                     0.554 +/- 0.057 (in 3 folds)
# ridge_cv.decision_thresholds_tuned           0.554 +/- 0.057 (in 3 folds)
# elasticnet_cv                                0.536 +/- 0.022 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned      0.536 +/- 0.022 (in 3 folds)
# linearsvm_ovr                                0.534 +/- 0.061 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned      0.534 +/- 0.061 (in 3 folds)
# lasso_multiclass                             0.530 +/- 0.072 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned   0.530 +/- 0.072 (in 3 folds)
# rf_multiclass                                0.513 +/- 0.076 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned      0.513 +/- 0.076 (in 3 folds)
# xgboost                                      0.543 +/- 0.051 (in 3 folds)
# xgboost.decision_thresholds_tuned            0.543 +/- 0.051 (in 3 folds)
#
#                                              au-PRC (macro OvO) per fold  \
# lasso_cv                                    0.556 +/- 0.056 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          0.556 +/- 0.056 (in 3 folds)
# ridge_cv                                    0.554 +/- 0.057 (in 3 folds)
# ridge_cv.decision_thresholds_tuned          0.554 +/- 0.057 (in 3 folds)
# elasticnet_cv                               0.536 +/- 0.022 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     0.536 +/- 0.022 (in 3 folds)
# linearsvm_ovr                               0.534 +/- 0.061 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     0.534 +/- 0.061 (in 3 folds)
# lasso_multiclass                            0.530 +/- 0.072 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  0.530 +/- 0.072 (in 3 folds)
# rf_multiclass                               0.513 +/- 0.076 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     0.513 +/- 0.076 (in 3 folds)
# xgboost                                     0.543 +/- 0.051 (in 3 folds)
# xgboost.decision_thresholds_tuned           0.543 +/- 0.051 (in 3 folds)
#
#                                                        Accuracy per fold  \
# lasso_cv                                    0.543 +/- 0.068 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          0.463 +/- 0.073 (in 3 folds)
# ridge_cv                                    0.549 +/- 0.062 (in 3 folds)
# ridge_cv.decision_thresholds_tuned          0.543 +/- 0.068 (in 3 folds)
# elasticnet_cv                               0.537 +/- 0.075 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     0.456 +/- 0.085 (in 3 folds)
# linearsvm_ovr                               0.445 +/- 0.048 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     0.440 +/- 0.079 (in 3 folds)
# lasso_multiclass                            0.449 +/- 0.080 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  0.452 +/- 0.063 (in 3 folds)
# rf_multiclass                               0.456 +/- 0.056 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     0.478 +/- 0.048 (in 3 folds)
# xgboost                                     0.443 +/- 0.028 (in 3 folds)
# xgboost.decision_thresholds_tuned           0.484 +/- 0.102 (in 3 folds)
#
#                                                              MCC per fold  \
# lasso_cv                                    -0.005 +/- 0.008 (in 3 folds)
# lasso_cv.decision_thresholds_tuned          -0.006 +/- 0.011 (in 3 folds)
# ridge_cv                                     0.000 +/- 0.000 (in 3 folds)
# ridge_cv.decision_thresholds_tuned           0.000 +/- 0.000 (in 3 folds)
# elasticnet_cv                               -0.016 +/- 0.028 (in 3 folds)
# elasticnet_cv.decision_thresholds_tuned     -0.056 +/- 0.081 (in 3 folds)
# linearsvm_ovr                               -0.099 +/- 0.113 (in 3 folds)
# linearsvm_ovr.decision_thresholds_tuned     -0.109 +/- 0.101 (in 3 folds)
# lasso_multiclass                            -0.090 +/- 0.173 (in 3 folds)
# lasso_multiclass.decision_thresholds_tuned  -0.046 +/- 0.040 (in 3 folds)
# rf_multiclass                               -0.095 +/- 0.114 (in 3 folds)
# rf_multiclass.decision_thresholds_tuned     -0.049 +/- 0.101 (in 3 folds)
# xgboost                                     -0.114 +/- 0.062 (in 3 folds)
# xgboost.decision_thresholds_tuned           -0.101 +/- 0.103 (in 3 folds)
#
#                                            Accuracy global MCC global  \
# lasso_cv                                             0.539      0.033
# lasso_cv.decision_thresholds_tuned                   0.467     -0.067
# ridge_cv                                             0.545      0.072
# ridge_cv.decision_thresholds_tuned                   0.539      0.000
# elasticnet_cv                                        0.533      0.014
# elasticnet_cv.decision_thresholds_tuned              0.461     -0.082
# linearsvm_ovr                                        0.442     -0.110
# linearsvm_ovr.decision_thresholds_tuned              0.442     -0.104
# lasso_multiclass                                     0.448     -0.097
# lasso_multiclass.decision_thresholds_tuned           0.455     -0.079
# rf_multiclass                                        0.455     -0.098
# rf_multiclass.decision_thresholds_tuned              0.479     -0.019
# xgboost                                              0.442     -0.120
# xgboost.decision_thresholds_tuned                    0.479     -0.086
#
#                                             sample_size  n_abstentions  \
# lasso_cv                                            165              0
# lasso_cv.decision_thresholds_tuned                  165              0
# ridge_cv                                            165              0
# ridge_cv.decision_thresholds_tuned                  165              0
# elasticnet_cv                                       165              0
# elasticnet_cv.decision_thresholds_tuned             165              0
# linearsvm_ovr                                       165              0
# linearsvm_ovr.decision_thresholds_tuned             165              0
# lasso_multiclass                                    165              0
# lasso_multiclass.decision_thresholds_tuned          165              0
# rf_multiclass                                       165              0
# rf_multiclass.decision_thresholds_tuned             165              0
# xgboost                                             165              0
# xgboost.decision_thresholds_tuned                   165              0
#
#                                             sample_size including abstentions  \
# lasso_cv                                                                  165
# lasso_cv.decision_thresholds_tuned                                        165
# ridge_cv                                                                  165
# ridge_cv.decision_thresholds_tuned                                        165
# elasticnet_cv                                                             165
# elasticnet_cv.decision_thresholds_tuned                                   165
# linearsvm_ovr                                                             165
# linearsvm_ovr.decision_thresholds_tuned                                   165
# lasso_multiclass                                                          165
# lasso_multiclass.decision_thresholds_tuned                                165
# rf_multiclass                                                             165
# rf_multiclass.decision_thresholds_tuned                                   165
# xgboost                                                                   165
# xgboost.decision_thresholds_tuned                                         165
#
#                                             abstention_rate  missing_classes
# lasso_cv                                                0.0            False
# lasso_cv.decision_thresholds_tuned                      0.0            False
# ridge_cv                                                0.0            False
# ridge_cv.decision_thresholds_tuned                      0.0             True
# elasticnet_cv                                           0.0            False
# elasticnet_cv.decision_thresholds_tuned                 0.0            False
# linearsvm_ovr                                           0.0            False
# linearsvm_ovr.decision_thresholds_tuned                 0.0            False
# lasso_multiclass                                        0.0            False
# lasso_multiclass.decision_thresholds_tuned              0.0            False
# rf_multiclass                                           0.0            False
# rf_multiclass.decision_thresholds_tuned                 0.0            False
# xgboost                                                 0.0            False
# xgboost.decision_thresholds_tuned                       0.0            False
# /users/maximz/code/boyd-immune-repertoire-classification/out/repertoire_stats/TCR/sex_healthy_only/train_smaller_model.compare_model_scores.test_set_performance.tsv
