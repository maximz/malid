# %% [markdown]
# # Analyze repertoire stats model performance on validation set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from typing import Union

# %matplotlib inline
import seaborn as sns
import genetools
from IPython.display import display, Markdown

# %%
from malid import config, helpers, logger
import crosseval
from malid.trained_model_wrappers import RepertoireClassifier

# %% [markdown]
# # Analyze

# %%
for gene_locus in config.gene_loci_used:
    for target_obs_col in config.classification_targets:
        try:
            target_obs_col.confirm_compatibility_with_gene_locus(gene_locus)
            target_obs_col.confirm_compatibility_with_cross_validation_split_strategy(
                config.cross_validation_split_strategy
            )
        except Exception as err:
            # Skip invalid combinations
            logger.warning(f"{err}. Skipping.")
            continue

        models_base_dir = RepertoireClassifier._get_model_base_dir(
            gene_locus=gene_locus,
            target_obs_column=target_obs_col,
            sample_weight_strategy=config.sample_weight_strategy,
        )  # should already exist

        output_base_dir = RepertoireClassifier._get_output_base_dir(
            gene_locus=gene_locus,
            target_obs_column=target_obs_col,
            sample_weight_strategy=config.sample_weight_strategy,
        )  # might not yet exist
        output_base_dir.mkdir(parents=True, exist_ok=True)  # create if needed

        model_output_prefix = models_base_dir / "train_smaller_model"
        results_output_prefix = output_base_dir / "train_smaller_model"

        try:
            logger.info(
                f"{gene_locus}, {target_obs_col} from {model_output_prefix} to {results_output_prefix}"
            )

            ## Load and summarize
            experiment_set = crosseval.ExperimentSet.load_from_disk(
                output_prefix=model_output_prefix
            )

            # Remove global fold (we trained global fold model, but now get evaluation scores on cross-validation folds only)
            # TODO: make kdict support: del self.model_outputs[:, fold_id]
            for key in experiment_set.model_outputs[:, -1].keys():
                logger.debug(f"Removing {key} (global fold)")
                del experiment_set.model_outputs[key]

            experiment_set_global_performance = experiment_set.summarize()
            experiment_set_global_performance.export_all_models(
                func_generate_classification_report_fname=lambda model_name: f"{results_output_prefix}.classification_report.{model_name}.txt",
                func_generate_confusion_matrix_fname=lambda model_name: f"{results_output_prefix}.confusion_matrix.{model_name}.png",
                dpi=72,
            )
            combined_stats = (
                experiment_set_global_performance.get_model_comparison_stats(sort=True)
            )
            combined_stats.to_csv(
                f"{results_output_prefix}.compare_model_scores.tsv",
                sep="\t",
            )
            display(
                Markdown(
                    f"## {gene_locus}, {target_obs_col} from {model_output_prefix} to {results_output_prefix}"
                )
            )
            display(combined_stats)

            ## Review binary misclassifications: Binary prediction vs ground truth
            # For binary case, make new confusion matrix of actual disease label (y) vs predicted y_binary
            # (But this changes global score metrics)
            if (
                target_obs_col.value.is_target_binary_for_repertoire_composition_classifier
            ):
                # this is a binary healthy/sick classifier
                # re-summarize with different ground truth label
                experiment_set.summarize(
                    global_evaluation_column_name=target_obs_col.value.confusion_matrix_expanded_column_name
                ).export_all_models(
                    func_generate_classification_report_fname=lambda model_name: f"{results_output_prefix}.classification_report.{model_name}.binary_vs_ground_truth.txt",
                    func_generate_confusion_matrix_fname=lambda model_name: f"{results_output_prefix}.confusion_matrix.{model_name}.binary_vs_ground_truth.png",
                    confusion_matrix_pred_label="Predicted binary label",
                    dpi=72,
                )

            ## also create the “coefficient variability” plot, over all the CV folds
            for (
                model_name,
                model_global_performance,
            ) in experiment_set_global_performance.model_global_performances.items():
                # get feature importances for each fold
                feature_importances: Union[
                    pd.DataFrame, None
                ] = model_global_performance.feature_importances

                if feature_importances is not None:
                    # feature importances are available for this model
                    fig = plt.figure(figsize=(9, 9))
                    sns.boxplot(data=feature_importances.abs(), orient="h")
                    plt.title(
                        f"Feature importance (absolute value) variability: {model_name}"
                    )
                    plt.tight_layout()
                    genetools.plots.savefig(
                        fig,
                        f"{results_output_prefix}.feature_importances.{model_name}.png",
                        dpi=72,
                    )
                    plt.close(fig)

        except Exception as err:
            logger.exception(f"{gene_locus}, {target_obs_col} failed with error: {err}")
# Out:
# {"message": "GeneLocus.BCR, TargetObsColumnEnum.disease from /home/maxim/code/immune-repertoire-classification/data/data_v_20231027/in_house_peak_disease_timepoints/repertoire_stats/BCR/disease/train_smaller_model to /home/maxim/code/immune-repertoire-classification/out/in_house_peak_disease_timepoints/repertoire_stats/BCR/disease/train_smaller_model", "time": "2023-11-04T01:56:10.061205"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.672589"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.717026"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.741446"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.753578"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.766884"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.790708"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.814702"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.826922"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.840173"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.864502"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.888318"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:19.900710"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.214594"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.239465"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.263599"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.275928"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.289634"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.313601"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.337222"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.349448"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.362823"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.386788"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.410348"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:20.422432"}
# ## GeneLocus.BCR, TargetObsColumnEnum.disease from /home/maxim/code/immune-repertoire-classification/data/data_v_20231027/in_house_peak_disease_timepoints/repertoire_stats/BCR/disease/train_smaller_model to /home/maxim/code/immune-repertoire-classification/out/in_house_peak_disease_timepoints/repertoire_stats/BCR/disease/train_smaller_model
#                                                    ROC-AUC (weighted OvO) per fold  \
# elasticnet_cv0.25                                     0.929 +/- 0.003 (in 3 folds)
# elasticnet_cv                                         0.929 +/- 0.003 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                     0.929 +/- 0.003 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax                 0.929 +/- 0.003 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax                 0.929 +/- 0.001 (in 3 folds)
# elasticnet_cv0.75                                     0.928 +/- 0.001 (in 3 folds)
# lasso_cv                                              0.927 +/- 0.002 (in 3 folds)
# lasso_sklearn_with_lambdamax                          0.927 +/- 0.002 (in 3 folds)
# ridge_sklearn_with_lambdamax                          0.926 +/- 0.002 (in 3 folds)
# ridge_cv                                              0.926 +/- 0.002 (in 3 folds)
# elasticnet_cv_lambda1se                               0.926 +/- 0.001 (in 3 folds)
# elasticnet_cv0.25_lambda1se                           0.925 +/- 0.003 (in 3 folds)
# ridge_cv_lambda1se                                    0.925 +/- 0.002 (in 3 folds)
# elasticnet_cv0.75_lambda1se                           0.924 +/- 0.001 (in 3 folds)
# lasso_cv_lambda1se                                    0.919 +/- 0.007 (in 3 folds)
# linearsvm_ovr                                         0.913 +/- 0.008 (in 3 folds)
# xgboost                                               0.911 +/- 0.008 (in 3 folds)
# logisticregression_unregularized                      0.903 +/- 0.008 (in 3 folds)
# rf_multiclass                                         0.902 +/- 0.012 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy             0.771 +/- 0.012 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...    0.770 +/- 0.012 (in 3 folds)
# dummy_stratified                                      0.506 +/- 0.012 (in 3 folds)
# dummy_most_frequent                                   0.500 +/- 0.000 (in 3 folds)
#
#                                                     ROC-AUC (macro OvO) per fold  \
# elasticnet_cv0.25                                   0.935 +/- 0.004 (in 3 folds)
# elasticnet_cv                                       0.935 +/- 0.004 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                   0.935 +/- 0.004 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax               0.935 +/- 0.004 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax               0.936 +/- 0.002 (in 3 folds)
# elasticnet_cv0.75                                   0.936 +/- 0.002 (in 3 folds)
# lasso_cv                                            0.934 +/- 0.001 (in 3 folds)
# lasso_sklearn_with_lambdamax                        0.934 +/- 0.002 (in 3 folds)
# ridge_sklearn_with_lambdamax                        0.934 +/- 0.004 (in 3 folds)
# ridge_cv                                            0.934 +/- 0.004 (in 3 folds)
# elasticnet_cv_lambda1se                             0.934 +/- 0.005 (in 3 folds)
# elasticnet_cv0.25_lambda1se                         0.933 +/- 0.006 (in 3 folds)
# ridge_cv_lambda1se                                  0.933 +/- 0.004 (in 3 folds)
# elasticnet_cv0.75_lambda1se                         0.933 +/- 0.004 (in 3 folds)
# lasso_cv_lambda1se                                  0.929 +/- 0.002 (in 3 folds)
# linearsvm_ovr                                       0.918 +/- 0.008 (in 3 folds)
# xgboost                                             0.917 +/- 0.004 (in 3 folds)
# logisticregression_unregularized                    0.909 +/- 0.010 (in 3 folds)
# rf_multiclass                                       0.910 +/- 0.008 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy           0.794 +/- 0.011 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...  0.793 +/- 0.012 (in 3 folds)
# dummy_stratified                                    0.504 +/- 0.010 (in 3 folds)
# dummy_most_frequent                                 0.500 +/- 0.000 (in 3 folds)
#
#                                                    au-PRC (weighted OvO) per fold  \
# elasticnet_cv0.25                                    0.930 +/- 0.006 (in 3 folds)
# elasticnet_cv                                        0.930 +/- 0.006 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                    0.930 +/- 0.005 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax                0.930 +/- 0.007 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax                0.931 +/- 0.004 (in 3 folds)
# elasticnet_cv0.75                                    0.930 +/- 0.004 (in 3 folds)
# lasso_cv                                             0.927 +/- 0.004 (in 3 folds)
# lasso_sklearn_with_lambdamax                         0.928 +/- 0.004 (in 3 folds)
# ridge_sklearn_with_lambdamax                         0.929 +/- 0.006 (in 3 folds)
# ridge_cv                                             0.929 +/- 0.006 (in 3 folds)
# elasticnet_cv_lambda1se                              0.929 +/- 0.006 (in 3 folds)
# elasticnet_cv0.25_lambda1se                          0.928 +/- 0.006 (in 3 folds)
# ridge_cv_lambda1se                                   0.928 +/- 0.007 (in 3 folds)
# elasticnet_cv0.75_lambda1se                          0.927 +/- 0.005 (in 3 folds)
# lasso_cv_lambda1se                                   0.922 +/- 0.005 (in 3 folds)
# linearsvm_ovr                                        0.909 +/- 0.012 (in 3 folds)
# xgboost                                              0.913 +/- 0.007 (in 3 folds)
# logisticregression_unregularized                     0.903 +/- 0.009 (in 3 folds)
# rf_multiclass                                        0.909 +/- 0.007 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy            0.821 +/- 0.017 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...   0.820 +/- 0.017 (in 3 folds)
# dummy_stratified                                     0.510 +/- 0.006 (in 3 folds)
# dummy_most_frequent                                  0.500 +/- 0.000 (in 3 folds)
#
#                                                      au-PRC (macro OvO) per fold  \
# elasticnet_cv0.25                                   0.938 +/- 0.009 (in 3 folds)
# elasticnet_cv                                       0.938 +/- 0.007 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                   0.938 +/- 0.007 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax               0.938 +/- 0.009 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax               0.939 +/- 0.006 (in 3 folds)
# elasticnet_cv0.75                                   0.938 +/- 0.006 (in 3 folds)
# lasso_cv                                            0.935 +/- 0.005 (in 3 folds)
# lasso_sklearn_with_lambdamax                        0.936 +/- 0.005 (in 3 folds)
# ridge_sklearn_with_lambdamax                        0.936 +/- 0.010 (in 3 folds)
# ridge_cv                                            0.937 +/- 0.010 (in 3 folds)
# elasticnet_cv_lambda1se                             0.938 +/- 0.009 (in 3 folds)
# elasticnet_cv0.25_lambda1se                         0.937 +/- 0.009 (in 3 folds)
# ridge_cv_lambda1se                                  0.936 +/- 0.011 (in 3 folds)
# elasticnet_cv0.75_lambda1se                         0.936 +/- 0.009 (in 3 folds)
# lasso_cv_lambda1se                                  0.933 +/- 0.006 (in 3 folds)
# linearsvm_ovr                                       0.917 +/- 0.013 (in 3 folds)
# xgboost                                             0.921 +/- 0.003 (in 3 folds)
# logisticregression_unregularized                    0.911 +/- 0.011 (in 3 folds)
# rf_multiclass                                       0.917 +/- 0.005 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy           0.833 +/- 0.016 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...  0.831 +/- 0.017 (in 3 folds)
# dummy_stratified                                    0.509 +/- 0.005 (in 3 folds)
# dummy_most_frequent                                 0.500 +/- 0.000 (in 3 folds)
#
#                                                                Accuracy per fold  \
# elasticnet_cv0.25                                   0.747 +/- 0.051 (in 3 folds)
# elasticnet_cv                                       0.739 +/- 0.046 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                   0.739 +/- 0.046 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax               0.747 +/- 0.051 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax               0.739 +/- 0.049 (in 3 folds)
# elasticnet_cv0.75                                   0.739 +/- 0.049 (in 3 folds)
# lasso_cv                                            0.720 +/- 0.035 (in 3 folds)
# lasso_sklearn_with_lambdamax                        0.722 +/- 0.031 (in 3 folds)
# ridge_sklearn_with_lambdamax                        0.744 +/- 0.036 (in 3 folds)
# ridge_cv                                            0.744 +/- 0.036 (in 3 folds)
# elasticnet_cv_lambda1se                             0.727 +/- 0.025 (in 3 folds)
# elasticnet_cv0.25_lambda1se                         0.732 +/- 0.011 (in 3 folds)
# ridge_cv_lambda1se                                  0.739 +/- 0.035 (in 3 folds)
# elasticnet_cv0.75_lambda1se                         0.710 +/- 0.028 (in 3 folds)
# lasso_cv_lambda1se                                  0.703 +/- 0.036 (in 3 folds)
# linearsvm_ovr                                       0.739 +/- 0.057 (in 3 folds)
# xgboost                                             0.683 +/- 0.006 (in 3 folds)
# logisticregression_unregularized                    0.681 +/- 0.019 (in 3 folds)
# rf_multiclass                                       0.661 +/- 0.037 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy           0.459 +/- 0.024 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...  0.459 +/- 0.024 (in 3 folds)
# dummy_stratified                                    0.217 +/- 0.022 (in 3 folds)
# dummy_most_frequent                                 0.366 +/- 0.003 (in 3 folds)
#
#                                                                     MCC per fold  \
# elasticnet_cv0.25                                   0.678 +/- 0.062 (in 3 folds)
# elasticnet_cv                                       0.669 +/- 0.056 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                   0.669 +/- 0.056 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax               0.678 +/- 0.062 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax               0.670 +/- 0.059 (in 3 folds)
# elasticnet_cv0.75                                   0.670 +/- 0.059 (in 3 folds)
# lasso_cv                                            0.645 +/- 0.042 (in 3 folds)
# lasso_sklearn_with_lambdamax                        0.648 +/- 0.037 (in 3 folds)
# ridge_sklearn_with_lambdamax                        0.676 +/- 0.045 (in 3 folds)
# ridge_cv                                            0.676 +/- 0.045 (in 3 folds)
# elasticnet_cv_lambda1se                             0.654 +/- 0.032 (in 3 folds)
# elasticnet_cv0.25_lambda1se                         0.660 +/- 0.015 (in 3 folds)
# ridge_cv_lambda1se                                  0.670 +/- 0.043 (in 3 folds)
# elasticnet_cv0.75_lambda1se                         0.634 +/- 0.033 (in 3 folds)
# lasso_cv_lambda1se                                  0.625 +/- 0.043 (in 3 folds)
# linearsvm_ovr                                       0.666 +/- 0.074 (in 3 folds)
# xgboost                                             0.590 +/- 0.007 (in 3 folds)
# logisticregression_unregularized                    0.593 +/- 0.019 (in 3 folds)
# rf_multiclass                                       0.556 +/- 0.052 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy           0.415 +/- 0.032 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...  0.415 +/- 0.032 (in 3 folds)
# dummy_stratified                                    0.016 +/- 0.029 (in 3 folds)
# dummy_most_frequent                                 0.000 +/- 0.000 (in 3 folds)
#
#                                                    Accuracy global MCC global  \
# elasticnet_cv0.25                                            0.746      0.677
# elasticnet_cv                                                0.739      0.668
# elasticnet_sklearn_with_lambdamax                            0.739      0.668
# elasticnet0.25_sklearn_with_lambdamax                        0.746      0.677
# elasticnet0.75_sklearn_with_lambdamax                        0.739      0.669
# elasticnet_cv0.75                                            0.739      0.669
# lasso_cv                                                     0.720      0.645
# lasso_sklearn_with_lambdamax                                 0.722      0.648
# ridge_sklearn_with_lambdamax                                 0.744      0.676
# ridge_cv                                                     0.744      0.676
# elasticnet_cv_lambda1se                                      0.727      0.654
# elasticnet_cv0.25_lambda1se                                  0.732      0.660
# ridge_cv_lambda1se                                           0.739      0.670
# elasticnet_cv0.75_lambda1se                                  0.710      0.634
# lasso_cv_lambda1se                                           0.702      0.624
# linearsvm_ovr                                                0.739      0.667
# xgboost                                                      0.683      0.589
# logisticregression_unregularized                             0.680      0.592
# rf_multiclass                                                0.661      0.556
# elasticnet_cv_each_disease_versus_healthy                    0.459      0.413
# elasticnet_each_disease_versus_healthy_sklearn_...           0.459      0.413
# dummy_stratified                                             0.217      0.016
# dummy_most_frequent                                          0.366      0.000
#
#                                                     sample_size  \
# elasticnet_cv0.25                                           410
# elasticnet_cv                                               410
# elasticnet_sklearn_with_lambdamax                           410
# elasticnet0.25_sklearn_with_lambdamax                       410
# elasticnet0.75_sklearn_with_lambdamax                       410
# elasticnet_cv0.75                                           410
# lasso_cv                                                    410
# lasso_sklearn_with_lambdamax                                410
# ridge_sklearn_with_lambdamax                                410
# ridge_cv                                                    410
# elasticnet_cv_lambda1se                                     410
# elasticnet_cv0.25_lambda1se                                 410
# ridge_cv_lambda1se                                          410
# elasticnet_cv0.75_lambda1se                                 410
# lasso_cv_lambda1se                                          410
# linearsvm_ovr                                               410
# xgboost                                                     410
# logisticregression_unregularized                            410
# rf_multiclass                                               410
# elasticnet_cv_each_disease_versus_healthy                   410
# elasticnet_each_disease_versus_healthy_sklearn_...          410
# dummy_stratified                                            410
# dummy_most_frequent                                         410
#
#                                                     n_abstentions  \
# elasticnet_cv0.25                                               0
# elasticnet_cv                                                   0
# elasticnet_sklearn_with_lambdamax                               0
# elasticnet0.25_sklearn_with_lambdamax                           0
# elasticnet0.75_sklearn_with_lambdamax                           0
# elasticnet_cv0.75                                               0
# lasso_cv                                                        0
# lasso_sklearn_with_lambdamax                                    0
# ridge_sklearn_with_lambdamax                                    0
# ridge_cv                                                        0
# elasticnet_cv_lambda1se                                         0
# elasticnet_cv0.25_lambda1se                                     0
# ridge_cv_lambda1se                                              0
# elasticnet_cv0.75_lambda1se                                     0
# lasso_cv_lambda1se                                              0
# linearsvm_ovr                                                   0
# xgboost                                                         0
# logisticregression_unregularized                                0
# rf_multiclass                                                   0
# elasticnet_cv_each_disease_versus_healthy                       0
# elasticnet_each_disease_versus_healthy_sklearn_...              0
# dummy_stratified                                                0
# dummy_most_frequent                                             0
#
#                                                     sample_size including abstentions  \
# elasticnet_cv0.25                                                                 410
# elasticnet_cv                                                                     410
# elasticnet_sklearn_with_lambdamax                                                 410
# elasticnet0.25_sklearn_with_lambdamax                                             410
# elasticnet0.75_sklearn_with_lambdamax                                             410
# elasticnet_cv0.75                                                                 410
# lasso_cv                                                                          410
# lasso_sklearn_with_lambdamax                                                      410
# ridge_sklearn_with_lambdamax                                                      410
# ridge_cv                                                                          410
# elasticnet_cv_lambda1se                                                           410
# elasticnet_cv0.25_lambda1se                                                       410
# ridge_cv_lambda1se                                                                410
# elasticnet_cv0.75_lambda1se                                                       410
# lasso_cv_lambda1se                                                                410
# linearsvm_ovr                                                                     410
# xgboost                                                                           410
# logisticregression_unregularized                                                  410
# rf_multiclass                                                                     410
# elasticnet_cv_each_disease_versus_healthy                                         410
# elasticnet_each_disease_versus_healthy_sklearn_...                                410
# dummy_stratified                                                                  410
# dummy_most_frequent                                                               410
#
#                                                     abstention_rate  \
# elasticnet_cv0.25                                               0.0
# elasticnet_cv                                                   0.0
# elasticnet_sklearn_with_lambdamax                               0.0
# elasticnet0.25_sklearn_with_lambdamax                           0.0
# elasticnet0.75_sklearn_with_lambdamax                           0.0
# elasticnet_cv0.75                                               0.0
# lasso_cv                                                        0.0
# lasso_sklearn_with_lambdamax                                    0.0
# ridge_sklearn_with_lambdamax                                    0.0
# ridge_cv                                                        0.0
# elasticnet_cv_lambda1se                                         0.0
# elasticnet_cv0.25_lambda1se                                     0.0
# ridge_cv_lambda1se                                              0.0
# elasticnet_cv0.75_lambda1se                                     0.0
# lasso_cv_lambda1se                                              0.0
# linearsvm_ovr                                                   0.0
# xgboost                                                         0.0
# logisticregression_unregularized                                0.0
# rf_multiclass                                                   0.0
# elasticnet_cv_each_disease_versus_healthy                       0.0
# elasticnet_each_disease_versus_healthy_sklearn_...              0.0
# dummy_stratified                                                0.0
# dummy_most_frequent                                             0.0
#
#                                                     missing_classes
# elasticnet_cv0.25                                             False
# elasticnet_cv                                                 False
# elasticnet_sklearn_with_lambdamax                             False
# elasticnet0.25_sklearn_with_lambdamax                         False
# elasticnet0.75_sklearn_with_lambdamax                         False
# elasticnet_cv0.75                                             False
# lasso_cv                                                      False
# lasso_sklearn_with_lambdamax                                  False
# ridge_sklearn_with_lambdamax                                  False
# ridge_cv                                                      False
# elasticnet_cv_lambda1se                                       False
# elasticnet_cv0.25_lambda1se                                   False
# ridge_cv_lambda1se                                            False
# elasticnet_cv0.75_lambda1se                                   False
# lasso_cv_lambda1se                                            False
# linearsvm_ovr                                                 False
# xgboost                                                       False
# logisticregression_unregularized                              False
# rf_multiclass                                                 False
# elasticnet_cv_each_disease_versus_healthy                      True
# elasticnet_each_disease_versus_healthy_sklearn_...             True
# dummy_stratified                                              False
# dummy_most_frequent                                            True
# {"message": "GeneLocus.TCR, TargetObsColumnEnum.disease from /home/maxim/code/immune-repertoire-classification/data/data_v_20231027/in_house_peak_disease_timepoints/repertoire_stats/TCR/disease/train_smaller_model to /home/maxim/code/immune-repertoire-classification/out/in_house_peak_disease_timepoints/repertoire_stats/TCR/disease/train_smaller_model", "time": "2023-11-04T01:56:24.171401"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.728914"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.814801"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.838733"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.851128"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.864616"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.889207"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.913450"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.925602"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.939011"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.963211"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.986783"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:37.998967"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.239082"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.263429"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.287179"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.299412"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.312493"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.336043"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.359249"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.371084"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.384085"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.407660"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.430668"}
# {"message": "Inserting phantom class: Healthy/Background", "time": "2023-11-04T01:56:38.442728"}
# ## GeneLocus.TCR, TargetObsColumnEnum.disease from /home/maxim/code/immune-repertoire-classification/data/data_v_20231027/in_house_peak_disease_timepoints/repertoire_stats/TCR/disease/train_smaller_model to /home/maxim/code/immune-repertoire-classification/out/in_house_peak_disease_timepoints/repertoire_stats/TCR/disease/train_smaller_model
#                                                    ROC-AUC (weighted OvO) per fold  \
# lasso_cv                                              0.941 +/- 0.014 (in 3 folds)
# lasso_sklearn_with_lambdamax                          0.941 +/- 0.014 (in 3 folds)
# elasticnet_cv0.75                                     0.941 +/- 0.014 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax                 0.941 +/- 0.014 (in 3 folds)
# elasticnet_cv_lambda1se                               0.941 +/- 0.013 (in 3 folds)
# elasticnet_cv0.25_lambda1se                           0.941 +/- 0.012 (in 3 folds)
# elasticnet_cv0.25                                     0.940 +/- 0.014 (in 3 folds)
# elasticnet_cv                                         0.940 +/- 0.014 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                     0.940 +/- 0.014 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax                 0.940 +/- 0.014 (in 3 folds)
# lasso_cv_lambda1se                                    0.940 +/- 0.013 (in 3 folds)
# elasticnet_cv0.75_lambda1se                           0.940 +/- 0.013 (in 3 folds)
# ridge_cv                                              0.938 +/- 0.010 (in 3 folds)
# ridge_cv_lambda1se                                    0.937 +/- 0.010 (in 3 folds)
# ridge_sklearn_with_lambdamax                          0.937 +/- 0.010 (in 3 folds)
# linearsvm_ovr                                         0.936 +/- 0.012 (in 3 folds)
# rf_multiclass                                         0.936 +/- 0.003 (in 3 folds)
# logisticregression_unregularized                      0.934 +/- 0.016 (in 3 folds)
# xgboost                                               0.917 +/- 0.011 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy             0.800 +/- 0.009 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...    0.800 +/- 0.009 (in 3 folds)
# dummy_most_frequent                                   0.500 +/- 0.000 (in 3 folds)
# dummy_stratified                                      0.490 +/- 0.022 (in 3 folds)
#
#                                                     ROC-AUC (macro OvO) per fold  \
# lasso_cv                                            0.942 +/- 0.017 (in 3 folds)
# lasso_sklearn_with_lambdamax                        0.942 +/- 0.017 (in 3 folds)
# elasticnet_cv0.75                                   0.941 +/- 0.017 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax               0.941 +/- 0.017 (in 3 folds)
# elasticnet_cv_lambda1se                             0.942 +/- 0.016 (in 3 folds)
# elasticnet_cv0.25_lambda1se                         0.942 +/- 0.015 (in 3 folds)
# elasticnet_cv0.25                                   0.940 +/- 0.017 (in 3 folds)
# elasticnet_cv                                       0.941 +/- 0.017 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                   0.941 +/- 0.017 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax               0.940 +/- 0.017 (in 3 folds)
# lasso_cv_lambda1se                                  0.941 +/- 0.017 (in 3 folds)
# elasticnet_cv0.75_lambda1se                         0.941 +/- 0.016 (in 3 folds)
# ridge_cv                                            0.940 +/- 0.013 (in 3 folds)
# ridge_cv_lambda1se                                  0.939 +/- 0.013 (in 3 folds)
# ridge_sklearn_with_lambdamax                        0.940 +/- 0.013 (in 3 folds)
# linearsvm_ovr                                       0.938 +/- 0.014 (in 3 folds)
# rf_multiclass                                       0.936 +/- 0.003 (in 3 folds)
# logisticregression_unregularized                    0.933 +/- 0.019 (in 3 folds)
# xgboost                                             0.914 +/- 0.015 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy           0.823 +/- 0.011 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...  0.822 +/- 0.010 (in 3 folds)
# dummy_most_frequent                                 0.500 +/- 0.000 (in 3 folds)
# dummy_stratified                                    0.491 +/- 0.018 (in 3 folds)
#
#                                                    au-PRC (weighted OvO) per fold  \
# lasso_cv                                             0.933 +/- 0.014 (in 3 folds)
# lasso_sklearn_with_lambdamax                         0.933 +/- 0.014 (in 3 folds)
# elasticnet_cv0.75                                    0.933 +/- 0.014 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax                0.933 +/- 0.014 (in 3 folds)
# elasticnet_cv_lambda1se                              0.932 +/- 0.012 (in 3 folds)
# elasticnet_cv0.25_lambda1se                          0.933 +/- 0.011 (in 3 folds)
# elasticnet_cv0.25                                    0.933 +/- 0.014 (in 3 folds)
# elasticnet_cv                                        0.932 +/- 0.013 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                    0.932 +/- 0.013 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax                0.933 +/- 0.014 (in 3 folds)
# lasso_cv_lambda1se                                   0.930 +/- 0.015 (in 3 folds)
# elasticnet_cv0.75_lambda1se                          0.931 +/- 0.013 (in 3 folds)
# ridge_cv                                             0.928 +/- 0.012 (in 3 folds)
# ridge_cv_lambda1se                                   0.927 +/- 0.012 (in 3 folds)
# ridge_sklearn_with_lambdamax                         0.928 +/- 0.012 (in 3 folds)
# linearsvm_ovr                                        0.928 +/- 0.012 (in 3 folds)
# rf_multiclass                                        0.924 +/- 0.006 (in 3 folds)
# logisticregression_unregularized                     0.926 +/- 0.017 (in 3 folds)
# xgboost                                              0.911 +/- 0.006 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy            0.848 +/- 0.011 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...   0.848 +/- 0.011 (in 3 folds)
# dummy_most_frequent                                  0.500 +/- 0.000 (in 3 folds)
# dummy_stratified                                     0.504 +/- 0.010 (in 3 folds)
#
#                                                      au-PRC (macro OvO) per fold  \
# lasso_cv                                            0.935 +/- 0.016 (in 3 folds)
# lasso_sklearn_with_lambdamax                        0.935 +/- 0.016 (in 3 folds)
# elasticnet_cv0.75                                   0.935 +/- 0.016 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax               0.935 +/- 0.016 (in 3 folds)
# elasticnet_cv_lambda1se                             0.936 +/- 0.013 (in 3 folds)
# elasticnet_cv0.25_lambda1se                         0.937 +/- 0.012 (in 3 folds)
# elasticnet_cv0.25                                   0.935 +/- 0.016 (in 3 folds)
# elasticnet_cv                                       0.935 +/- 0.015 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                   0.935 +/- 0.015 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax               0.936 +/- 0.015 (in 3 folds)
# lasso_cv_lambda1se                                  0.933 +/- 0.017 (in 3 folds)
# elasticnet_cv0.75_lambda1se                         0.934 +/- 0.014 (in 3 folds)
# ridge_cv                                            0.933 +/- 0.012 (in 3 folds)
# ridge_cv_lambda1se                                  0.933 +/- 0.012 (in 3 folds)
# ridge_sklearn_with_lambdamax                        0.933 +/- 0.012 (in 3 folds)
# linearsvm_ovr                                       0.932 +/- 0.012 (in 3 folds)
# rf_multiclass                                       0.926 +/- 0.007 (in 3 folds)
# logisticregression_unregularized                    0.927 +/- 0.021 (in 3 folds)
# xgboost                                             0.910 +/- 0.008 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy           0.858 +/- 0.012 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...  0.857 +/- 0.013 (in 3 folds)
# dummy_most_frequent                                 0.500 +/- 0.000 (in 3 folds)
# dummy_stratified                                    0.504 +/- 0.008 (in 3 folds)
#
#                                                                Accuracy per fold  \
# lasso_cv                                            0.733 +/- 0.036 (in 3 folds)
# lasso_sklearn_with_lambdamax                        0.733 +/- 0.036 (in 3 folds)
# elasticnet_cv0.75                                   0.733 +/- 0.039 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax               0.733 +/- 0.039 (in 3 folds)
# elasticnet_cv_lambda1se                             0.722 +/- 0.019 (in 3 folds)
# elasticnet_cv0.25_lambda1se                         0.717 +/- 0.019 (in 3 folds)
# elasticnet_cv0.25                                   0.733 +/- 0.039 (in 3 folds)
# elasticnet_cv                                       0.736 +/- 0.039 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                   0.736 +/- 0.039 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax               0.736 +/- 0.039 (in 3 folds)
# lasso_cv_lambda1se                                  0.728 +/- 0.016 (in 3 folds)
# elasticnet_cv0.75_lambda1se                         0.722 +/- 0.019 (in 3 folds)
# ridge_cv                                            0.706 +/- 0.014 (in 3 folds)
# ridge_cv_lambda1se                                  0.700 +/- 0.013 (in 3 folds)
# ridge_sklearn_with_lambdamax                        0.706 +/- 0.014 (in 3 folds)
# linearsvm_ovr                                       0.730 +/- 0.011 (in 3 folds)
# rf_multiclass                                       0.725 +/- 0.019 (in 3 folds)
# logisticregression_unregularized                    0.739 +/- 0.057 (in 3 folds)
# xgboost                                             0.689 +/- 0.018 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy           0.434 +/- 0.048 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...  0.434 +/- 0.048 (in 3 folds)
# dummy_most_frequent                                 0.360 +/- 0.004 (in 3 folds)
# dummy_stratified                                    0.193 +/- 0.049 (in 3 folds)
#
#                                                                      MCC per fold  \
# lasso_cv                                             0.667 +/- 0.053 (in 3 folds)
# lasso_sklearn_with_lambdamax                         0.667 +/- 0.053 (in 3 folds)
# elasticnet_cv0.75                                    0.665 +/- 0.059 (in 3 folds)
# elasticnet0.75_sklearn_with_lambdamax                0.665 +/- 0.059 (in 3 folds)
# elasticnet_cv_lambda1se                              0.654 +/- 0.033 (in 3 folds)
# elasticnet_cv0.25_lambda1se                          0.648 +/- 0.036 (in 3 folds)
# elasticnet_cv0.25                                    0.666 +/- 0.059 (in 3 folds)
# elasticnet_cv                                        0.669 +/- 0.059 (in 3 folds)
# elasticnet_sklearn_with_lambdamax                    0.669 +/- 0.059 (in 3 folds)
# elasticnet0.25_sklearn_with_lambdamax                0.669 +/- 0.059 (in 3 folds)
# lasso_cv_lambda1se                                   0.662 +/- 0.029 (in 3 folds)
# elasticnet_cv0.75_lambda1se                          0.655 +/- 0.035 (in 3 folds)
# ridge_cv                                             0.643 +/- 0.026 (in 3 folds)
# ridge_cv_lambda1se                                   0.638 +/- 0.021 (in 3 folds)
# ridge_sklearn_with_lambdamax                         0.643 +/- 0.026 (in 3 folds)
# linearsvm_ovr                                        0.663 +/- 0.021 (in 3 folds)
# rf_multiclass                                        0.643 +/- 0.027 (in 3 folds)
# logisticregression_unregularized                     0.669 +/- 0.083 (in 3 folds)
# xgboost                                              0.604 +/- 0.022 (in 3 folds)
# elasticnet_cv_each_disease_versus_healthy            0.379 +/- 0.060 (in 3 folds)
# elasticnet_each_disease_versus_healthy_sklearn_...   0.379 +/- 0.060 (in 3 folds)
# dummy_most_frequent                                  0.000 +/- 0.000 (in 3 folds)
# dummy_stratified                                    -0.021 +/- 0.047 (in 3 folds)
#
#                                                    Accuracy global MCC global  \
# lasso_cv                                                     0.733      0.665
# lasso_sklearn_with_lambdamax                                 0.733      0.665
# elasticnet_cv0.75                                            0.733      0.663
# elasticnet0.75_sklearn_with_lambdamax                        0.733      0.663
# elasticnet_cv_lambda1se                                      0.722      0.652
# elasticnet_cv0.25_lambda1se                                  0.717      0.646
# elasticnet_cv0.25                                            0.733      0.664
# elasticnet_cv                                                0.736      0.667
# elasticnet_sklearn_with_lambdamax                            0.736      0.667
# elasticnet0.25_sklearn_with_lambdamax                        0.736      0.667
# lasso_cv_lambda1se                                           0.728      0.660
# elasticnet_cv0.75_lambda1se                                  0.722      0.652
# ridge_cv                                                     0.706      0.641
# ridge_cv_lambda1se                                           0.700      0.636
# ridge_sklearn_with_lambdamax                                 0.706      0.641
# linearsvm_ovr                                                0.730      0.661
# rf_multiclass                                                0.725      0.643
# logisticregression_unregularized                             0.738      0.667
# xgboost                                                      0.689      0.601
# elasticnet_cv_each_disease_versus_healthy                    0.433      0.377
# elasticnet_each_disease_versus_healthy_sklearn_...           0.433      0.377
# dummy_most_frequent                                          0.360      0.000
# dummy_stratified                                             0.193     -0.021
#
#                                                     sample_size  \
# lasso_cv                                                    367
# lasso_sklearn_with_lambdamax                                367
# elasticnet_cv0.75                                           367
# elasticnet0.75_sklearn_with_lambdamax                       367
# elasticnet_cv_lambda1se                                     367
# elasticnet_cv0.25_lambda1se                                 367
# elasticnet_cv0.25                                           367
# elasticnet_cv                                               367
# elasticnet_sklearn_with_lambdamax                           367
# elasticnet0.25_sklearn_with_lambdamax                       367
# lasso_cv_lambda1se                                          367
# elasticnet_cv0.75_lambda1se                                 367
# ridge_cv                                                    367
# ridge_cv_lambda1se                                          367
# ridge_sklearn_with_lambdamax                                367
# linearsvm_ovr                                               367
# rf_multiclass                                               367
# logisticregression_unregularized                            367
# xgboost                                                     367
# elasticnet_cv_each_disease_versus_healthy                   367
# elasticnet_each_disease_versus_healthy_sklearn_...          367
# dummy_most_frequent                                         367
# dummy_stratified                                            367
#
#                                                     n_abstentions  \
# lasso_cv                                                        0
# lasso_sklearn_with_lambdamax                                    0
# elasticnet_cv0.75                                               0
# elasticnet0.75_sklearn_with_lambdamax                           0
# elasticnet_cv_lambda1se                                         0
# elasticnet_cv0.25_lambda1se                                     0
# elasticnet_cv0.25                                               0
# elasticnet_cv                                                   0
# elasticnet_sklearn_with_lambdamax                               0
# elasticnet0.25_sklearn_with_lambdamax                           0
# lasso_cv_lambda1se                                              0
# elasticnet_cv0.75_lambda1se                                     0
# ridge_cv                                                        0
# ridge_cv_lambda1se                                              0
# ridge_sklearn_with_lambdamax                                    0
# linearsvm_ovr                                                   0
# rf_multiclass                                                   0
# logisticregression_unregularized                                0
# xgboost                                                         0
# elasticnet_cv_each_disease_versus_healthy                       0
# elasticnet_each_disease_versus_healthy_sklearn_...              0
# dummy_most_frequent                                             0
# dummy_stratified                                                0
#
#                                                     sample_size including abstentions  \
# lasso_cv                                                                          367
# lasso_sklearn_with_lambdamax                                                      367
# elasticnet_cv0.75                                                                 367
# elasticnet0.75_sklearn_with_lambdamax                                             367
# elasticnet_cv_lambda1se                                                           367
# elasticnet_cv0.25_lambda1se                                                       367
# elasticnet_cv0.25                                                                 367
# elasticnet_cv                                                                     367
# elasticnet_sklearn_with_lambdamax                                                 367
# elasticnet0.25_sklearn_with_lambdamax                                             367
# lasso_cv_lambda1se                                                                367
# elasticnet_cv0.75_lambda1se                                                       367
# ridge_cv                                                                          367
# ridge_cv_lambda1se                                                                367
# ridge_sklearn_with_lambdamax                                                      367
# linearsvm_ovr                                                                     367
# rf_multiclass                                                                     367
# logisticregression_unregularized                                                  367
# xgboost                                                                           367
# elasticnet_cv_each_disease_versus_healthy                                         367
# elasticnet_each_disease_versus_healthy_sklearn_...                                367
# dummy_most_frequent                                                               367
# dummy_stratified                                                                  367
#
#                                                     abstention_rate  \
# lasso_cv                                                        0.0
# lasso_sklearn_with_lambdamax                                    0.0
# elasticnet_cv0.75                                               0.0
# elasticnet0.75_sklearn_with_lambdamax                           0.0
# elasticnet_cv_lambda1se                                         0.0
# elasticnet_cv0.25_lambda1se                                     0.0
# elasticnet_cv0.25                                               0.0
# elasticnet_cv                                                   0.0
# elasticnet_sklearn_with_lambdamax                               0.0
# elasticnet0.25_sklearn_with_lambdamax                           0.0
# lasso_cv_lambda1se                                              0.0
# elasticnet_cv0.75_lambda1se                                     0.0
# ridge_cv                                                        0.0
# ridge_cv_lambda1se                                              0.0
# ridge_sklearn_with_lambdamax                                    0.0
# linearsvm_ovr                                                   0.0
# rf_multiclass                                                   0.0
# logisticregression_unregularized                                0.0
# xgboost                                                         0.0
# elasticnet_cv_each_disease_versus_healthy                       0.0
# elasticnet_each_disease_versus_healthy_sklearn_...              0.0
# dummy_most_frequent                                             0.0
# dummy_stratified                                                0.0
#
#                                                     missing_classes
# lasso_cv                                                      False
# lasso_sklearn_with_lambdamax                                  False
# elasticnet_cv0.75                                             False
# elasticnet0.75_sklearn_with_lambdamax                         False
# elasticnet_cv_lambda1se                                       False
# elasticnet_cv0.25_lambda1se                                   False
# elasticnet_cv0.25                                             False
# elasticnet_cv                                                 False
# elasticnet_sklearn_with_lambdamax                             False
# elasticnet0.25_sklearn_with_lambdamax                         False
# lasso_cv_lambda1se                                            False
# elasticnet_cv0.75_lambda1se                                   False
# ridge_cv                                                      False
# ridge_cv_lambda1se                                            False
# ridge_sklearn_with_lambdamax                                  False
# linearsvm_ovr                                                 False
# rf_multiclass                                                 False
# logisticregression_unregularized                              False
# xgboost                                                       False
# elasticnet_cv_each_disease_versus_healthy                      True
# elasticnet_each_disease_versus_healthy_sklearn_...             True
# dummy_most_frequent                                            True
# dummy_stratified                                              False
