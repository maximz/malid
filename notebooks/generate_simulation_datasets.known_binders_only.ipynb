# %% [markdown]
# 1. Take one real Covid19 patient. Extract any sequences that are known binders (+/- 15% mutation allowed)
# 2. Take one real healthy person. Eliminate any sequences that are known binders to Covid (+/- 15% mutation)
# 3. Mix 1 and 2 at desired signal to noise ratio
#
# This is BCR only.

# %%
from typing import List
import numpy as np
import pandas as pd
import anndata
import gc
import shutil

import malid.external.genetools_scanpy_helpers
from malid import io
from malid import config, helpers, logger
from malid.datamodels import (
    GeneLocus,
    TargetObsColumnEnum,
    SampleWeightStrategy,
    healthy_label,
)

from malid.trained_model_wrappers import ConvergentClusterClassifier

# %%
# we're looking at BCR only here
gene_locus = GeneLocus.BCR

# %%
# If we want to generate based on an older dataset version, we can swap it in like this:
config.paths = config.make_paths(
    embedder=config.embedder, dataset_version="20220704_filter2"
)

# %%
config.paths.simulated_data_dir
# Out:
# PosixPath('/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data')

# %%
## Get CoV-AbDab known binders
# TODO: switch to malid.interpretation provided loader

# set columnns our code expects (fold_label, fold_id, v_gene, j_gene, cdr3_aa_sequence_trim_len, cdr3_seq_aa_q_trim)
covabdab_df = pd.read_csv(
    config.paths.base_data_dir / "CoV-AbDab_310122.filtered.tsv", sep="\t"
).assign(fold_label="reference", fold_id=0)

covabdab_df = ConvergentClusterClassifier._cluster_training_set(
    df=covabdab_df,
    sequence_identity_threshold=0.95,  # very strict - in order to just prevent near-exact dupes
)

# Make cluster centroids for clusters, weighed by number of clone members (number of unique VDJ sequences)
cluster_centroids_df = ConvergentClusterClassifier._get_cluster_centroids(
    clustered_df=covabdab_df
)
# Reshape as dict
cluster_centroids_by_supergroup = (
    ConvergentClusterClassifier._wrap_cluster_centroids_as_dict_by_supergroup(
        cluster_centroids=cluster_centroids_df
    )
)

# %%
def extract_sequences_from_specimen(
    adata: anndata.AnnData,
    keep_known_binding: bool,
    known_binders_cluster_centroids_by_supergroup,
    # threshold for assigning our seqs (test seqs) to known binder clusters
    clustering_test_assignment_threshold=0.85,
) -> anndata.AnnData:
    """given a specimen anndata,
    extract known binder sequences (+/- 15% mutation) if keep_known_binding,
    or extract sequences that are not known binders (+/- 15% mutation) if not keep_known_binding."""
    test_df = adata.obs.copy()
    # group by v, j, len
    test_groups = test_df.groupby(
        ["v_gene", "j_gene", "cdr3_aa_sequence_trim_len"], observed=True
    )

    test_df[["cluster_id_within_clustering_group", "distance_to_nearest_centroid"]] = (
        test_groups["cdr3_seq_aa_q_trim"].transform(
            lambda test_sequences: ConvergentClusterClassifier.assign_sequences_to_cluster_centroids(
                test_sequences,
                known_binders_cluster_centroids_by_supergroup,
                clustering_test_assignment_threshold,
            )
        )
        # extract the series of tuples into two columns while preserving the index
        # .to_list() is an alternative here, which may be faster, and seems to guarantee index ordering but not sure?
        .apply(pd.Series)
    )

    # create a globally meaningful "resulting cluster ID" for each row of df (each input sequence from each participant):
    test_df["global_resulting_cluster_ID"] = test_df[
        [
            "v_gene",
            "j_gene",
            "cdr3_aa_sequence_trim_len",
            "cluster_id_within_clustering_group",
        ]
    ].apply(tuple, axis=1)

    # which sequences assigned to any predictive clusters?
    unmatched_seqs_bool_vector = test_df["cluster_id_within_clustering_group"].isna()
    if keep_known_binding:
        obsnames = test_df[~unmatched_seqs_bool_vector].index
    else:
        obsnames = test_df[unmatched_seqs_bool_vector].index

    return adata[obsnames]

# %%
def _sample_from_two_populations_to_achieve_mix_ratio(
    population_size_a: int, population_size_b: int, ratio: float
):
    """
    Return how many items to sample from population A and population B to achieve a desired mix ratio.
    We have two populations of size a,b, with a known target signal-to-noise ratio r
    Solve for x,y fractions of each population to sample, given ax/(ax+by) = r (and x,y > 0)
    Also we want to use as much of possible of the available datasets.
    So figure out which dataset is the limiting factor given the ratio; take as much as possible from there.
    """
    # if taking all of a, i.e. x=1, then r(ax+by)=r(a+by)=a.
    x = 1
    y = population_size_a / population_size_b * (1 - ratio) / ratio
    if y > 1:
        # this means that using all of a would require using more than 100% of b - which is impossible.
        # so b is the limiting factor. can't take all of a; let's take all of b.
        # if taking all of b, i.e. y=1, then we have (1-r)(ax+by) = (1-r)(ax+b) = b
        y = 1
        x = population_size_b / population_size_a * ratio / (1 - ratio)
    # round and return how much to sample from each population
    return int(round(x * population_size_a)), int(round(y * population_size_b))


def make_simulated_patient(
    signal_to_noise_ratio: float,
    disease_adata: anndata.AnnData,
    healthy_adata: anndata.AnnData,
) -> anndata.AnnData:
    """create a synthetic disease patient by mixing a real disease patient's known binding sequences and a real healthy donor's sequences that don't match known binders."""
    new_specimen_label = f"{disease_adata.obs['specimen_label'].iloc[0]}_{healthy_adata.obs['specimen_label'].iloc[0]}"
    new_participant_label = f"{disease_adata.obs['participant_label'].iloc[0]}_{healthy_adata.obs['participant_label'].iloc[0]}"

    def _label_anndata(adata, disease_status):
        adata = adata.copy()
        # label the seqs as disease or not
        adata.obs["is_actually_disease"] = disease_status
        # combine the participant labels and specimen labels
        adata.obs["participant_label"] = new_participant_label
        adata.obs["specimen_label"] = new_specimen_label
        return adata

    disease_part = _label_anndata(disease_adata, True)
    healthy_part = _label_anndata(healthy_adata, False)

    # Mix with signal_to_noise_ratio
    n_disease, n_healthy = _sample_from_two_populations_to_achieve_mix_ratio(
        population_size_a=disease_part.shape[0],
        population_size_b=healthy_part.shape[0],
        ratio=signal_to_noise_ratio,
    )
    if n_disease > disease_part.shape[0] or n_healthy > healthy_part.shape[0]:
        # this should not happen
        raise ValueError(
            f"Not enough healthy or disease sequences to achieve desired signal-to-noise ratio {signal_to_noise_ratio}."
        )
    effective_ratio = n_disease / (n_disease + n_healthy)
    logger.info(
        f"Combining {new_participant_label}, {new_specimen_label}: effective signal-to-noise ratio {effective_ratio} ({n_disease} disease and {n_healthy} healthy sequences); desired ratio {signal_to_noise_ratio}."
    )

    # sample and concatenate
    return anndata.concat(
        [
            disease_part[
                np.random.choice(
                    a=disease_part.obs_names, size=n_disease, replace=False
                )
            ],
            healthy_part[
                np.random.choice(
                    a=healthy_part.obs_names, size=n_healthy, replace=False
                )
            ],
        ]
    )

# %%
def validate_passes_thresholds(
    selected_seqs: anndata.AnnData,
    #     n_sequences_per_specimen_per_isotype: int,
    min_number_of_sequences_per_specimen: int,
) -> bool:
    # Sanity check that all isotypes are present:
    if set(selected_seqs.obs["isotype_supergroup"].unique()) != set(
        helpers.isotype_groups_kept[gene_locus]
    ):
        return False

    #     # Sanity check that there are enough sequences from each isotype
    #     for isotype, obs_subset in selected_seqs.obs.groupby(
    #         "isotype_supergroup", observed=True
    #     ):
    #         if obs_subset.shape[0] < n_sequences_per_specimen_per_isotype:
    #             return False

    # Sanity check that there are enough sequences from this specimen
    if selected_seqs.shape[0] < min_number_of_sequences_per_specimen:
        return False

    return True

# %%
def simulate_for_fold(
    adata_fold: anndata.AnnData,
    signal_to_noise_ratio: float,
    n_disease_specimens: int,
    n_healthy_specimens: int,
    #     n_sequences_per_specimen_per_isotype: int,
    min_number_of_sequences_per_specimen: int,
) -> anndata.AnnData:
    selected_disease_samples: List[anndata.AnnData] = []
    selected_healthy_samples: List[anndata.AnnData] = []

    already_sampled_participants = set()

    participants_and_specimens_by_disease = {
        disease: grp.values
        for disease, grp in adata_fold.obs[
            ["disease", "specimen_label", "participant_label"]
        ]
        .drop_duplicates()
        .groupby("disease")
    }

    for (
        _,
        disease_specimen_label,
        source_participant_label,
    ) in participants_and_specimens_by_disease["Covid19"]:
        if len(selected_disease_samples) == n_disease_specimens:
            # have enough
            break
        if source_participant_label in already_sampled_participants:
            # already used another specimen from this patient
            logger.warning(
                f"Skipping disease specimen {disease_specimen_label} because we already included another sample from {source_participant_label}."
            )
            continue
        # sample from a real patient
        known_binding_seqs: anndata.AnnData = extract_sequences_from_specimen(
            adata_fold[adata_fold.obs["specimen_label"] == disease_specimen_label],
            keep_known_binding=True,
            known_binders_cluster_centroids_by_supergroup=cluster_centroids_by_supergroup,
        )
        if validate_passes_thresholds(
            selected_seqs=known_binding_seqs,
            #             n_sequences_per_specimen_per_isotype=n_sequences_per_specimen_per_isotype,
            min_number_of_sequences_per_specimen=min_number_of_sequences_per_specimen,
        ):
            selected_disease_samples.append(known_binding_seqs)
            already_sampled_participants.add(source_participant_label)
            logger.info(
                f"Adding disease specimen {disease_specimen_label} from {source_participant_label}."
            )
        else:
            logger.warning(
                f"Disease specimen {disease_specimen_label} from {source_participant_label} did not pass thresholds."
            )

    for (
        _,
        healthy_specimen_label,
        source_participant_label,
    ) in participants_and_specimens_by_disease[healthy_label]:
        # need one per synthetic disease patient and one per healthy control we create
        if len(selected_healthy_samples) == n_disease_specimens + n_healthy_specimens:
            # have enough
            break
        if source_participant_label in already_sampled_participants:
            # already used another specimen from this patient
            logger.warning(
                f"Skipping healthy specimen {healthy_specimen_label} because we already included another sample from {source_participant_label}."
            )
            continue
        # sample from a real healthy donor
        known_not_binding_seqs = extract_sequences_from_specimen(
            adata_fold[adata_fold.obs["specimen_label"] == healthy_specimen_label],
            keep_known_binding=False,
            known_binders_cluster_centroids_by_supergroup=cluster_centroids_by_supergroup,
        )
        if validate_passes_thresholds(
            selected_seqs=known_not_binding_seqs,
            #             n_sequences_per_specimen_per_isotype=n_sequences_per_specimen_per_isotype,
            min_number_of_sequences_per_specimen=min_number_of_sequences_per_specimen,
        ):
            selected_healthy_samples.append(known_not_binding_seqs)
            already_sampled_participants.add(source_participant_label)
            logger.info(
                f"Adding healthy specimen {healthy_specimen_label} from {source_participant_label}."
            )
        else:
            logger.warning(
                f"Healthy specimen {healthy_specimen_label} from {source_participant_label} did not pass thresholds."
            )

    if len(selected_disease_samples) != n_disease_specimens:
        raise ValueError("Did not select enough disease specimens")
    if len(selected_healthy_samples) != n_disease_specimens + n_healthy_specimens:
        raise ValueError("Did not select enough healthy specimens")

    # make synthetic mixtures for disease patients
    returned_specimens: List[anndata.AnnData] = []
    for _ in range(n_disease_specimens):
        disease_specimen, healthy_specimen = (
            selected_disease_samples.pop(),
            selected_healthy_samples.pop(),
        )
        synthetic_specimen: anndata.AnnData = make_simulated_patient(
            signal_to_noise_ratio, disease_specimen, healthy_specimen
        )
        returned_specimens.append(synthetic_specimen)
    for _ in range(n_healthy_specimens):
        returned_specimens.append(selected_healthy_samples.pop())

    # package up as an anndata
    # undo any scaling
    final_anndata = anndata.concat(returned_specimens).raw.to_adata()
    final_anndata.obs_names_make_unique()

    # remove unused labels, if these variables are Categoricals
    final_anndata.obs["participant_label"] = (
        final_anndata.obs["participant_label"]
        .astype("category")
        .cat.remove_unused_categories()
    )
    final_anndata.obs["specimen_label"] = (
        final_anndata.obs["specimen_label"]
        .astype("category")
        .cat.remove_unused_categories()
    )

    # no need to pass old PCA info along
    del final_anndata.obsm

    return final_anndata

# %%
pca_n_comps = 10

signal_to_noise_ratios = [0.05, 0.10, 0.25]

output_dirs = {
    signal_to_noise_ratio: config.paths.simulated_data_dir
    / f"scaled_anndatas_{signal_to_noise_ratio:0.2f}"
    for signal_to_noise_ratio in signal_to_noise_ratios
}
for output_dir_anndatas in output_dirs.values():
    # Clear out and remove folder if it already exists
    if output_dir_anndatas.exists():
        if not output_dir_anndatas.is_dir():
            raise ValueError(
                f"Output directory {output_dir_anndatas} already xists but is not a directory."
            )
        shutil.rmtree(output_dir_anndatas)

    output_dir_anndatas.mkdir(parents=True, exist_ok=False)
    print(output_dir_anndatas)


for fold_id in config.cross_validation_fold_ids:
    # These transformations will be fit on train_smaller set and applied to others
    # so they start as None and then will be replaced.
    scale_transformers = {ratio: None for ratio in signal_to_noise_ratios}
    pca_transformers = {ratio: None for ratio in signal_to_noise_ratios}

    for fold_label in ["train_smaller", "validation", "test"]:
        if fold_id == -1 and fold_label == "test":
            # skip: global fold does not have a test set
            continue

        adata_fold = io.load_fold_embeddings(
            fold_id=fold_id,
            fold_label=fold_label,
            gene_locus=gene_locus,
            target_obs_column=TargetObsColumnEnum.disease,
            sample_weight_strategy=SampleWeightStrategy.ISOTYPE_USAGE,
            load_isotype_counts_per_specimen=False,
        )
        for signal_to_noise_ratio in signal_to_noise_ratios:
            # vary fraction disease specific

            # TODO: we can also pull selected_disease_samples,selected_healthy_samples out to be shared between signal_to_noise_ratios
            # (but would need to change pop())
            adata = simulate_for_fold(
                adata_fold=adata_fold,
                signal_to_noise_ratio=signal_to_noise_ratio,
                n_disease_specimens=5,
                n_healthy_specimens=5,
                # n_sequences_per_specimen_per_isotype=100, # removed because expect mostly IgG from Covid patients
                min_number_of_sequences_per_specimen=10,  # TODO: 100
            )

            # Now scale, PCA, and export the data
            # Use transformers if available (starts as None)
            (
                adata,
                scale_transformers[signal_to_noise_ratio],
            ) = malid.external.genetools_scanpy_helpers.scale_anndata(
                adata,
                scale_transformer=scale_transformers[signal_to_noise_ratio],
                inplace=True,
                set_raw=True,
            )
            (
                adata,
                pca_transformers[signal_to_noise_ratio],
            ) = malid.external.genetools_scanpy_helpers.pca_anndata(
                adata,
                pca_transformer=pca_transformers[signal_to_noise_ratio],
                n_components=pca_n_comps,
                inplace=True,
            )
            if adata.obsm["X_pca"].shape[1] != pca_n_comps:
                raise ValueError(
                    "PCA did not produce the expected number of components"
                )

            # Reduce disk space usage by removing unnecessary obs columns
            adata.obs.drop(
                columns=list(
                    set(adata.obs.columns)
                    - set(adata.uns.get("original_obs_columns", []))
                    # do not delete this column
                    - {"is_actually_disease"}
                )
                + [
                    "num_reads",
                    "total_clone_num_reads",
                    "num_clone_members",
                    "cdr1_seq_aa_q_trim",
                    "cdr2_seq_aa_q_trim",
                    "extracted_isotype",
                    "igh_or_tcrb_clone_id",
                    "cdr3_aa_sequence_trim_len",
                    "disease_subtype",
                ],
                errors="ignore",
                inplace=True,
            )
            # Sanity check: make sure we did not drop these columns
            assert "disease" in adata.obs.columns
            assert "is_actually_disease" in adata.obs.columns

            # Also remove any uns keys that were added after the original read-from-disk step within load_fold_embeddings
            for key in set(adata.uns.keys()) - set(
                adata.uns.get("original_uns_keys", [])
            ):
                del adata.uns[key]

            # Also remove large string index
            # this is a RangeIndex, but after reading back in, these will become strings automatically (ImplicitModificationWarning: Transforming to str index.)
            adata.obs_names = range(adata.shape[0])

            # Save some space on this field too
            adata.obs["v_mut"] = adata.obs["v_mut"].astype(np.float32)

            # Write anndata and CSVs to disk
            output_dir_anndatas = output_dirs[signal_to_noise_ratio]
            fname_out = output_dir_anndatas / f"fold.{fold_id}.{fold_label}.h5ad"
            logger.info(f"Fold {fold_id}-{fold_label}, {gene_locus} -> {fname_out}")
            adata.write(fname_out, compression="gzip")
            adata.obs.to_csv(
                output_dir_anndatas / f"fold.{fold_id}.{fold_label}.obs.tsv.gz",
                index=None,
                sep="\t",
            )
            np.savetxt(
                output_dir_anndatas / f"fold.{fold_id}.{fold_label}.X.tsv.gz",
                adata.X,
                fmt="%0.4f",
                delimiter="\t",
            )

            # Replace .X with X_pca
            adata = anndata.AnnData(
                X=adata.obsm["X_pca"],
                obs=adata.obs,
                uns=adata.uns,
            )
            # Writing out the anndata again is unnecessary - already have X_pca in original
            adata.write(
                output_dir_anndatas / f"fold.{fold_id}.{fold_label}.pca.h5ad",
                compression="gzip",
            )
            np.savetxt(
                output_dir_anndatas / f"fold.{fold_id}.{fold_label}.X_pca.tsv.gz",
                adata.X,
                fmt="%0.4f",
                delimiter="\t",
            )

            del adata
            gc.collect()

        # after finishing all desired signal to noise ratios, delete cached dataset
        io.clear_cached_fold_embeddings()
        gc.collect()
# Out:
# 2022-08-31 01:14:30,556 - malid.external.scratch_cache - INFO - Reading network file from local machine cache: /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/anndatas_scaled/BCR/fold.0.train_smaller.h5ad -> /srv/scratch/maximz/cache/de2b6a86e81c33b78d6afeb74df304e81e419dd0a0a9e3f3ffe4dfa2.0.train_smaller.h5ad
# /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.05
# /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.10
# /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.25
# WARNING: Your filename has more than two extensions: ['.0', '.train_smaller', '.h5ad'].
# Only considering the two last: ['.train_smaller', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.0', '.train_smaller', '.h5ad'].
# Only considering the two last: ['.train_smaller', '.h5ad'].
# 2022-08-31 01:15:22,357 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M369-S001 from BFI-0007450.
# 2022-08-31 01:15:22,360 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S003 because we already included another sample from BFI-0007450.
# 2022-08-31 01:15:22,362 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S014 because we already included another sample from BFI-0007450.
# 2022-08-31 01:15:23,605 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S001 from BFI-0007480.
# 2022-08-31 01:15:23,606 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S015 because we already included another sample from BFI-0007480.
# 2022-08-31 01:15:24,833 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S023 from BFI-0007482.
# 2022-08-31 01:15:25,994 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S008 from BFI-0007483.
# 2022-08-31 01:15:25,995 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S024 because we already included another sample from BFI-0007483.
# 2022-08-31 01:15:26,581 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S009 from BFI-0007484.
# 2022-08-31 01:15:28,586 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S012 from BFI-0002852.
# 2022-08-31 01:15:29,550 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S038 from BFI-0002866.
# 2022-08-31 01:15:31,894 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S039 from BFI-0002867.
# 2022-08-31 01:15:34,269 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-004 from BFI-0003053.
# 2022-08-31 01:15:36,807 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-005 from BFI-0003054.
# 2022-08-31 01:15:40,019 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-006 from BFI-0003055.
# 2022-08-31 01:15:41,462 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-008 from BFI-0003057.
# 2022-08-31 01:15:45,508 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-012 from BFI-0003061.
# 2022-08-31 01:15:45,694 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-015 from BFI-0003064.
# 2022-08-31 01:15:46,063 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-016 from BFI-0003065.
# 2022-08-31 01:15:46,078 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007484_BFI-0003065, M371-S009_M64-016: effective signal-to-noise ratio 0.05 (10 disease and 190 healthy sequences); desired ratio 0.05.
# 2022-08-31 01:15:46,097 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007483_BFI-0003064, M371-S008_M64-015: effective signal-to-noise ratio 0.05 (13 disease and 247 healthy sequences); desired ratio 0.05.
# 2022-08-31 01:15:50,934 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007482_BFI-0003061, M371-S023_M64-012: effective signal-to-noise ratio 0.05 (14 disease and 266 healthy sequences); desired ratio 0.05.
# 2022-08-31 01:15:51,898 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007480_BFI-0003057, M371-S001_M64-008: effective signal-to-noise ratio 0.05 (20 disease and 380 healthy sequences); desired ratio 0.05.
# 2022-08-31 01:15:54,064 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007450_BFI-0003055, M369-S001_M64-006: effective signal-to-noise ratio 0.05 (76 disease and 1444 healthy sequences); desired ratio 0.05.
# 2022-08-31 01:16:33,894 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Fold 0-train_smaller, GeneLocus.BCR -> /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.05/fold.0.train_smaller.h5ad
# 2022-08-31 01:16:33,946 - anndata - INFO - ... storing 'v_gene' as categorical
# 2022-08-31 01:16:33,954 - anndata - INFO - ... storing 'j_gene' as categorical
# 2022-08-31 01:16:33,964 - anndata - INFO - ... storing 'disease' as categorical
# 2022-08-31 01:16:34,342 - anndata - INFO - ... storing 'cdr3_seq_aa_q_trim' as categorical
# 2022-08-31 01:27:28,233 - py.warnings - WARNING - /users/maximz/anaconda3/envs/cuda-env-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#
# 2022-08-31 01:27:33,876 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M369-S001 from BFI-0007450.
# 2022-08-31 01:27:33,878 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S003 because we already included another sample from BFI-0007450.
# 2022-08-31 01:27:33,879 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S014 because we already included another sample from BFI-0007450.
# 2022-08-31 01:27:34,888 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S001 from BFI-0007480.
# 2022-08-31 01:27:34,889 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S015 because we already included another sample from BFI-0007480.
# 2022-08-31 01:27:35,734 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S023 from BFI-0007482.
# 2022-08-31 01:27:36,705 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S008 from BFI-0007483.
# 2022-08-31 01:27:36,707 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S024 because we already included another sample from BFI-0007483.
# 2022-08-31 01:27:37,285 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S009 from BFI-0007484.
# 2022-08-31 01:27:38,160 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S012 from BFI-0002852.
# 2022-08-31 01:27:39,014 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S038 from BFI-0002866.
# 2022-08-31 01:27:40,154 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S039 from BFI-0002867.
# 2022-08-31 01:27:41,518 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-004 from BFI-0003053.
# 2022-08-31 01:27:42,721 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-005 from BFI-0003054.
# 2022-08-31 01:27:44,039 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-006 from BFI-0003055.
# 2022-08-31 01:27:44,902 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-008 from BFI-0003057.
# 2022-08-31 01:27:46,510 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-012 from BFI-0003061.
# 2022-08-31 01:27:46,714 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-015 from BFI-0003064.
# 2022-08-31 01:27:47,117 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-016 from BFI-0003065.
# 2022-08-31 01:27:47,145 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007484_BFI-0003065, M371-S009_M64-016: effective signal-to-noise ratio 0.1 (10 disease and 90 healthy sequences); desired ratio 0.1.
# 2022-08-31 01:27:47,168 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007483_BFI-0003064, M371-S008_M64-015: effective signal-to-noise ratio 0.1 (13 disease and 117 healthy sequences); desired ratio 0.1.
# 2022-08-31 01:27:47,723 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007482_BFI-0003061, M371-S023_M64-012: effective signal-to-noise ratio 0.1 (14 disease and 126 healthy sequences); desired ratio 0.1.
# 2022-08-31 01:27:47,915 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007480_BFI-0003057, M371-S001_M64-008: effective signal-to-noise ratio 0.1 (20 disease and 180 healthy sequences); desired ratio 0.1.
# 2022-08-31 01:27:48,278 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007450_BFI-0003055, M369-S001_M64-006: effective signal-to-noise ratio 0.1 (76 disease and 684 healthy sequences); desired ratio 0.1.
# 2022-08-31 01:27:57,084 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Fold 0-train_smaller, GeneLocus.BCR -> /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.10/fold.0.train_smaller.h5ad
# 2022-08-31 01:27:57,149 - anndata - INFO - ... storing 'v_gene' as categorical
# 2022-08-31 01:27:57,159 - anndata - INFO - ... storing 'j_gene' as categorical
# 2022-08-31 01:27:57,168 - anndata - INFO - ... storing 'disease' as categorical
# 2022-08-31 01:27:57,598 - anndata - INFO - ... storing 'cdr3_seq_aa_q_trim' as categorical
# 2022-08-31 01:38:42,946 - py.warnings - WARNING - /users/maximz/anaconda3/envs/cuda-env-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#
# 2022-08-31 01:38:48,437 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M369-S001 from BFI-0007450.
# 2022-08-31 01:38:48,439 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S003 because we already included another sample from BFI-0007450.
# 2022-08-31 01:38:48,440 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S014 because we already included another sample from BFI-0007450.
# 2022-08-31 01:38:49,357 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S001 from BFI-0007480.
# 2022-08-31 01:38:49,358 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S015 because we already included another sample from BFI-0007480.
# 2022-08-31 01:38:50,182 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S023 from BFI-0007482.
# 2022-08-31 01:38:51,078 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S008 from BFI-0007483.
# 2022-08-31 01:38:51,079 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S024 because we already included another sample from BFI-0007483.
# 2022-08-31 01:38:51,648 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S009 from BFI-0007484.
# 2022-08-31 01:38:52,491 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S012 from BFI-0002852.
# 2022-08-31 01:38:53,237 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S038 from BFI-0002866.
# 2022-08-31 01:38:54,224 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S039 from BFI-0002867.
# 2022-08-31 01:38:55,320 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-004 from BFI-0003053.
# 2022-08-31 01:38:56,440 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-005 from BFI-0003054.
# 2022-08-31 01:38:57,671 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-006 from BFI-0003055.
# 2022-08-31 01:38:58,490 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-008 from BFI-0003057.
# 2022-08-31 01:39:00,040 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-012 from BFI-0003061.
# 2022-08-31 01:39:00,229 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-015 from BFI-0003064.
# 2022-08-31 01:39:00,609 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-016 from BFI-0003065.
# 2022-08-31 01:39:00,635 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007484_BFI-0003065, M371-S009_M64-016: effective signal-to-noise ratio 0.25 (10 disease and 30 healthy sequences); desired ratio 0.25.
# 2022-08-31 01:39:00,656 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007483_BFI-0003064, M371-S008_M64-015: effective signal-to-noise ratio 0.25 (13 disease and 39 healthy sequences); desired ratio 0.25.
# 2022-08-31 01:39:01,142 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007482_BFI-0003061, M371-S023_M64-012: effective signal-to-noise ratio 0.25 (14 disease and 42 healthy sequences); desired ratio 0.25.
# 2022-08-31 01:39:01,312 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007480_BFI-0003057, M371-S001_M64-008: effective signal-to-noise ratio 0.25 (20 disease and 60 healthy sequences); desired ratio 0.25.
# 2022-08-31 01:39:01,627 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007450_BFI-0003055, M369-S001_M64-006: effective signal-to-noise ratio 0.25 (76 disease and 228 healthy sequences); desired ratio 0.25.
# 2022-08-31 01:39:10,221 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Fold 0-train_smaller, GeneLocus.BCR -> /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.25/fold.0.train_smaller.h5ad
# 2022-08-31 01:39:10,271 - anndata - INFO - ... storing 'v_gene' as categorical
# 2022-08-31 01:39:10,280 - anndata - INFO - ... storing 'j_gene' as categorical
# 2022-08-31 01:39:10,289 - anndata - INFO - ... storing 'disease' as categorical
# 2022-08-31 01:39:10,641 - anndata - INFO - ... storing 'cdr3_seq_aa_q_trim' as categorical
# 2022-08-31 01:49:52,166 - py.warnings - WARNING - /users/maximz/anaconda3/envs/cuda-env-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#
# 2022-08-31 01:49:56,460 - malid.external.scratch_cache - INFO - Reading network file from local machine cache: /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/anndatas_scaled/BCR/fold.0.validation.h5ad -> /srv/scratch/maximz/cache/9e909d84d4c652defab7d01506f735fd31870785eb5da499c787dcf4.0.validation.h5ad
# WARNING: Your filename has more than two extensions: ['.0', '.validation', '.h5ad'].
# Only considering the two last: ['.validation', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.0', '.validation', '.h5ad'].
# Only considering the two last: ['.validation', '.h5ad'].
# 2022-08-31 01:51:18,984 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M371-S004 from BFI-0007453 did not pass thresholds.
# 2022-08-31 01:51:19,620 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S017 from BFI-0007453.
# 2022-08-31 01:51:19,952 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S197 from BFI-0009004 did not pass thresholds.
# 2022-08-31 01:51:22,616 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S225 from BFI-0009031 did not pass thresholds.
# 2022-08-31 01:51:23,098 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S228 from BFI-0009034 did not pass thresholds.
# 2022-08-31 01:51:23,548 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S229 from BFI-0009035 did not pass thresholds.
# 2022-08-31 01:51:24,271 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S230 from BFI-0009036.
# 2022-08-31 01:51:24,272 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M418-S231 because we already included another sample from BFI-0009036.
# 2022-08-31 01:51:24,273 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M418-S232 because we already included another sample from BFI-0009036.
# 2022-08-31 01:51:24,672 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S110 from BFI-0009056 did not pass thresholds.
# 2022-08-31 01:51:25,197 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S112 from BFI-0009056 did not pass thresholds.
# 2022-08-31 01:51:25,865 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S139 from BFI-0009076.
# 2022-08-31 01:51:26,575 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S021 from BFI-0009139.
# 2022-08-31 01:51:27,097 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S025 from BFI-0009142 did not pass thresholds.
# 2022-08-31 01:51:27,862 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S027 from BFI-0009144.
# 2022-08-31 01:51:28,693 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S040 from BFI-0002868.
# 2022-08-31 01:51:30,935 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-002 from BFI-0003051.
# 2022-08-31 01:51:31,735 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-013 from BFI-0003062.
# 2022-08-31 01:51:32,704 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-028 from BFI-0003077.
# 2022-08-31 01:51:33,576 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-030 from BFI-0003079.
# 2022-08-31 01:51:34,059 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-034 from BFI-0003083.
# 2022-08-31 01:51:35,034 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-036 from BFI-0003085.
# 2022-08-31 01:51:36,802 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-038 from BFI-0003087.
# 2022-08-31 01:51:37,350 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-042 from BFI-0003091.
# 2022-08-31 01:51:38,827 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-045 from BFI-0003094.
# 2022-08-31 01:51:39,213 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009144_BFI-0003094, M418-S027_M64-045: effective signal-to-noise ratio 0.05 (29 disease and 551 healthy sequences); desired ratio 0.05.
# 2022-08-31 01:51:39,285 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009139_BFI-0003091, M418-S021_M64-042: effective signal-to-noise ratio 0.05 (44 disease and 836 healthy sequences); desired ratio 0.05.
# 2022-08-31 01:51:39,858 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009076_BFI-0003087, M418-S139_M64-038: effective signal-to-noise ratio 0.05 (39 disease and 741 healthy sequences); desired ratio 0.05.
# 2022-08-31 01:51:40,125 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009036_BFI-0003085, M418-S230_M64-036: effective signal-to-noise ratio 0.05 (25 disease and 475 healthy sequences); desired ratio 0.05.
# 2022-08-31 01:51:40,190 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007453_BFI-0003083, M371-S017_M64-034: effective signal-to-noise ratio 0.05 (17 disease and 323 healthy sequences); desired ratio 0.05.
# 2022-08-31 01:51:47,112 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Fold 0-validation, GeneLocus.BCR -> /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.05/fold.0.validation.h5ad
# 2022-08-31 01:51:47,194 - anndata - INFO - ... storing 'v_gene' as categorical
# 2022-08-31 01:51:47,206 - anndata - INFO - ... storing 'j_gene' as categorical
# 2022-08-31 01:51:47,218 - anndata - INFO - ... storing 'disease' as categorical
# 2022-08-31 01:51:47,742 - anndata - INFO - ... storing 'cdr3_seq_aa_q_trim' as categorical
# 2022-08-31 01:51:47,751 - anndata - INFO - ... storing 'isotype_supergroup' as categorical
# 2022-08-31 02:06:41,653 - py.warnings - WARNING - /users/maximz/anaconda3/envs/cuda-env-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#
# 2022-08-31 02:06:47,250 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M371-S004 from BFI-0007453 did not pass thresholds.
# 2022-08-31 02:06:47,889 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S017 from BFI-0007453.
# 2022-08-31 02:06:48,226 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S197 from BFI-0009004 did not pass thresholds.
# 2022-08-31 02:06:48,763 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S225 from BFI-0009031 did not pass thresholds.
# 2022-08-31 02:06:49,263 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S228 from BFI-0009034 did not pass thresholds.
# 2022-08-31 02:06:49,721 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S229 from BFI-0009035 did not pass thresholds.
# 2022-08-31 02:06:50,467 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S230 from BFI-0009036.
# 2022-08-31 02:06:50,468 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M418-S231 because we already included another sample from BFI-0009036.
# 2022-08-31 02:06:50,469 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M418-S232 because we already included another sample from BFI-0009036.
# 2022-08-31 02:06:50,865 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S110 from BFI-0009056 did not pass thresholds.
# 2022-08-31 02:06:51,406 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S112 from BFI-0009056 did not pass thresholds.
# 2022-08-31 02:06:52,091 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S139 from BFI-0009076.
# 2022-08-31 02:06:52,821 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S021 from BFI-0009139.
# 2022-08-31 02:06:53,350 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S025 from BFI-0009142 did not pass thresholds.
# 2022-08-31 02:06:54,117 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S027 from BFI-0009144.
# 2022-08-31 02:06:54,948 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S040 from BFI-0002868.
# 2022-08-31 02:06:57,003 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-002 from BFI-0003051.
# 2022-08-31 02:06:57,762 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-013 from BFI-0003062.
# 2022-08-31 02:06:58,647 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-028 from BFI-0003077.
# 2022-08-31 02:06:59,502 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-030 from BFI-0003079.
# 2022-08-31 02:06:59,968 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-034 from BFI-0003083.
# 2022-08-31 02:07:00,890 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-036 from BFI-0003085.
# 2022-08-31 02:07:02,451 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-038 from BFI-0003087.
# 2022-08-31 02:07:02,975 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-042 from BFI-0003091.
# 2022-08-31 02:07:04,280 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-045 from BFI-0003094.
# 2022-08-31 02:07:04,658 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009144_BFI-0003094, M418-S027_M64-045: effective signal-to-noise ratio 0.1 (29 disease and 261 healthy sequences); desired ratio 0.1.
# 2022-08-31 02:07:04,712 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009139_BFI-0003091, M418-S021_M64-042: effective signal-to-noise ratio 0.1 (44 disease and 396 healthy sequences); desired ratio 0.1.
# 2022-08-31 02:07:05,273 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009076_BFI-0003087, M418-S139_M64-038: effective signal-to-noise ratio 0.1 (39 disease and 351 healthy sequences); desired ratio 0.1.
# 2022-08-31 02:07:05,530 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009036_BFI-0003085, M418-S230_M64-036: effective signal-to-noise ratio 0.1 (25 disease and 225 healthy sequences); desired ratio 0.1.
# 2022-08-31 02:07:05,589 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007453_BFI-0003083, M371-S017_M64-034: effective signal-to-noise ratio 0.1 (17 disease and 153 healthy sequences); desired ratio 0.1.
# 2022-08-31 02:07:10,572 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Fold 0-validation, GeneLocus.BCR -> /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.10/fold.0.validation.h5ad
# 2022-08-31 02:07:10,652 - anndata - INFO - ... storing 'v_gene' as categorical
# 2022-08-31 02:07:10,664 - anndata - INFO - ... storing 'j_gene' as categorical
# 2022-08-31 02:07:10,677 - anndata - INFO - ... storing 'disease' as categorical
# 2022-08-31 02:07:11,190 - anndata - INFO - ... storing 'cdr3_seq_aa_q_trim' as categorical
# 2022-08-31 02:07:11,199 - anndata - INFO - ... storing 'isotype_supergroup' as categorical
# 2022-08-31 02:21:59,994 - py.warnings - WARNING - /users/maximz/anaconda3/envs/cuda-env-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#
# 2022-08-31 02:22:05,203 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M371-S004 from BFI-0007453 did not pass thresholds.
# 2022-08-31 02:22:05,830 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S017 from BFI-0007453.
# 2022-08-31 02:22:06,158 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S197 from BFI-0009004 did not pass thresholds.
# 2022-08-31 02:22:06,697 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S225 from BFI-0009031 did not pass thresholds.
# 2022-08-31 02:22:07,195 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S228 from BFI-0009034 did not pass thresholds.
# 2022-08-31 02:22:07,648 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S229 from BFI-0009035 did not pass thresholds.
# 2022-08-31 02:22:08,382 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S230 from BFI-0009036.
# 2022-08-31 02:22:08,383 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M418-S231 because we already included another sample from BFI-0009036.
# 2022-08-31 02:22:08,384 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M418-S232 because we already included another sample from BFI-0009036.
# 2022-08-31 02:22:08,778 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S110 from BFI-0009056 did not pass thresholds.
# 2022-08-31 02:22:09,317 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S112 from BFI-0009056 did not pass thresholds.
# 2022-08-31 02:22:09,996 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S139 from BFI-0009076.
# 2022-08-31 02:22:10,717 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S021 from BFI-0009139.
# 2022-08-31 02:22:11,240 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S025 from BFI-0009142 did not pass thresholds.
# 2022-08-31 02:22:12,002 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S027 from BFI-0009144.
# 2022-08-31 02:22:12,836 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S040 from BFI-0002868.
# 2022-08-31 02:22:14,881 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-002 from BFI-0003051.
# 2022-08-31 02:22:15,640 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-013 from BFI-0003062.
# 2022-08-31 02:22:16,514 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-028 from BFI-0003077.
# 2022-08-31 02:22:17,358 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-030 from BFI-0003079.
# 2022-08-31 02:22:17,819 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-034 from BFI-0003083.
# 2022-08-31 02:22:18,731 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-036 from BFI-0003085.
# 2022-08-31 02:22:20,279 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-038 from BFI-0003087.
# 2022-08-31 02:22:20,797 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-042 from BFI-0003091.
# 2022-08-31 02:22:22,090 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-045 from BFI-0003094.
# 2022-08-31 02:22:22,464 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009144_BFI-0003094, M418-S027_M64-045: effective signal-to-noise ratio 0.25 (29 disease and 87 healthy sequences); desired ratio 0.25.
# 2022-08-31 02:22:22,515 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009139_BFI-0003091, M418-S021_M64-042: effective signal-to-noise ratio 0.25 (44 disease and 132 healthy sequences); desired ratio 0.25.
# 2022-08-31 02:22:23,066 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009076_BFI-0003087, M418-S139_M64-038: effective signal-to-noise ratio 0.25 (39 disease and 117 healthy sequences); desired ratio 0.25.
# 2022-08-31 02:22:23,325 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009036_BFI-0003085, M418-S230_M64-036: effective signal-to-noise ratio 0.25 (25 disease and 75 healthy sequences); desired ratio 0.25.
# 2022-08-31 02:22:23,382 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007453_BFI-0003083, M371-S017_M64-034: effective signal-to-noise ratio 0.25 (17 disease and 51 healthy sequences); desired ratio 0.25.
# 2022-08-31 02:22:28,253 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Fold 0-validation, GeneLocus.BCR -> /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.25/fold.0.validation.h5ad
# 2022-08-31 02:22:28,331 - anndata - INFO - ... storing 'v_gene' as categorical
# 2022-08-31 02:22:28,343 - anndata - INFO - ... storing 'j_gene' as categorical
# 2022-08-31 02:22:28,355 - anndata - INFO - ... storing 'disease' as categorical
# 2022-08-31 02:22:28,870 - anndata - INFO - ... storing 'cdr3_seq_aa_q_trim' as categorical
# 2022-08-31 02:22:28,879 - anndata - INFO - ... storing 'isotype_supergroup' as categorical
# 2022-08-31 02:37:06,074 - py.warnings - WARNING - /users/maximz/anaconda3/envs/cuda-env-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#
# 2022-08-31 02:37:11,067 - malid.external.scratch_cache - INFO - Reading network file from local machine cache: /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/anndatas_scaled/BCR/fold.0.test.h5ad -> /srv/scratch/maximz/cache/5723c164b1f27c22795a9f7198fdf9bfbfe553df2bdf9052506d1b2c.0.test.h5ad
# WARNING: Your filename has more than two extensions: ['.0', '.test', '.h5ad'].
# Only considering the two last: ['.test', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.0', '.test', '.h5ad'].
# Only considering the two last: ['.test', '.h5ad'].
# 2022-08-31 02:39:32,711 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M369-S007 from BFI-0007455.
# 2022-08-31 02:39:32,713 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S002 because we already included another sample from BFI-0007455.
# 2022-08-31 02:39:32,714 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S031 because we already included another sample from BFI-0007455.
# 2022-08-31 02:39:32,715 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S033 because we already included another sample from BFI-0007455.
# 2022-08-31 02:39:34,618 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M371-S005 from BFI-0007481 did not pass thresholds.
# 2022-08-31 02:39:35,287 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S028 from BFI-0007486.
# 2022-08-31 02:39:35,288 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S029 because we already included another sample from BFI-0007486.
# 2022-08-31 02:39:35,289 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S030 because we already included another sample from BFI-0007486.
# 2022-08-31 02:39:35,612 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S219 from BFI-0009025 did not pass thresholds.
# 2022-08-31 02:39:35,993 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S101 from BFI-0009051 did not pass thresholds.
# 2022-08-31 02:39:36,312 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S102 from BFI-0009051 did not pass thresholds.
# 2022-08-31 02:39:36,496 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S104 from BFI-0009052 did not pass thresholds.
# 2022-08-31 02:39:36,946 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S105 from BFI-0009052 did not pass thresholds.
# 2022-08-31 02:39:37,441 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S106 from BFI-0009052 did not pass thresholds.
# 2022-08-31 02:39:37,715 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S113 from BFI-0009057 did not pass thresholds.
# 2022-08-31 02:39:38,282 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S114 from BFI-0009057 did not pass thresholds.
# 2022-08-31 02:39:38,915 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S144 from BFI-0009080.
# 2022-08-31 02:39:39,655 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S148 from BFI-0009083 did not pass thresholds.
# 2022-08-31 02:39:40,206 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S149 from BFI-0009083 did not pass thresholds.
# 2022-08-31 02:39:40,834 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S150 from BFI-0009083 did not pass thresholds.
# 2022-08-31 02:39:41,466 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S169 from BFI-0009098 did not pass thresholds.
# 2022-08-31 02:39:41,941 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S174 from BFI-0009102 did not pass thresholds.
# 2022-08-31 02:39:42,430 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S184 from BFI-0009112 did not pass thresholds.
# 2022-08-31 02:39:43,050 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S193 from BFI-0009121.
# 2022-08-31 02:39:43,790 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S001 from BFI-0009122.
# 2022-08-31 02:39:44,645 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S014 from BFI-0000234.
# 2022-08-31 02:39:45,445 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S042 from BFI-0002850.
# 2022-08-31 02:39:46,320 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S041 from BFI-0002851.
# 2022-08-31 02:39:46,793 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S037 from BFI-0002861.
# 2022-08-31 02:39:47,600 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S036 from BFI-0002862.
# 2022-08-31 02:39:48,323 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S035 from BFI-0002863.
# 2022-08-31 02:39:48,639 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-003 from BFI-0003052.
# 2022-08-31 02:39:49,672 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-009 from BFI-0003058.
# 2022-08-31 02:39:50,933 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-010 from BFI-0003059.
# 2022-08-31 02:39:51,418 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-014 from BFI-0003063.
# 2022-08-31 02:39:51,453 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009122_BFI-0003063, M418-S001_M64-014: effective signal-to-noise ratio 0.05 (20 disease and 380 healthy sequences); desired ratio 0.05.
# 2022-08-31 02:39:51,833 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009121_BFI-0003059, M418-S193_M64-010: effective signal-to-noise ratio 0.05 (14 disease and 266 healthy sequences); desired ratio 0.05.
# 2022-08-31 02:39:52,090 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0009080_BFI-0003058, M418-S144_M64-009: effective signal-to-noise ratio 0.05 (28 disease and 532 healthy sequences); desired ratio 0.05.
# 2022-08-31 02:39:52,131 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007486_BFI-0003052, M371-S028_M64-003: effective signal-to-noise ratio 0.05 (24 disease and 456 healthy sequences); desired ratio 0.05.
# 2022-08-31 02:39:52,294 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007455_BFI-0002863, M369-S007_M124-S035: effective signal-to-noise ratio 0.05 (66 disease and 1254 healthy sequences); desired ratio 0.05.
# 2022-08-31 02:39:55,012 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Fold 0-test, GeneLocus.BCR -> /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.05/fold.0.test.h5ad
# 2022-08-31 02:39:55,048 - anndata - INFO - ... storing 'v_gene' as categorical
# 2022-08-31 02:39:55,055 - anndata - INFO - ... storing 'j_gene' as categorical
# 2022-08-31 02:39:55,062 - anndata - INFO - ... storing 'disease' as categorical
# 2022-08-31 02:39:55,416 - anndata - INFO - ... storing 'cdr3_seq_aa_q_trim' as categorical
# 2022-08-31 02:47:50,013 - py.warnings - WARNING - /users/maximz/anaconda3/envs/cuda-env-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#
# 2022-08-31 02:47:54,243 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M369-S007 from BFI-0007455.
# 2022-08-31 02:47:54,245 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S002 because we already included another sample from BFI-0007455.
# 2022-08-31 02:47:54,246 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S031 because we already included another sample from BFI-0007455.
# 2022-08-31 02:47:54,246 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S033 because we already included another sample from BFI-0007455.
# 2022-08-31 02:47:55,164 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M371-S005 from BFI-0007481 did not pass thresholds.
# 2022-08-31 02:47:55,864 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S028 from BFI-0007486.
# 2022-08-31 02:47:55,865 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S029 because we already included another sample from BFI-0007486.
# 2022-08-31 02:47:55,866 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S030 because we already included another sample from BFI-0007486.
# 2022-08-31 02:47:56,195 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S219 from BFI-0009025 did not pass thresholds.
# 2022-08-31 02:47:56,595 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S101 from BFI-0009051 did not pass thresholds.
# 2022-08-31 02:47:56,929 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S102 from BFI-0009051 did not pass thresholds.
# 2022-08-31 02:47:57,119 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S104 from BFI-0009052 did not pass thresholds.
# 2022-08-31 02:47:57,604 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S105 from BFI-0009052 did not pass thresholds.
# 2022-08-31 02:47:58,146 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S106 from BFI-0009052 did not pass thresholds.
# 2022-08-31 02:47:58,433 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S113 from BFI-0009057 did not pass thresholds.
# 2022-08-31 02:47:59,031 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S114 from BFI-0009057 did not pass thresholds.
# 2022-08-31 02:47:59,739 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S144 from BFI-0009080.
# 2022-08-31 02:48:00,547 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S148 from BFI-0009083 did not pass thresholds.
# 2022-08-31 02:48:01,158 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S149 from BFI-0009083 did not pass thresholds.
# 2022-08-31 02:48:01,838 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S150 from BFI-0009083 did not pass thresholds.
# 2022-08-31 02:48:02,535 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S169 from BFI-0009098 did not pass thresholds.
# 2022-08-31 02:48:03,023 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S174 from BFI-0009102 did not pass thresholds.
# 2022-08-31 02:48:03,537 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M418-S184 from BFI-0009112 did not pass thresholds.
# 2022-08-31 02:48:04,183 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S193 from BFI-0009121.
# 2022-08-31 02:48:04,966 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M418-S001 from BFI-0009122.
# 2022-08-31 02:48:05,871 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S014 from BFI-0000234.
# 2022-08-31 02:48:06,721 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S042 from BFI-0002850.
# 2022-08-31 02:48:07,657 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S041 from BFI-0002851.
# 2022-08-31 02:48:08,170 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S037 from BFI-0002861.
# 2022-08-31 02:48:09,059 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S036 from BFI-0002862.
# 2022-08-31 02:48:09,814 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S035 from BFI-0002863.
# 2022-08-31 02:48:10,141 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-003 from BFI-0003052.
# 2022-08-31 02:48:11,223 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-009 from BFI-0003058.
# ...
# 2022-08-31 05:37:10,074 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Fold 2-validation, GeneLocus.BCR -> /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.25/fold.2.validation.h5ad
# 2022-08-31 05:37:10,138 - anndata - INFO - ... storing 'v_gene' as categorical
# 2022-08-31 05:37:10,149 - anndata - INFO - ... storing 'j_gene' as categorical
# 2022-08-31 05:37:10,160 - anndata - INFO - ... storing 'disease' as categorical
# 2022-08-31 05:37:10,592 - anndata - INFO - ... storing 'cdr3_seq_aa_q_trim' as categorical
# 2022-08-31 05:37:10,601 - anndata - INFO - ... storing 'isotype_supergroup' as categorical
# 2022-08-31 05:50:41,201 - py.warnings - WARNING - /users/maximz/anaconda3/envs/cuda-env-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#
# 2022-08-31 05:50:45,781 - malid.external.scratch_cache - INFO - Reading network file from local machine cache: /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/anndatas_scaled/BCR/fold.2.test.h5ad -> /srv/scratch/maximz/cache/3b9c8e0cb054f7947d2b969b87c4bc1404e60f01392cf154a24641f6.2.test.h5ad
# WARNING: Your filename has more than two extensions: ['.2', '.test', '.h5ad'].
# Only considering the two last: ['.test', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.2', '.test', '.h5ad'].
# Only considering the two last: ['.test', '.h5ad'].
# 2022-08-31 05:52:37,417 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M371-S004 from BFI-0007453 did not pass thresholds.
# 2022-08-31 05:52:38,023 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S017 from BFI-0007453.
# 2022-08-31 05:52:40,026 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S001 from BFI-0007480.
# 2022-08-31 05:52:40,027 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S015 because we already included another sample from BFI-0007480.
# 2022-08-31 05:52:40,773 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S023 from BFI-0007482.
# 2022-08-31 05:52:41,600 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S008 from BFI-0007483.
# 2022-08-31 05:52:41,601 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S024 because we already included another sample from BFI-0007483.
# 2022-08-31 05:52:42,241 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S011 from BFI-0007485.
# 2022-08-31 05:52:43,011 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S012 from BFI-0002852.
# 2022-08-31 05:52:44,023 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S039 from BFI-0002867.
# 2022-08-31 05:52:45,042 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-005 from BFI-0003054.
# 2022-08-31 05:52:46,176 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-006 from BFI-0003055.
# 2022-08-31 05:52:46,360 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-015 from BFI-0003064.
# 2022-08-31 05:52:46,859 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-020 from BFI-0003069.
# 2022-08-31 05:52:47,740 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-021 from BFI-0003070.
# 2022-08-31 05:52:48,443 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-026 from BFI-0003075.
# 2022-08-31 05:52:49,123 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-030 from BFI-0003079.
# 2022-08-31 05:52:50,096 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-036 from BFI-0003085.
# 2022-08-31 05:52:50,331 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007485_BFI-0003085, M371-S011_M64-036: effective signal-to-noise ratio 0.05 (11 disease and 209 healthy sequences); desired ratio 0.05.
# 2022-08-31 05:52:50,486 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007483_BFI-0003079, M371-S008_M64-030: effective signal-to-noise ratio 0.05 (13 disease and 247 healthy sequences); desired ratio 0.05.
# 2022-08-31 05:52:50,635 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007482_BFI-0003075, M371-S023_M64-026: effective signal-to-noise ratio 0.05 (14 disease and 266 healthy sequences); desired ratio 0.05.
# 2022-08-31 05:52:50,819 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007480_BFI-0003070, M371-S001_M64-021: effective signal-to-noise ratio 0.05 (20 disease and 380 healthy sequences); desired ratio 0.05.
# 2022-08-31 05:52:50,873 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007453_BFI-0003069, M371-S017_M64-020: effective signal-to-noise ratio 0.05 (17 disease and 323 healthy sequences); desired ratio 0.05.
# 2022-08-31 05:52:54,318 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Fold 2-test, GeneLocus.BCR -> /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.05/fold.2.test.h5ad
# 2022-08-31 05:52:54,361 - anndata - INFO - ... storing 'v_gene' as categorical
# 2022-08-31 05:52:54,369 - anndata - INFO - ... storing 'j_gene' as categorical
# 2022-08-31 05:52:54,378 - anndata - INFO - ... storing 'disease' as categorical
# 2022-08-31 05:52:54,701 - anndata - INFO - ... storing 'cdr3_seq_aa_q_trim' as categorical
# 2022-08-31 06:03:10,216 - py.warnings - WARNING - /users/maximz/anaconda3/envs/cuda-env-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#
# 2022-08-31 06:03:14,147 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M371-S004 from BFI-0007453 did not pass thresholds.
# 2022-08-31 06:03:14,786 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S017 from BFI-0007453.
# 2022-08-31 06:03:15,703 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S001 from BFI-0007480.
# 2022-08-31 06:03:15,704 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S015 because we already included another sample from BFI-0007480.
# 2022-08-31 06:03:16,511 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S023 from BFI-0007482.
# 2022-08-31 06:03:17,418 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S008 from BFI-0007483.
# 2022-08-31 06:03:17,419 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S024 because we already included another sample from BFI-0007483.
# 2022-08-31 06:03:18,138 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S011 from BFI-0007485.
# 2022-08-31 06:03:18,956 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S012 from BFI-0002852.
# 2022-08-31 06:03:20,030 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S039 from BFI-0002867.
# 2022-08-31 06:03:21,169 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-005 from BFI-0003054.
# 2022-08-31 06:03:22,413 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-006 from BFI-0003055.
# 2022-08-31 06:03:22,610 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-015 from BFI-0003064.
# 2022-08-31 06:03:23,126 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-020 from BFI-0003069.
# 2022-08-31 06:03:24,050 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-021 from BFI-0003070.
# 2022-08-31 06:03:24,782 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-026 from BFI-0003075.
# 2022-08-31 06:03:25,488 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-030 from BFI-0003079.
# 2022-08-31 06:03:26,526 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-036 from BFI-0003085.
# 2022-08-31 06:03:26,755 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007485_BFI-0003085, M371-S011_M64-036: effective signal-to-noise ratio 0.1 (11 disease and 99 healthy sequences); desired ratio 0.1.
# 2022-08-31 06:03:26,905 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007483_BFI-0003079, M371-S008_M64-030: effective signal-to-noise ratio 0.1 (13 disease and 117 healthy sequences); desired ratio 0.1.
# 2022-08-31 06:03:27,049 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007482_BFI-0003075, M371-S023_M64-026: effective signal-to-noise ratio 0.1 (14 disease and 126 healthy sequences); desired ratio 0.1.
# 2022-08-31 06:03:27,228 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007480_BFI-0003070, M371-S001_M64-021: effective signal-to-noise ratio 0.1 (20 disease and 180 healthy sequences); desired ratio 0.1.
# 2022-08-31 06:03:27,289 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007453_BFI-0003069, M371-S017_M64-020: effective signal-to-noise ratio 0.1 (17 disease and 153 healthy sequences); desired ratio 0.1.
# 2022-08-31 06:03:30,731 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Fold 2-test, GeneLocus.BCR -> /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.10/fold.2.test.h5ad
# 2022-08-31 06:03:30,779 - anndata - INFO - ... storing 'v_gene' as categorical
# 2022-08-31 06:03:30,787 - anndata - INFO - ... storing 'j_gene' as categorical
# 2022-08-31 06:03:30,796 - anndata - INFO - ... storing 'disease' as categorical
# 2022-08-31 06:03:31,107 - anndata - INFO - ... storing 'cdr3_seq_aa_q_trim' as categorical
# 2022-08-31 06:03:31,114 - anndata - INFO - ... storing 'isotype_supergroup' as categorical
# 2022-08-31 06:13:43,438 - py.warnings - WARNING - /users/maximz/anaconda3/envs/cuda-env-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#
# 2022-08-31 06:13:47,314 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Disease specimen M371-S004 from BFI-0007453 did not pass thresholds.
# 2022-08-31 06:13:48,007 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S017 from BFI-0007453.
# 2022-08-31 06:13:48,991 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S001 from BFI-0007480.
# 2022-08-31 06:13:48,993 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S015 because we already included another sample from BFI-0007480.
# 2022-08-31 06:13:49,895 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S023 from BFI-0007482.
# 2022-08-31 06:13:50,847 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S008 from BFI-0007483.
# 2022-08-31 06:13:50,849 - generate_simulation_datasets.known_binders_only.ipynb - WARNING - Skipping disease specimen M371-S024 because we already included another sample from BFI-0007483.
# 2022-08-31 06:13:51,519 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding disease specimen M371-S011 from BFI-0007485.
# 2022-08-31 06:13:52,354 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S012 from BFI-0002852.
# 2022-08-31 06:13:53,414 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M124-S039 from BFI-0002867.
# 2022-08-31 06:13:54,509 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-005 from BFI-0003054.
# 2022-08-31 06:13:55,714 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-006 from BFI-0003055.
# 2022-08-31 06:13:55,902 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-015 from BFI-0003064.
# 2022-08-31 06:13:56,426 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-020 from BFI-0003069.
# 2022-08-31 06:13:57,349 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-021 from BFI-0003070.
# 2022-08-31 06:13:58,094 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-026 from BFI-0003075.
# 2022-08-31 06:13:58,810 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-030 from BFI-0003079.
# 2022-08-31 06:13:59,840 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Adding healthy specimen M64-036 from BFI-0003085.
# 2022-08-31 06:14:00,085 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007485_BFI-0003085, M371-S011_M64-036: effective signal-to-noise ratio 0.25 (11 disease and 33 healthy sequences); desired ratio 0.25.
# 2022-08-31 06:14:00,235 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007483_BFI-0003079, M371-S008_M64-030: effective signal-to-noise ratio 0.25 (13 disease and 39 healthy sequences); desired ratio 0.25.
# 2022-08-31 06:14:00,380 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007482_BFI-0003075, M371-S023_M64-026: effective signal-to-noise ratio 0.25 (14 disease and 42 healthy sequences); desired ratio 0.25.
# 2022-08-31 06:14:00,559 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007480_BFI-0003070, M371-S001_M64-021: effective signal-to-noise ratio 0.25 (20 disease and 60 healthy sequences); desired ratio 0.25.
# 2022-08-31 06:14:00,612 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Combining BFI-0007453_BFI-0003069, M371-S017_M64-020: effective signal-to-noise ratio 0.25 (17 disease and 51 healthy sequences); desired ratio 0.25.
# 2022-08-31 06:14:04,003 - generate_simulation_datasets.known_binders_only.ipynb - INFO - Fold 2-test, GeneLocus.BCR -> /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20220704_filter2/embedded/unirep_fine_tuned/simulated_data/scaled_anndatas_0.25/fold.2.test.h5ad
# 2022-08-31 06:14:04,067 - anndata - INFO - ... storing 'v_gene' as categorical
# 2022-08-31 06:14:04,078 - anndata - INFO - ... storing 'j_gene' as categorical
# 2022-08-31 06:14:04,090 - anndata - INFO - ... storing 'disease' as categorical
# 2022-08-31 06:14:04,495 - anndata - INFO - ... storing 'cdr3_seq_aa_q_trim' as categorical
# 2022-08-31 06:14:04,503 - anndata - INFO - ... storing 'isotype_supergroup' as categorical
# 2022-08-31 06:24:14,611 - py.warnings - WARNING - /users/maximz/anaconda3/envs/cuda-env-py39/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
