# %%
import pandas as pd
from malid import config
from malid.datamodels import healthy_label

# %%
base_dir = config.paths.external_raw_data / "chudakov_aging"
external_metadata = pd.read_csv(base_dir / "metadata.txt", sep="\t").assign(
    ethnicity_condensed="Caucasian"
)
# The A* in sample identifier is the batch ID.
# Age and sex data is provided in the metadata.txt file.
# Samples having age "0" are umbilical cord blood samples.
external_metadata
# Out:
#         file_name  sample_id sex  age    label  ..filter.. ethnicity_condensed
# 0     A3-i101.txt    A3-i101   F   36   p1-F36  conv:MiTcr           Caucasian
# 1     A3-i102.txt    A3-i102   F   43   p2-F43  conv:MiTcr           Caucasian
# 2     A3-i106.txt    A3-i106   F   43   p3-F43  conv:MiTcr           Caucasian
# 3     A3-i107.txt    A3-i107   F   39   p4-F39  conv:MiTcr           Caucasian
# 4     A3-i110.txt    A3-i110   F   34   p5-F34  conv:MiTcr           Caucasian
# ..            ...        ...  ..  ...      ...         ...                 ...
# 74  A6-I204ob.txt  A6-I204ob   F   99  p74-F99  conv:MiTcr           Caucasian
# 75  A6-I205ob.txt  A6-I205ob   F   95  p75-F95  conv:MiTcr           Caucasian
# 76  A6-I200ob.txt  A6-I200ob   M   27  p76-M27  conv:MiTcr           Caucasian
# 77  A6-I201ob.txt  A6-I201ob   M   30  p76-M30  conv:MiTcr           Caucasian
# 78  A6-I202ob.txt  A6-I202ob   M   47  p53-M47  conv:MiTcr           Caucasian
#
# [79 rows x 7 columns]

# %%
external_metadata["label"].duplicated().any()
# Out:
# True

# %%
external_metadata["label"].value_counts()
# Out:
# p36-M25    2
# p7-F87     2
# p1-F36     1
# p51-F92    1
# p58-M0     1
#           ..
# p27-M64    1
# p26-M66    1
# p25-M85    1
# p24-F89    1
# p53-M47    1
# Name: label, Length: 77, dtype: int64

# %%
external_metadata["label"].str.split("-").str[0].duplicated().any()
# Out:
# True

# %%
external_metadata["label"].str.split("-").str[0].value_counts()
# Out:
# p76    2
# p36    2
# p7     2
# p53    2
# p50    1
#       ..
# p27    1
# p26    1
# p25    1
# p24    1
# p39    1
# Name: label, Length: 75, dtype: int64

# %%
# p53, p76 suspicious that years apart. but checks out against paper 2's explanation of two time points.
# the other two must be the two individuals listed in the paper with replicate samples - yes the ages match
external_metadata[
    external_metadata["label"].str.split("-").str[0].duplicated(keep=False)
]
# Out:
#         file_name  sample_id sex  age    label  ..filter.. ethnicity_condensed
# 6     A3-i150.txt    A3-i150   F   87   p7-F87  conv:MiTcr           Caucasian
# 7     A3-i151.txt    A3-i151   F   87   p7-F87  conv:MiTcr           Caucasian
# 35    A4-i189.txt    A4-i189   M   25  p36-M25  conv:MiTcr           Caucasian
# 36    A4-i190.txt    A4-i190   M   25  p36-M25  conv:MiTcr           Caucasian
# 53     A5-S23.txt     A5-S23   M   50  p53-M50  conv:MiTcr           Caucasian
# 76  A6-I200ob.txt  A6-I200ob   M   27  p76-M27  conv:MiTcr           Caucasian
# 77  A6-I201ob.txt  A6-I201ob   M   30  p76-M30  conv:MiTcr           Caucasian
# 78  A6-I202ob.txt  A6-I202ob   M   47  p53-M47  conv:MiTcr           Caucasian

# %%
external_metadata["participant_label"] = (
    external_metadata["label"].str.split("-").str[0]
)
external_metadata
# Out:
#         file_name  sample_id sex  age    label  ..filter..  \
# 0     A3-i101.txt    A3-i101   F   36   p1-F36  conv:MiTcr
# 1     A3-i102.txt    A3-i102   F   43   p2-F43  conv:MiTcr
# 2     A3-i106.txt    A3-i106   F   43   p3-F43  conv:MiTcr
# 3     A3-i107.txt    A3-i107   F   39   p4-F39  conv:MiTcr
# 4     A3-i110.txt    A3-i110   F   34   p5-F34  conv:MiTcr
# ..            ...        ...  ..  ...      ...         ...
# 74  A6-I204ob.txt  A6-I204ob   F   99  p74-F99  conv:MiTcr
# 75  A6-I205ob.txt  A6-I205ob   F   95  p75-F95  conv:MiTcr
# 76  A6-I200ob.txt  A6-I200ob   M   27  p76-M27  conv:MiTcr
# 77  A6-I201ob.txt  A6-I201ob   M   30  p76-M30  conv:MiTcr
# 78  A6-I202ob.txt  A6-I202ob   M   47  p53-M47  conv:MiTcr
#
#    ethnicity_condensed participant_label
# 0            Caucasian                p1
# 1            Caucasian                p2
# 2            Caucasian                p3
# 3            Caucasian                p4
# 4            Caucasian                p5
# ..                 ...               ...
# 74           Caucasian               p74
# 75           Caucasian               p75
# 76           Caucasian               p76
# 77           Caucasian               p76
# 78           Caucasian               p53
#
# [79 rows x 8 columns]

# %%
assert (external_metadata["file_name"] == external_metadata["sample_id"] + ".txt").all()

# %%
external_metadata["..filter.."].value_counts()
# Out:
# conv:MiTcr    79
# Name: ..filter.., dtype: int64

# %%
# get rid of extreme ages like cord blood
external_metadata["age"].describe()
# Out:
# count     79.000000
# mean      54.177215
# std       32.747973
# min        0.000000
# 25%       26.000000
# 50%       51.000000
# 75%       87.500000
# max      103.000000
# Name: age, dtype: float64

# %%
external_metadata = external_metadata[
    (external_metadata["age"] >= 20) & (external_metadata["age"] <= 80)
]
external_metadata["age"].describe()
# Out:
# count    39.000000
# mean     46.769231
# std      15.827128
# min      20.000000
# 25%      36.000000
# 50%      50.000000
# 75%      61.000000
# max      75.000000
# Name: age, dtype: float64

# %%
external_metadata = external_metadata.rename(
    columns={"sample_id": "specimen_label"}
).assign(
    disease=healthy_label,
    study_name="Britanova",
    disease_subtype=f"{healthy_label} - Britanova",
)
external_metadata
# Out:
#         file_name specimen_label sex  age    label  ..filter..  \
# 0     A3-i101.txt        A3-i101   F   36   p1-F36  conv:MiTcr
# 1     A3-i102.txt        A3-i102   F   43   p2-F43  conv:MiTcr
# 2     A3-i106.txt        A3-i106   F   43   p3-F43  conv:MiTcr
# 3     A3-i107.txt        A3-i107   F   39   p4-F39  conv:MiTcr
# 4     A3-i110.txt        A3-i110   F   34   p5-F34  conv:MiTcr
# 14    A2-i138.txt        A2-i138   F   74  p15-F74  conv:MiTcr
# 15    A2-i139.txt        A2-i139   M   75  p16-M75  conv:MiTcr
# 16    A2-i140.txt        A2-i140   F   73  p17-F73  conv:MiTcr
# 17    A2-i141.txt        A2-i141   M   71  p18-M71  conv:MiTcr
# 18    A4-i101.txt        A4-i101   M   36  p19-M36  conv:MiTcr
# 19    A4-i102.txt        A4-i102   M   37  p20-M37  conv:MiTcr
# 20    A4-i106.txt        A4-i106   M   43  p21-M43  conv:MiTcr
# 21    A4-i107.txt        A4-i107   M   39  p22-M39  conv:MiTcr
# 22    A4-i110.txt        A4-i110   F   43  p23-F43  conv:MiTcr
# 25    A4-i124.txt        A4-i124   M   66  p26-M66  conv:MiTcr
# 26    A4-i125.txt        A4-i125   M   64  p27-M64  conv:MiTcr
# 28    A4-i128.txt        A4-i128   F   62  p29-F62  conv:MiTcr
# 31    A4-i184.txt        A4-i184   M   61  p32-M61  conv:MiTcr
# 32    A4-i185.txt        A4-i185   F   61  p33-F61  conv:MiTcr
# 33    A4-i186.txt        A4-i186   F   61  p34-F61  conv:MiTcr
# 34    A4-i188.txt        A4-i188   F   61  p35-F61  conv:MiTcr
# 35    A4-i189.txt        A4-i189   M   25  p36-M25  conv:MiTcr
# 36    A4-i190.txt        A4-i190   M   25  p36-M25  conv:MiTcr
# 37    A4-i191.txt        A4-i191   F   22  p37-F22  conv:MiTcr
# 38    A4-i192.txt        A4-i192   F   24  p38-F24  conv:MiTcr
# 39    A4-i194.txt        A4-i194   M   20  p39-M20  conv:MiTcr
# 40    A4-i195.txt        A4-i195   F   21  p40-F21  conv:MiTcr
# 41     A5-S22.txt         A5-S22   M   51  p41-M51  conv:MiTcr
# 43     A5-S20.txt         A5-S20   F   51  p43-F51  conv:MiTcr
# 52     A5-S24.txt         A5-S24   F   50  p52-F50  conv:MiTcr
# 53     A5-S23.txt         A5-S23   M   50  p53-M50  conv:MiTcr
# 54     A5-S21.txt         A5-S21   F   51  p54-F51  conv:MiTcr
# 56     A5-S19.txt         A5-S19   F   55  p56-F55  conv:MiTcr
# 70    A6-I160.txt        A6-I160   F   51  p70-F51  conv:MiTcr
# 71  A6-I215ob.txt      A6-I215ob   F   51  p71-F51  conv:MiTcr
# 72    A6-I150.txt        A6-I150   M   51  p72-M51  conv:MiTcr
# 76  A6-I200ob.txt      A6-I200ob   M   27  p76-M27  conv:MiTcr
# 77  A6-I201ob.txt      A6-I201ob   M   30  p76-M30  conv:MiTcr
# 78  A6-I202ob.txt      A6-I202ob   M   47  p53-M47  conv:MiTcr
#
#    ethnicity_condensed participant_label             disease study_name  \
# 0            Caucasian                p1  Healthy/Background  Britanova
# 1            Caucasian                p2  Healthy/Background  Britanova
# 2            Caucasian                p3  Healthy/Background  Britanova
# 3            Caucasian                p4  Healthy/Background  Britanova
# 4            Caucasian                p5  Healthy/Background  Britanova
# 14           Caucasian               p15  Healthy/Background  Britanova
# 15           Caucasian               p16  Healthy/Background  Britanova
# 16           Caucasian               p17  Healthy/Background  Britanova
# 17           Caucasian               p18  Healthy/Background  Britanova
# 18           Caucasian               p19  Healthy/Background  Britanova
# 19           Caucasian               p20  Healthy/Background  Britanova
# 20           Caucasian               p21  Healthy/Background  Britanova
# 21           Caucasian               p22  Healthy/Background  Britanova
# 22           Caucasian               p23  Healthy/Background  Britanova
# 25           Caucasian               p26  Healthy/Background  Britanova
# 26           Caucasian               p27  Healthy/Background  Britanova
# 28           Caucasian               p29  Healthy/Background  Britanova
# 31           Caucasian               p32  Healthy/Background  Britanova
# 32           Caucasian               p33  Healthy/Background  Britanova
# 33           Caucasian               p34  Healthy/Background  Britanova
# 34           Caucasian               p35  Healthy/Background  Britanova
# 35           Caucasian               p36  Healthy/Background  Britanova
# 36           Caucasian               p36  Healthy/Background  Britanova
# 37           Caucasian               p37  Healthy/Background  Britanova
# 38           Caucasian               p38  Healthy/Background  Britanova
# 39           Caucasian               p39  Healthy/Background  Britanova
# 40           Caucasian               p40  Healthy/Background  Britanova
# 41           Caucasian               p41  Healthy/Background  Britanova
# 43           Caucasian               p43  Healthy/Background  Britanova
# 52           Caucasian               p52  Healthy/Background  Britanova
# 53           Caucasian               p53  Healthy/Background  Britanova
# 54           Caucasian               p54  Healthy/Background  Britanova
# 56           Caucasian               p56  Healthy/Background  Britanova
# 70           Caucasian               p70  Healthy/Background  Britanova
# 71           Caucasian               p71  Healthy/Background  Britanova
# 72           Caucasian               p72  Healthy/Background  Britanova
# 76           Caucasian               p76  Healthy/Background  Britanova
# 77           Caucasian               p76  Healthy/Background  Britanova
# 78           Caucasian               p53  Healthy/Background  Britanova
#
#                    disease_subtype
# 0   Healthy/Background - Britanova
# 1   Healthy/Background - Britanova
# 2   Healthy/Background - Britanova
# 3   Healthy/Background - Britanova
# 4   Healthy/Background - Britanova
# 14  Healthy/Background - Britanova
# 15  Healthy/Background - Britanova
# 16  Healthy/Background - Britanova
# 17  Healthy/Background - Britanova
# 18  Healthy/Background - Britanova
# 19  Healthy/Background - Britanova
# 20  Healthy/Background - Britanova
# 21  Healthy/Background - Britanova
# 22  Healthy/Background - Britanova
# 25  Healthy/Background - Britanova
# 26  Healthy/Background - Britanova
# 28  Healthy/Background - Britanova
# 31  Healthy/Background - Britanova
# 32  Healthy/Background - Britanova
# 33  Healthy/Background - Britanova
# 34  Healthy/Background - Britanova
# 35  Healthy/Background - Britanova
# 36  Healthy/Background - Britanova
# 37  Healthy/Background - Britanova
# 38  Healthy/Background - Britanova
# 39  Healthy/Background - Britanova
# 40  Healthy/Background - Britanova
# 41  Healthy/Background - Britanova
# 43  Healthy/Background - Britanova
# 52  Healthy/Background - Britanova
# 53  Healthy/Background - Britanova
# 54  Healthy/Background - Britanova
# 56  Healthy/Background - Britanova
# 70  Healthy/Background - Britanova
# 71  Healthy/Background - Britanova
# 72  Healthy/Background - Britanova
# 76  Healthy/Background - Britanova
# 77  Healthy/Background - Britanova
# 78  Healthy/Background - Britanova

# %%
external_metadata_export = external_metadata[
    [
        "specimen_label",
        "sex",
        "age",
        "ethnicity_condensed",
        "participant_label",
        "disease",
        "study_name",
        "disease_subtype",
    ]
]
external_metadata_export
# Out:
#    specimen_label sex  age ethnicity_condensed participant_label  \
# 0         A3-i101   F   36           Caucasian                p1
# 1         A3-i102   F   43           Caucasian                p2
# 2         A3-i106   F   43           Caucasian                p3
# 3         A3-i107   F   39           Caucasian                p4
# 4         A3-i110   F   34           Caucasian                p5
# 14        A2-i138   F   74           Caucasian               p15
# 15        A2-i139   M   75           Caucasian               p16
# 16        A2-i140   F   73           Caucasian               p17
# 17        A2-i141   M   71           Caucasian               p18
# 18        A4-i101   M   36           Caucasian               p19
# 19        A4-i102   M   37           Caucasian               p20
# 20        A4-i106   M   43           Caucasian               p21
# 21        A4-i107   M   39           Caucasian               p22
# 22        A4-i110   F   43           Caucasian               p23
# 25        A4-i124   M   66           Caucasian               p26
# 26        A4-i125   M   64           Caucasian               p27
# 28        A4-i128   F   62           Caucasian               p29
# 31        A4-i184   M   61           Caucasian               p32
# 32        A4-i185   F   61           Caucasian               p33
# 33        A4-i186   F   61           Caucasian               p34
# 34        A4-i188   F   61           Caucasian               p35
# 35        A4-i189   M   25           Caucasian               p36
# 36        A4-i190   M   25           Caucasian               p36
# 37        A4-i191   F   22           Caucasian               p37
# 38        A4-i192   F   24           Caucasian               p38
# 39        A4-i194   M   20           Caucasian               p39
# 40        A4-i195   F   21           Caucasian               p40
# 41         A5-S22   M   51           Caucasian               p41
# 43         A5-S20   F   51           Caucasian               p43
# 52         A5-S24   F   50           Caucasian               p52
# 53         A5-S23   M   50           Caucasian               p53
# 54         A5-S21   F   51           Caucasian               p54
# 56         A5-S19   F   55           Caucasian               p56
# 70        A6-I160   F   51           Caucasian               p70
# 71      A6-I215ob   F   51           Caucasian               p71
# 72        A6-I150   M   51           Caucasian               p72
# 76      A6-I200ob   M   27           Caucasian               p76
# 77      A6-I201ob   M   30           Caucasian               p76
# 78      A6-I202ob   M   47           Caucasian               p53
#
#                disease study_name                 disease_subtype
# 0   Healthy/Background  Britanova  Healthy/Background - Britanova
# 1   Healthy/Background  Britanova  Healthy/Background - Britanova
# 2   Healthy/Background  Britanova  Healthy/Background - Britanova
# 3   Healthy/Background  Britanova  Healthy/Background - Britanova
# 4   Healthy/Background  Britanova  Healthy/Background - Britanova
# 14  Healthy/Background  Britanova  Healthy/Background - Britanova
# 15  Healthy/Background  Britanova  Healthy/Background - Britanova
# 16  Healthy/Background  Britanova  Healthy/Background - Britanova
# 17  Healthy/Background  Britanova  Healthy/Background - Britanova
# 18  Healthy/Background  Britanova  Healthy/Background - Britanova
# 19  Healthy/Background  Britanova  Healthy/Background - Britanova
# 20  Healthy/Background  Britanova  Healthy/Background - Britanova
# 21  Healthy/Background  Britanova  Healthy/Background - Britanova
# 22  Healthy/Background  Britanova  Healthy/Background - Britanova
# 25  Healthy/Background  Britanova  Healthy/Background - Britanova
# 26  Healthy/Background  Britanova  Healthy/Background - Britanova
# 28  Healthy/Background  Britanova  Healthy/Background - Britanova
# 31  Healthy/Background  Britanova  Healthy/Background - Britanova
# 32  Healthy/Background  Britanova  Healthy/Background - Britanova
# 33  Healthy/Background  Britanova  Healthy/Background - Britanova
# 34  Healthy/Background  Britanova  Healthy/Background - Britanova
# 35  Healthy/Background  Britanova  Healthy/Background - Britanova
# 36  Healthy/Background  Britanova  Healthy/Background - Britanova
# 37  Healthy/Background  Britanova  Healthy/Background - Britanova
# 38  Healthy/Background  Britanova  Healthy/Background - Britanova
# 39  Healthy/Background  Britanova  Healthy/Background - Britanova
# 40  Healthy/Background  Britanova  Healthy/Background - Britanova
# 41  Healthy/Background  Britanova  Healthy/Background - Britanova
# 43  Healthy/Background  Britanova  Healthy/Background - Britanova
# 52  Healthy/Background  Britanova  Healthy/Background - Britanova
# 53  Healthy/Background  Britanova  Healthy/Background - Britanova
# 54  Healthy/Background  Britanova  Healthy/Background - Britanova
# 56  Healthy/Background  Britanova  Healthy/Background - Britanova
# 70  Healthy/Background  Britanova  Healthy/Background - Britanova
# 71  Healthy/Background  Britanova  Healthy/Background - Britanova
# 72  Healthy/Background  Britanova  Healthy/Background - Britanova
# 76  Healthy/Background  Britanova  Healthy/Background - Britanova
# 77  Healthy/Background  Britanova  Healthy/Background - Britanova
# 78  Healthy/Background  Britanova  Healthy/Background - Britanova

# %%
# remember, some patients have multiple samples as we investigated above
assert external_metadata_export["participant_label"].duplicated().any()
external_metadata_export[
    external_metadata_export["participant_label"].duplicated(keep=False)
].sort_values("participant_label")
# Out:
#    specimen_label sex  age ethnicity_condensed participant_label  \
# 35        A4-i189   M   25           Caucasian               p36
# 36        A4-i190   M   25           Caucasian               p36
# 53         A5-S23   M   50           Caucasian               p53
# 78      A6-I202ob   M   47           Caucasian               p53
# 76      A6-I200ob   M   27           Caucasian               p76
# 77      A6-I201ob   M   30           Caucasian               p76
#
#                disease study_name                 disease_subtype
# 35  Healthy/Background  Britanova  Healthy/Background - Britanova
# 36  Healthy/Background  Britanova  Healthy/Background - Britanova
# 53  Healthy/Background  Britanova  Healthy/Background - Britanova
# 78  Healthy/Background  Britanova  Healthy/Background - Britanova
# 76  Healthy/Background  Britanova  Healthy/Background - Britanova
# 77  Healthy/Background  Britanova  Healthy/Background - Britanova

# %%
# but each specimen listed once
assert not external_metadata_export["specimen_label"].duplicated().any()

# %%
external_metadata_export.to_csv(
    config.paths.metadata_dir
    / "generated.external_cohorts.healthy_tcr_britanova.participant_metadata.tsv",
    sep="\t",
    index=None,
)
