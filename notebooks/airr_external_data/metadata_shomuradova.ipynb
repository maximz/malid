# %% [markdown]
# Patient types:
#
# - `convalescent patients (CPs) `
#
# > To study the adaptive immune response to SARS-CoV-2, we recruited 34 CPs. According to the classification developed by the U.S. National Institutes of Health, the patients were categorized as having asymptomatic (n = 2), mild (n = 20), or moderate to severe (n = 12) disease.
# >
# > Peripheral blood was collected between days 17 and 49 (median day 34) after the onset of symptoms or a positive PCR test result.
#
# - `14 healthy volunteers recruited during the COVID-19 pandemic (HD(CoV)) with no symptoms and negative PCR test results`. However might have past exposure?
#    - Later they do say `All tested HD(CoV) sera lacked antibodies against SARS-CoV-2 antigens`
#    - and `IgGs from the HD(CoV) and HD(BB) groups showed no reactivity to the S protein of SARS-CoV-2 or its receptor-binding domain (RBD)`
#    - however **`This might indicate that some HD(CoV) patients were exposed to the virus but rapidly cleared it via T cells without developing a humoral response.`**
# - `10 samples of peripheral blood mononuclear cells (PBMCs) from biobanked healthy hematopoietic stem cell donors (HD(BB)), which were cryopreserved no later than September 2019`. The HD(BB) are not included in the download - why?
# - `10 serum samples from healthy blood donors that were cryopreserved no later than 2017 (HD(S)).` These were not sequenced

# %%
import pandas as pd
from malid import config

# %%
base_dir = config.paths.external_raw_data / "Shomuradova"

# %%
# specimen labels seen in the AIRR repertoire list
metadata = pd.read_csv(
    base_dir / "Shomuradova_ir_2022-09-24_0105_632e57c42f04a.tsv", sep="\t"
)
metadata = (
    metadata[
        [
            "repertoire_id",
            "subject_id",
            "sample_id",
            "cell_subset",
            "cell_phenotype",
            "medical_history",
            "disease_stage",
            "age_min",
            "sex",
        ]
    ]
    .rename(columns={"age_min": "age"})
    .assign(
        sex=metadata["sex"].replace({"male": "M", "female": "F"}),
        ethnicity_condensed="Caucasian",
    )
)
metadata
# Out:
#                 repertoire_id  subject_id               sample_id  \
# 0    5f07aa8739579433171763b2        1437           p1437_CD4ifny
# 1    5f07aa8839579433171763b3        1437           p1437_CD8ifny
# 2    5f07aa8839579433171763b4        1437              p1437_PBMC
# 3    5f07aa8839579433171763b5        1445           p1445_CD4ifny
# 4    5f07aa8939579433171763b6        1445           p1445_CD8ifny
# ..                        ...         ...                     ...
# 111  6047f712136a6d9249829490        1448  p1448_exp_YLQ_neg_beta
# 112  6047f712136a6d9249829492        1484  p1484_exp_RLQ_neg_beta
# 113  6047f713136a6d9249829493        1484  p1484_exp_RLQ_pos_beta
# 114  6047f713136a6d9249829495        1495  p1495_exp_RLQ_neg_beta
# 115  6047f714136a6d9249829497        1495  p1495_exp_RLQ_pos_beta
#
#                          cell_subset                 cell_phenotype  \
# 0         CD4-positive helper T cell                     CD4+ IFNγ+
# 1    CD8-positive, alpha-beta T cell                     CD8+ IFNγ+
# 2
# 3         CD4-positive helper T cell                     CD4+ IFNγ+
# 4    CD8-positive, alpha-beta T cell                     CD8+ IFNγ+
# ..                               ...                            ...
# 111  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: YLQPRTFLL-
# 112  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV-
# 113  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV+
# 114  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV-
# 115  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV+
#
#               medical_history disease_stage age sex ethnicity_condensed
# 0               COVID-19 Mild  Convalescent  28   M           Caucasian
# 1               COVID-19 Mild  Convalescent  28   M           Caucasian
# 2               COVID-19 Mild  Convalescent  28   M           Caucasian
# 3               COVID-19 Mild  Convalescent  32   M           Caucasian
# 4               COVID-19 Mild  Convalescent  32   M           Caucasian
# ..                        ...           ...  ..  ..                 ...
# 111  COVID-19 Moderate/severe  Convalescent  37   M           Caucasian
# 112                                          59   F           Caucasian
# 113                                          59   F           Caucasian
# 114  COVID-19 Moderate/severe  Convalescent  41   M           Caucasian
# 115  COVID-19 Moderate/severe  Convalescent  41   M           Caucasian
#
# [116 rows x 10 columns]

# %%
# specimen labels seen in the actual AIRR sequences export
specimen_labels = pd.read_csv(base_dir / "specimen_labels.txt", header=None)
specimen_labels
# Out:
#                             0
# 0    5f07aa8739579433171763b2
# 1    5f07aa8839579433171763b3
# 2    5f07aa8839579433171763b4
# 3    5f07aa8839579433171763b5
# 4    5f07aa8939579433171763b6
# ..                        ...
# 111  6047f712136a6d9249829490
# 112  6047f712136a6d9249829492
# 113  6047f713136a6d9249829493
# 114  6047f713136a6d9249829495
# 115  6047f714136a6d9249829497
#
# [116 rows x 1 columns]

# %%
# patient diagnosis/type extracted from paper
# we want to ignore HD(CoV) because they may have some Covid exposure. see notes above.
patient_status = pd.read_csv(base_dir / "Shomuradova_patient_metadata.csv")
patient_status
# Out:
#    patient     type             disease         severity
# 0    p1426       CP             Covid19             mild
# 1    p1428       CP             Covid19             mild
# 2    p1434       CP             Covid19             mild
# 3    p1435       CP             Covid19             mild
# 4    p1436       CP             Covid19             mild
# 5    p1437       CP             Covid19             mild
# 6    p1445       CP             Covid19             mild
# 7    p1446       CP             Covid19             mild
# 8    p1447       CP             Covid19             mild
# 9    p1448       CP             Covid19  moderate/severe
# 10   p1449       CP             Covid19             mild
# 11   p1452       CP             Covid19             mild
# 12   p1463       CP             Covid19  moderate/severe
# 13   p1465       CP             Covid19  moderate/severe
# 14   p1466       CP             Covid19             mild
# 15   p1470       CP             Covid19             mild
# 16   p1472       CP             Covid19     asymptomatic
# 17   p1473       CP             Covid19             mild
# 18   p1476       CP             Covid19  moderate/severe
# 19   p1480       CP             Covid19  moderate/severe
# 20   p1481       CP             Covid19  moderate/severe
# 21   p1482       CP             Covid19             mild
# 22   p1484       CP             Covid19     asymptomatic
# 23   p1486       CP             Covid19  moderate/severe
# 24   p1487       CP             Covid19  moderate/severe
# 25   p1489       CP             Covid19             mild
# 26   p1491       CP             Covid19             mild
# 27   p1494       CP             Covid19             mild
# 28   p1495       CP             Covid19  moderate/severe
# 29   p1499       CP             Covid19  moderate/severe
# 30   p1507       CP             Covid19             mild
# 31   p1531       CP             Covid19             mild
# 32   p1545       CP             Covid19  moderate/severe
# 33   p1551       CP             Covid19             mild
# 34    p001  HD(CoV)                 NaN              NaN
# 35    p003  HD(CoV)                 NaN              NaN
# 36   p1018  HD(CoV)                 NaN              NaN
# 37   p1048  HD(CoV)                 NaN              NaN
# 38   p1305  HD(CoV)                 NaN              NaN
# 39   p1329  HD(CoV)                 NaN              NaN
# 40   p1354  HD(CoV)                 NaN              NaN
# 41   p1425  HD(CoV)                 NaN              NaN
# 42   p1440  HD(CoV)                 NaN              NaN
# 43   p1477  HD(CoV)                 NaN              NaN
# 44    p846  HD(CoV)                 NaN              NaN
# 45    p856  HD(CoV)                 NaN              NaN
# 46    p952  HD(CoV)                 NaN              NaN
# 47   p1180   HD(BB)  Healthy/Background              NaN
# 48   p1235   HD(BB)  Healthy/Background              NaN
# 49   p1243   HD(BB)  Healthy/Background              NaN
# 50   p1309   HD(BB)  Healthy/Background              NaN
# 51   p1311   HD(BB)  Healthy/Background              NaN
# 52    p847   HD(BB)  Healthy/Background              NaN
# 53    p879   HD(BB)  Healthy/Background              NaN
# 54    p883   HD(BB)  Healthy/Background              NaN
# 55    p884   HD(BB)  Healthy/Background              NaN
# 56    p924   HD(BB)  Healthy/Background              NaN

# %%
metadata_annot = pd.merge(
    metadata,
    patient_status.assign(
        subject_id=patient_status["patient"].str.extract("(\d+)").astype(int)
    ),
    how="left",
    on="subject_id",
    validate="m:1",
)
metadata_annot
# Out:
#                 repertoire_id  subject_id               sample_id  \
# 0    5f07aa8739579433171763b2        1437           p1437_CD4ifny
# 1    5f07aa8839579433171763b3        1437           p1437_CD8ifny
# 2    5f07aa8839579433171763b4        1437              p1437_PBMC
# 3    5f07aa8839579433171763b5        1445           p1445_CD4ifny
# 4    5f07aa8939579433171763b6        1445           p1445_CD8ifny
# ..                        ...         ...                     ...
# 111  6047f712136a6d9249829490        1448  p1448_exp_YLQ_neg_beta
# 112  6047f712136a6d9249829492        1484  p1484_exp_RLQ_neg_beta
# 113  6047f713136a6d9249829493        1484  p1484_exp_RLQ_pos_beta
# 114  6047f713136a6d9249829495        1495  p1495_exp_RLQ_neg_beta
# 115  6047f714136a6d9249829497        1495  p1495_exp_RLQ_pos_beta
#
#                          cell_subset                 cell_phenotype  \
# 0         CD4-positive helper T cell                     CD4+ IFNγ+
# 1    CD8-positive, alpha-beta T cell                     CD8+ IFNγ+
# 2
# 3         CD4-positive helper T cell                     CD4+ IFNγ+
# 4    CD8-positive, alpha-beta T cell                     CD8+ IFNγ+
# ..                               ...                            ...
# 111  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: YLQPRTFLL-
# 112  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV-
# 113  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV+
# 114  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV-
# 115  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV+
#
#               medical_history disease_stage age sex ethnicity_condensed  \
# 0               COVID-19 Mild  Convalescent  28   M           Caucasian
# 1               COVID-19 Mild  Convalescent  28   M           Caucasian
# 2               COVID-19 Mild  Convalescent  28   M           Caucasian
# 3               COVID-19 Mild  Convalescent  32   M           Caucasian
# 4               COVID-19 Mild  Convalescent  32   M           Caucasian
# ..                        ...           ...  ..  ..                 ...
# 111  COVID-19 Moderate/severe  Convalescent  37   M           Caucasian
# 112                                          59   F           Caucasian
# 113                                          59   F           Caucasian
# 114  COVID-19 Moderate/severe  Convalescent  41   M           Caucasian
# 115  COVID-19 Moderate/severe  Convalescent  41   M           Caucasian
#
#     patient type  disease         severity
# 0     p1437   CP  Covid19             mild
# 1     p1437   CP  Covid19             mild
# 2     p1437   CP  Covid19             mild
# 3     p1445   CP  Covid19             mild
# 4     p1445   CP  Covid19             mild
# ..      ...  ...      ...              ...
# 111   p1448   CP  Covid19  moderate/severe
# 112   p1484   CP  Covid19     asymptomatic
# 113   p1484   CP  Covid19     asymptomatic
# 114   p1495   CP  Covid19  moderate/severe
# 115   p1495   CP  Covid19  moderate/severe
#
# [116 rows x 14 columns]

# %%
metadata_annot["type"].isna().value_counts()
# Out:
# False    116
# Name: type, dtype: int64

# %%
metadata_annot["type"].value_counts()
# Out:
# CP         113
# HD(CoV)      3
# Name: type, dtype: int64

# %%
metadata_annot.groupby("type")["subject_id"].nunique()
# Out:
# type
# CP         21
# HD(CoV)     1
# Name: subject_id, dtype: int64

# %%
metadata_annot.groupby("disease")["subject_id"].nunique()
# Out:
# disease
# Covid19    21
# Name: subject_id, dtype: int64

# %%
# HD(BB) not available. Covid19 only.
metadata_filtered = (
    metadata_annot[metadata_annot["disease"] == "Covid19"]
    .rename(columns={"repertoire_id": "specimen_label", "patient": "participant_label"})
    .assign(study_name="Shomuradova")
)
metadata_filtered["disease_subtype"] = (
    metadata_filtered["disease"] + " - " + metadata_filtered["severity"]
)
metadata_filtered
# Out:
#                specimen_label  subject_id               sample_id  \
# 0    5f07aa8739579433171763b2        1437           p1437_CD4ifny
# 1    5f07aa8839579433171763b3        1437           p1437_CD8ifny
# 2    5f07aa8839579433171763b4        1437              p1437_PBMC
# 3    5f07aa8839579433171763b5        1445           p1445_CD4ifny
# 4    5f07aa8939579433171763b6        1445           p1445_CD8ifny
# ..                        ...         ...                     ...
# 111  6047f712136a6d9249829490        1448  p1448_exp_YLQ_neg_beta
# 112  6047f712136a6d9249829492        1484  p1484_exp_RLQ_neg_beta
# 113  6047f713136a6d9249829493        1484  p1484_exp_RLQ_pos_beta
# 114  6047f713136a6d9249829495        1495  p1495_exp_RLQ_neg_beta
# 115  6047f714136a6d9249829497        1495  p1495_exp_RLQ_pos_beta
#
#                          cell_subset                 cell_phenotype  \
# 0         CD4-positive helper T cell                     CD4+ IFNγ+
# 1    CD8-positive, alpha-beta T cell                     CD8+ IFNγ+
# 2
# 3         CD4-positive helper T cell                     CD4+ IFNγ+
# 4    CD8-positive, alpha-beta T cell                     CD8+ IFNγ+
# ..                               ...                            ...
# 111  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: YLQPRTFLL-
# 112  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV-
# 113  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV+
# 114  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV-
# 115  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV+
#
#               medical_history disease_stage age sex ethnicity_condensed  \
# 0               COVID-19 Mild  Convalescent  28   M           Caucasian
# 1               COVID-19 Mild  Convalescent  28   M           Caucasian
# 2               COVID-19 Mild  Convalescent  28   M           Caucasian
# 3               COVID-19 Mild  Convalescent  32   M           Caucasian
# 4               COVID-19 Mild  Convalescent  32   M           Caucasian
# ..                        ...           ...  ..  ..                 ...
# 111  COVID-19 Moderate/severe  Convalescent  37   M           Caucasian
# 112                                          59   F           Caucasian
# 113                                          59   F           Caucasian
# 114  COVID-19 Moderate/severe  Convalescent  41   M           Caucasian
# 115  COVID-19 Moderate/severe  Convalescent  41   M           Caucasian
#
#     participant_label type  disease         severity   study_name  \
# 0               p1437   CP  Covid19             mild  Shomuradova
# 1               p1437   CP  Covid19             mild  Shomuradova
# 2               p1437   CP  Covid19             mild  Shomuradova
# 3               p1445   CP  Covid19             mild  Shomuradova
# 4               p1445   CP  Covid19             mild  Shomuradova
# ..                ...  ...      ...              ...          ...
# 111             p1448   CP  Covid19  moderate/severe  Shomuradova
# 112             p1484   CP  Covid19     asymptomatic  Shomuradova
# 113             p1484   CP  Covid19     asymptomatic  Shomuradova
# 114             p1495   CP  Covid19  moderate/severe  Shomuradova
# 115             p1495   CP  Covid19  moderate/severe  Shomuradova
#
#                disease_subtype
# 0               Covid19 - mild
# 1               Covid19 - mild
# 2               Covid19 - mild
# 3               Covid19 - mild
# 4               Covid19 - mild
# ..                         ...
# 111  Covid19 - moderate/severe
# 112     Covid19 - asymptomatic
# 113     Covid19 - asymptomatic
# 114  Covid19 - moderate/severe
# 115  Covid19 - moderate/severe
#
# [113 rows x 16 columns]

# %%
# if disease_stage is blank (with one space), it means asymptomatic
metadata_filtered[
    metadata_filtered["disease_stage"]
    .mask(metadata_filtered["disease_stage"].str.strip() == "")
    .isna()
]
# Out:
#                specimen_label  subject_id               sample_id  \
# 112  6047f712136a6d9249829492        1484  p1484_exp_RLQ_neg_beta
# 113  6047f713136a6d9249829493        1484  p1484_exp_RLQ_pos_beta
#
#                          cell_subset                 cell_phenotype  \
# 112  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV-
# 113  CD8-positive, alpha-beta T cell  CD3+ CD8+ epitope: RLQSLQTYV+
#
#     medical_history disease_stage age sex ethnicity_condensed  \
# 112                                59   F           Caucasian
# 113                                59   F           Caucasian
#
#     participant_label type  disease      severity   study_name  \
# 112             p1484   CP  Covid19  asymptomatic  Shomuradova
# 113             p1484   CP  Covid19  asymptomatic  Shomuradova
#
#             disease_subtype
# 112  Covid19 - asymptomatic
# 113  Covid19 - asymptomatic

# %%
# confirm our annotations
metadata_filtered[["medical_history", "severity"]].drop_duplicates()
# Out:
#               medical_history         severity
# 0               COVID-19 Mild             mild
# 9       COVID-19 Asymptomatic     asymptomatic
# 32   COVID-19 Moderate/Severe  moderate/severe
# 67   COVID-19 Moderate/severe  moderate/severe
# 112                               asymptomatic

# %%
# extract sample type
# "We analyzed the TCR repertoires of fluorescence-activated cell sorting (FACS)-sorted IFNγ-secreting CD8+/CD4+ cells and MHC-tetramer-positive populations as well as the total fraction of PBMCs by Illumina high-throughput sequencing"
metadata_filtered["sample_type"] = (
    metadata_filtered["sample_id"]
    .str.split("_")
    .str[1:]
    .apply(lambda arr: " ".join(arr))
)
metadata_filtered[["cell_phenotype", "cell_subset", "sample_type"]].drop_duplicates()
# Out:
#                    cell_phenotype                      cell_subset  \
# 0                      CD4+ IFNγ+       CD4-positive helper T cell
# 1                      CD8+ IFNγ+  CD8-positive, alpha-beta T cell
# 2
# 9                      CD4+ IFNγ+       CD4-positive helper T cell
# 10                     CD8+ IFNγ+  CD8-positive, alpha-beta T cell
# 11
# 15  CD3+ CD8+ epitope: KIADYNYKL-  CD8-positive, alpha-beta T cell
# 16  CD3+ CD8+ epitope: KIADYNYKL+  CD8-positive, alpha-beta T cell
# 17  CD3+ CD8+ epitope: LITGRLQSL-  CD8-positive, alpha-beta T cell
# 18  CD3+ CD8+ epitope: LITGRLQSL+  CD8-positive, alpha-beta T cell
# 19  CD3+ CD8+ epitope: RLNEVAKNL-  CD8-positive, alpha-beta T cell
# 20  CD3+ CD8+ epitope: RLQSLQTYV-  CD8-positive, alpha-beta T cell
# 21  CD3+ CD8+ epitope: RLQSLQTYV+  CD8-positive, alpha-beta T cell
# 22  CD3+ CD8+ epitope: YLQPRTFLL-  CD8-positive, alpha-beta T cell
# 23  CD3+ CD8+ epitope: YLQPRTFLL+  CD8-positive, alpha-beta T cell
# 36  CD3+ CD8+ epitope: ALNTLVKQL-  CD8-positive, alpha-beta T cell
# 37  CD3+ CD8+ epitope: ALNTLVKQL+  CD8-positive, alpha-beta T cell
# 38  CD3+ CD8+ epitope: LITGRLQSL-  CD8-positive, alpha-beta T cell
# 43  CD3+ CD8+ epitope: RLQSLQTYV+  CD8-positive, alpha-beta T cell
# 44       CD3+ CD8+ epitope: total  CD8-positive, alpha-beta T cell
# 45  CD3+ CD8+ epitope: YLQPRTFLL+  CD8-positive, alpha-beta T cell
# 46  CD3+ CD8+ epitope: YLQPRTFLL-  CD8-positive, alpha-beta T cell
# 48  CD3+ CD8+ epitope: FIAGLIAIV-  CD8-positive, alpha-beta T cell
# 49  CD3+ CD8+ epitope: FIAGLIAIV+  CD8-positive, alpha-beta T cell
# 50  CD3+ CD8+ epitope: LLFNKVTLA+  CD8-positive, alpha-beta T cell
# 53  CD3+ CD8+ epitope: VLNDILSRL-  CD8-positive, alpha-beta T cell
# 54  CD3+ CD8+ epitope: VLNDILSRL+  CD8-positive, alpha-beta T cell
# 61  CD3+ CD8+ epitope: RLQSLQTYV-  CD8-positive, alpha-beta T cell
#
#              sample_type
# 0                CD4ifny
# 1                CD8ifny
# 2                   PBMC
# 9                CD8ifny
# 10                  PBMC
# 11               CD4ifny
# 15      exp KIA neg beta
# 16      exp KIA pos beta
# 17      exp LIT neg beta
# 18      exp LIT pos beta
# 19      exp RLN neg beta
# 20      exp RLQ neg beta
# 21      exp RLQ pos beta
# 22      exp YLQ neg beta
# 23      exp YLQ pos beta
# 36      exp ALN neg beta
# 37      exp ALN pos beta
# 38  exp LIT KLP neg beta
# 43          RLQ pos beta
# 44            total beta
# 45          YLQ pos beta
# 46          YLQ neg beta
# 48          FIA neg beta
# 49          FIA pos beta
# 50           LL pos beta
# 53          VLN neg beta
# 54          VLN pos beta
# 61          RLQ neg beta

# %%
metadata_filtered.groupby(["cell_phenotype", "cell_subset", "sample_type"]).size()
# Out:
# cell_phenotype                 cell_subset                      sample_type
#                                                                 CD4ifny                  1
#                                                                 PBMC                    17
# CD3+ CD8+ epitope: ALNTLVKQL+  CD8-positive, alpha-beta T cell  exp ALN pos beta         1
# CD3+ CD8+ epitope: ALNTLVKQL-  CD8-positive, alpha-beta T cell  exp ALN neg beta         1
# CD3+ CD8+ epitope: FIAGLIAIV+  CD8-positive, alpha-beta T cell  FIA pos beta             1
# CD3+ CD8+ epitope: FIAGLIAIV-  CD8-positive, alpha-beta T cell  FIA neg beta             1
# CD3+ CD8+ epitope: KIADYNYKL+  CD8-positive, alpha-beta T cell  exp KIA pos beta         2
# CD3+ CD8+ epitope: KIADYNYKL-  CD8-positive, alpha-beta T cell  exp KIA neg beta         2
# CD3+ CD8+ epitope: LITGRLQSL+  CD8-positive, alpha-beta T cell  exp LIT pos beta         2
# CD3+ CD8+ epitope: LITGRLQSL-  CD8-positive, alpha-beta T cell  exp LIT KLP neg beta     1
#                                                                 exp LIT neg beta         1
# CD3+ CD8+ epitope: LLFNKVTLA+  CD8-positive, alpha-beta T cell  LL pos beta              1
# CD3+ CD8+ epitope: RLNEVAKNL-  CD8-positive, alpha-beta T cell  exp RLN neg beta         1
# CD3+ CD8+ epitope: RLQSLQTYV+  CD8-positive, alpha-beta T cell  RLQ pos beta             3
#                                                                 exp RLQ pos beta         8
# CD3+ CD8+ epitope: RLQSLQTYV-  CD8-positive, alpha-beta T cell  RLQ neg beta             1
#                                                                 exp RLQ neg beta         7
# CD3+ CD8+ epitope: VLNDILSRL+  CD8-positive, alpha-beta T cell  VLN pos beta             1
# CD3+ CD8+ epitope: VLNDILSRL-  CD8-positive, alpha-beta T cell  VLN neg beta             1
# CD3+ CD8+ epitope: YLQPRTFLL+  CD8-positive, alpha-beta T cell  YLQ pos beta             5
#                                                                 exp YLQ pos beta         6
# CD3+ CD8+ epitope: YLQPRTFLL-  CD8-positive, alpha-beta T cell  YLQ neg beta             5
#                                                                 exp YLQ neg beta         7
# CD3+ CD8+ epitope: total       CD8-positive, alpha-beta T cell  total beta               2
# CD4+ IFNγ+                     CD4-positive helper T cell       CD4ifny                 16
#                                                                 CD8ifny                  1
# CD8+ IFNγ+                     CD8-positive, alpha-beta T cell  CD8ifny                 17
#                                                                 PBMC                     1
# dtype: int64

# %%
# use total PBMC samples only. cell_phenotype and cell_subset must be blank
metadata_filtered = metadata_filtered[
    (metadata_filtered["sample_type"] == "PBMC")
    & (
        metadata_filtered["cell_phenotype"]
        .mask(metadata_filtered["cell_phenotype"].str.strip() == "")
        .isna()
    )
    & (
        metadata_filtered["cell_subset"]
        .mask(metadata_filtered["cell_subset"].str.strip() == "")
        .isna()
    )
]
metadata_filtered
# Out:
#                specimen_label  subject_id   sample_id cell_subset  \
# 2    5f07aa8839579433171763b4        1437  p1437_PBMC
# 5    5f07aa8939579433171763b7        1445  p1445_PBMC
# 8    5f07aa8a39579433171763ba        1473  p1473_PBMC
# 14   5f07aa8c39579433171763c0        1489  p1489_PBMC
# 66   6047f702136a6d924982945c        1434  p1434_PBMC
# 69   6047f703136a6d924982945f        1448  p1448_PBMC
# 72   6047f704136a6d9249829462        1449  p1449_PBMC
# 75   6047f704136a6d9249829465        1465  p1465_PBMC
# 81   6047f706136a6d924982946b        1480  p1480_PBMC
# 84   6047f707136a6d924982946e        1481  p1481_PBMC
# 87   6047f708136a6d9249829471        1482  p1482_PBMC
# 90   6047f709136a6d9249829474        1486  p1486_PBMC
# 93   6047f70a136a6d9249829477        1494  p1494_PBMC
# 96   6047f70b136a6d924982947a        1495  p1495_PBMC
# 99   6047f70c136a6d924982947d        1531  p1531_PBMC
# 101  6047f70c136a6d924982947f        1545  p1545_PBMC
# 104  6047f70d136a6d9249829482        1551  p1551_PBMC
#
#     cell_phenotype           medical_history disease_stage age sex  \
# 2                              COVID-19 Mild  Convalescent  28   M
# 5                              COVID-19 Mild  Convalescent  32   M
# 8                              COVID-19 Mild  Convalescent  31   F
# 14                             COVID-19 Mild  Convalescent  27   M
# 66                             COVID-19 Mild  Convalescent  28   M
# 69                  COVID-19 Moderate/severe  Convalescent  37   M
# 72                             COVID-19 Mild  Convalescent  34   F
# 75                  COVID-19 Moderate/severe  Convalescent  19   M
# 81                  COVID-19 Moderate/severe  Convalescent  29   M
# 84                  COVID-19 Moderate/severe  Convalescent  30   F
# 87                             COVID-19 Mild  Convalescent  36   F
# 90                  COVID-19 Moderate/severe  Convalescent  46   F
# 93                             COVID-19 Mild  Convalescent  36   F
# 96                  COVID-19 Moderate/severe  Convalescent  41   M
# 99                             COVID-19 Mild  Convalescent  23   M
# 101                 COVID-19 Moderate/severe  Convalescent  44   F
# 104                            COVID-19 Mild  Convalescent  24   M
#
#     ethnicity_condensed participant_label type  disease         severity  \
# 2             Caucasian             p1437   CP  Covid19             mild
# 5             Caucasian             p1445   CP  Covid19             mild
# 8             Caucasian             p1473   CP  Covid19             mild
# 14            Caucasian             p1489   CP  Covid19             mild
# 66            Caucasian             p1434   CP  Covid19             mild
# 69            Caucasian             p1448   CP  Covid19  moderate/severe
# 72            Caucasian             p1449   CP  Covid19             mild
# 75            Caucasian             p1465   CP  Covid19  moderate/severe
# 81            Caucasian             p1480   CP  Covid19  moderate/severe
# 84            Caucasian             p1481   CP  Covid19  moderate/severe
# 87            Caucasian             p1482   CP  Covid19             mild
# 90            Caucasian             p1486   CP  Covid19  moderate/severe
# 93            Caucasian             p1494   CP  Covid19             mild
# 96            Caucasian             p1495   CP  Covid19  moderate/severe
# 99            Caucasian             p1531   CP  Covid19             mild
# 101           Caucasian             p1545   CP  Covid19  moderate/severe
# 104           Caucasian             p1551   CP  Covid19             mild
#
#       study_name            disease_subtype sample_type
# 2    Shomuradova             Covid19 - mild        PBMC
# 5    Shomuradova             Covid19 - mild        PBMC
# 8    Shomuradova             Covid19 - mild        PBMC
# 14   Shomuradova             Covid19 - mild        PBMC
# 66   Shomuradova             Covid19 - mild        PBMC
# 69   Shomuradova  Covid19 - moderate/severe        PBMC
# 72   Shomuradova             Covid19 - mild        PBMC
# 75   Shomuradova  Covid19 - moderate/severe        PBMC
# 81   Shomuradova  Covid19 - moderate/severe        PBMC
# 84   Shomuradova  Covid19 - moderate/severe        PBMC
# 87   Shomuradova             Covid19 - mild        PBMC
# 90   Shomuradova  Covid19 - moderate/severe        PBMC
# 93   Shomuradova             Covid19 - mild        PBMC
# 96   Shomuradova  Covid19 - moderate/severe        PBMC
# 99   Shomuradova             Covid19 - mild        PBMC
# 101  Shomuradova  Covid19 - moderate/severe        PBMC
# 104  Shomuradova             Covid19 - mild        PBMC

# %%
# one sample left per patient

# %%
metadata_filtered["type"].value_counts()
# Out:
# CP    17
# Name: type, dtype: int64

# %%
metadata_filtered["disease"].value_counts()
# Out:
# Covid19    17
# Name: disease, dtype: int64

# %%
metadata_filtered.groupby("type")["subject_id"].nunique()
# Out:
# type
# CP    17
# Name: subject_id, dtype: int64

# %%
metadata_filtered.groupby("disease")["subject_id"].nunique()
# Out:
# disease
# Covid19    17
# Name: subject_id, dtype: int64

# %%
assert (metadata_filtered.groupby("subject_id").size() == 1).all()

# %%
# filter by subtype? not for now.

# %%
metadata_filtered["disease_subtype"].value_counts()
# Out:
# Covid19 - mild               10
# Covid19 - moderate/severe     7
# Name: disease_subtype, dtype: int64

# %%
metadata_filtered
# Out:
#                specimen_label  subject_id   sample_id cell_subset  \
# 2    5f07aa8839579433171763b4        1437  p1437_PBMC
# 5    5f07aa8939579433171763b7        1445  p1445_PBMC
# 8    5f07aa8a39579433171763ba        1473  p1473_PBMC
# 14   5f07aa8c39579433171763c0        1489  p1489_PBMC
# 66   6047f702136a6d924982945c        1434  p1434_PBMC
# 69   6047f703136a6d924982945f        1448  p1448_PBMC
# 72   6047f704136a6d9249829462        1449  p1449_PBMC
# 75   6047f704136a6d9249829465        1465  p1465_PBMC
# 81   6047f706136a6d924982946b        1480  p1480_PBMC
# 84   6047f707136a6d924982946e        1481  p1481_PBMC
# 87   6047f708136a6d9249829471        1482  p1482_PBMC
# 90   6047f709136a6d9249829474        1486  p1486_PBMC
# 93   6047f70a136a6d9249829477        1494  p1494_PBMC
# 96   6047f70b136a6d924982947a        1495  p1495_PBMC
# 99   6047f70c136a6d924982947d        1531  p1531_PBMC
# 101  6047f70c136a6d924982947f        1545  p1545_PBMC
# 104  6047f70d136a6d9249829482        1551  p1551_PBMC
#
#     cell_phenotype           medical_history disease_stage age sex  \
# 2                              COVID-19 Mild  Convalescent  28   M
# 5                              COVID-19 Mild  Convalescent  32   M
# 8                              COVID-19 Mild  Convalescent  31   F
# 14                             COVID-19 Mild  Convalescent  27   M
# 66                             COVID-19 Mild  Convalescent  28   M
# 69                  COVID-19 Moderate/severe  Convalescent  37   M
# 72                             COVID-19 Mild  Convalescent  34   F
# 75                  COVID-19 Moderate/severe  Convalescent  19   M
# 81                  COVID-19 Moderate/severe  Convalescent  29   M
# 84                  COVID-19 Moderate/severe  Convalescent  30   F
# 87                             COVID-19 Mild  Convalescent  36   F
# 90                  COVID-19 Moderate/severe  Convalescent  46   F
# 93                             COVID-19 Mild  Convalescent  36   F
# 96                  COVID-19 Moderate/severe  Convalescent  41   M
# 99                             COVID-19 Mild  Convalescent  23   M
# 101                 COVID-19 Moderate/severe  Convalescent  44   F
# 104                            COVID-19 Mild  Convalescent  24   M
#
#     ethnicity_condensed participant_label type  disease         severity  \
# 2             Caucasian             p1437   CP  Covid19             mild
# 5             Caucasian             p1445   CP  Covid19             mild
# 8             Caucasian             p1473   CP  Covid19             mild
# 14            Caucasian             p1489   CP  Covid19             mild
# 66            Caucasian             p1434   CP  Covid19             mild
# 69            Caucasian             p1448   CP  Covid19  moderate/severe
# 72            Caucasian             p1449   CP  Covid19             mild
# 75            Caucasian             p1465   CP  Covid19  moderate/severe
# 81            Caucasian             p1480   CP  Covid19  moderate/severe
# 84            Caucasian             p1481   CP  Covid19  moderate/severe
# 87            Caucasian             p1482   CP  Covid19             mild
# 90            Caucasian             p1486   CP  Covid19  moderate/severe
# 93            Caucasian             p1494   CP  Covid19             mild
# 96            Caucasian             p1495   CP  Covid19  moderate/severe
# 99            Caucasian             p1531   CP  Covid19             mild
# 101           Caucasian             p1545   CP  Covid19  moderate/severe
# 104           Caucasian             p1551   CP  Covid19             mild
#
#       study_name            disease_subtype sample_type
# 2    Shomuradova             Covid19 - mild        PBMC
# 5    Shomuradova             Covid19 - mild        PBMC
# 8    Shomuradova             Covid19 - mild        PBMC
# 14   Shomuradova             Covid19 - mild        PBMC
# 66   Shomuradova             Covid19 - mild        PBMC
# 69   Shomuradova  Covid19 - moderate/severe        PBMC
# 72   Shomuradova             Covid19 - mild        PBMC
# 75   Shomuradova  Covid19 - moderate/severe        PBMC
# 81   Shomuradova  Covid19 - moderate/severe        PBMC
# 84   Shomuradova  Covid19 - moderate/severe        PBMC
# 87   Shomuradova             Covid19 - mild        PBMC
# 90   Shomuradova  Covid19 - moderate/severe        PBMC
# 93   Shomuradova             Covid19 - mild        PBMC
# 96   Shomuradova  Covid19 - moderate/severe        PBMC
# 99   Shomuradova             Covid19 - mild        PBMC
# 101  Shomuradova  Covid19 - moderate/severe        PBMC
# 104  Shomuradova             Covid19 - mild        PBMC

# %%
# export
metadata_export = metadata_filtered[
    [
        "specimen_label",
        "participant_label",
        "disease",
        "study_name",
        "disease_subtype",
        "age",
        "sex",
        "ethnicity_condensed",
    ]
]
metadata_export
# Out:
#                specimen_label participant_label  disease   study_name  \
# 2    5f07aa8839579433171763b4             p1437  Covid19  Shomuradova
# 5    5f07aa8939579433171763b7             p1445  Covid19  Shomuradova
# 8    5f07aa8a39579433171763ba             p1473  Covid19  Shomuradova
# 14   5f07aa8c39579433171763c0             p1489  Covid19  Shomuradova
# 66   6047f702136a6d924982945c             p1434  Covid19  Shomuradova
# 69   6047f703136a6d924982945f             p1448  Covid19  Shomuradova
# 72   6047f704136a6d9249829462             p1449  Covid19  Shomuradova
# 75   6047f704136a6d9249829465             p1465  Covid19  Shomuradova
# 81   6047f706136a6d924982946b             p1480  Covid19  Shomuradova
# 84   6047f707136a6d924982946e             p1481  Covid19  Shomuradova
# 87   6047f708136a6d9249829471             p1482  Covid19  Shomuradova
# 90   6047f709136a6d9249829474             p1486  Covid19  Shomuradova
# 93   6047f70a136a6d9249829477             p1494  Covid19  Shomuradova
# 96   6047f70b136a6d924982947a             p1495  Covid19  Shomuradova
# 99   6047f70c136a6d924982947d             p1531  Covid19  Shomuradova
# 101  6047f70c136a6d924982947f             p1545  Covid19  Shomuradova
# 104  6047f70d136a6d9249829482             p1551  Covid19  Shomuradova
#
#                disease_subtype age sex ethnicity_condensed
# 2               Covid19 - mild  28   M           Caucasian
# 5               Covid19 - mild  32   M           Caucasian
# 8               Covid19 - mild  31   F           Caucasian
# 14              Covid19 - mild  27   M           Caucasian
# 66              Covid19 - mild  28   M           Caucasian
# 69   Covid19 - moderate/severe  37   M           Caucasian
# 72              Covid19 - mild  34   F           Caucasian
# 75   Covid19 - moderate/severe  19   M           Caucasian
# 81   Covid19 - moderate/severe  29   M           Caucasian
# 84   Covid19 - moderate/severe  30   F           Caucasian
# 87              Covid19 - mild  36   F           Caucasian
# 90   Covid19 - moderate/severe  46   F           Caucasian
# 93              Covid19 - mild  36   F           Caucasian
# 96   Covid19 - moderate/severe  41   M           Caucasian
# 99              Covid19 - mild  23   M           Caucasian
# 101  Covid19 - moderate/severe  44   F           Caucasian
# 104             Covid19 - mild  24   M           Caucasian

# %%
metadata_export.to_csv(
    config.paths.metadata_dir
    / "generated.external_cohorts.covid_tcr_shomuradova.participant_metadata.tsv",
    sep="\t",
    index=None,
)
