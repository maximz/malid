# %% [markdown]
# # Analyze metamodel performance on test set, with abstention
#
# > Train patient-level rollup model using existing base models trained on train-smaller set.

# %%
from pathlib import Path
from typing import Dict, Generator, List, Optional, Tuple, Union
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %matplotlib inline
import seaborn as sns
import genetools
from IPython.display import display, Markdown

# %%
from malid import config, logger
from malid.external.glmnet_wrapper import GlmnetLogitNetWrapper
from malid.train import train_metamodel
from malid.external import model_evaluation
from malid.datamodels import (
    TargetObsColumnEnum,
    GeneLocus,
)
from malid.trained_model_wrappers import BlendingMetamodel
from malid.external.genetools_plots import (
    plot_mean_and_standard_deviation_heatmap,
)

# %%
def _plot_feature_importances(
    plot_df: pd.DataFrame, model_name: str, xlabel: str, xmin_at_zero: bool
):
    """plot feature importances for binary/multiclass random forest or binary linear model,
    where we have one model across all classes, rather than OvR multiclass model"""
    fig, ax = plt.subplots(figsize=(4, plot_df.shape[1] / 2.5))

    try:
        # Convert any metamodel feature names to friendly names,
        # if they have not already been renamed to friendly names when grouping/summing subsets.
        plot_df = plot_df.rename(
            columns=lambda feature_name: BlendingMetamodel.convert_feature_name_to_friendly_name(
                feature_name
            )
        )

        if plot_df.shape[0] == 1:
            # Special case: single entry. Show scatter plot instead of box plot.
            ax.scatter(plot_df.iloc[0].values, plot_df.iloc[0].index)
            # Make spacing and y-axis order similar to default boxplot
            buffer = 0.5
            ax.set_ylim(-buffer, plot_df.shape[1] - 1 + buffer)
            ax.invert_yaxis()
        else:
            # Default: boxplot
            sns.boxplot(data=plot_df, orient="h", ax=ax)

        plt.title(
            f"{model_name} ({plot_df.shape[0]} fold{'s'[:plot_df.shape[0] != 1]})"
        )
        plt.xlabel(xlabel)
        if xmin_at_zero:
            plt.xlim(
                0,
            )
        return fig
    except Exception as err:
        # close figure just in case, some Jupyter does not try to display a broken figure
        plt.close(fig)
        # reraise
        raise err


def _sum_subsets_of_feature_importances(
    df: pd.DataFrame,
    subset_names: Optional[Dict[str, str]],
    drop_empty_subsets: bool = True,
):
    """Sum up feature importances by subsets.
    Subset_names is a dict mapping friendly_subset_name to regex to match columns (we match with "contains" operation).
    Drop_empty_subsets is whether to drop empty subsets (i.e. where no columns match the regex).
    Pass through as-is without summing if subset_names is not provided
    """
    if subset_names is not None:
        # get relevant columns for each subset
        sum_parts = {
            name: df.loc[:, df.columns.str.contains(regex)]
            for name, regex in subset_names.items()
        }

        if drop_empty_subsets:
            # drop subsets where no columns have matched
            sum_parts = {
                name: df_part
                for name, df_part in sum_parts.items()
                if not df_part.empty
            }

        if len(sum_parts) == 0:
            raise ValueError(
                f"Subset names {subset_names} not found in df columns {df.columns}"
            )

        # do the sums
        return pd.DataFrame.from_dict(
            {name: df_part.sum(axis=1) for name, df_part in sum_parts.items()},
            orient="columns",
        )

    # pass through as-is without summing if subset_names is not provided
    return df


def get_feature_importance_subsets_to_plot(
    gene_locus: GeneLocus,
) -> Dict[str, Union[Dict[str, str], None]]:
    model_component_names = [
        ("repertoire_stats", "Repertoire composition"),
        ("convergent_cluster_model", "CDR3 clustering"),
        ("sequence_model", "Language model"),
    ]
    demographics_include = {"Demographics": "^demographics"}
    interactions_include = {
        "Sequence x Demographic feature interactions": "^interaction"
    }
    return {
        "all": None,
        "by_locus": {
            f"{gene_locus_part.name}": f"^{gene_locus_part.name}:*"
            for gene_locus_part in gene_locus
        }
        | demographics_include
        | interactions_include,
        "by_model_component": {
            # Don't match if starts with interaction
            # i.e. match "BCR:sequence_model:Covid19" but not "interaction|BCR:sequence_model:Covid19|demographics:age".
            f"{model_component_friendly_name}": f"^(?:(?!interaction).)*{model_component_name}"
            for model_component_name, model_component_friendly_name in model_component_names
        }
        | demographics_include
        | interactions_include,
        "by_locus_and_model_component": {
            f"{model_component_friendly_name} ({gene_locus_part.name})": f"^{gene_locus_part.name}:{model_component_name}:*"
            for model_component_name, model_component_friendly_name in model_component_names
            for gene_locus_part in gene_locus
        }
        | demographics_include
        | interactions_include,
    }


def plot_multiclass_feature_importances(
    model_name: str,
    raw_coefs_mean: pd.DataFrame,
    raw_coefs_std: Optional[pd.DataFrame],
    gene_locus: GeneLocus,
    target_obs_column: TargetObsColumnEnum,
    metamodel_flavor: str,
    n_folds: int,
) -> Generator[Tuple[str, plt.Figure], None, None]:
    ## We will plot raw coefs, and also use absvals so we can combine features

    def _sort_plot_features(features_df: pd.DataFrame) -> pd.DataFrame:
        # Arrange feature columns in desired order:
        # 1. BCR : model1 : Covid19
        # 2. BCR : model2 : Covid19
        # 3. BCR : model3 : Covid19
        # 4. TCR : model1 : Covid19
        # 5. TCR : model2 : Covid19
        # 6. TCR : model3 : Covid19
        # 7. BCR : model1 : HIV
        # and so on
        column_order = features_df.columns.to_series().str.split(":", expand=True)
        if column_order.shape[1] >= 3:
            # this is true for the above examples
            column_order = column_order.sort_values([2, 0])
        else:
            # the demographics-only metamodel flavor has feature names with only one single colon
            column_order = column_order.sort_values([0])
        return features_df[column_order.index]

    raw_coefs_mean = _sort_plot_features(raw_coefs_mean)
    if raw_coefs_std is not None:
        raw_coefs_std = _sort_plot_features(raw_coefs_std)

    diverging_color_cmap = "RdBu_r"
    # Cut cmap by 15% from both sides, so that we don't have dark blue and dark red at the extremes, which are hard to distinguish
    # https://stackoverflow.com/a/18926541/130164
    diverging_color_cmap = matplotlib.cm.get_cmap(name=diverging_color_cmap)
    diverging_color_cmap = diverging_color_cmap.from_list(
        name=f"{diverging_color_cmap.name}_truncated",
        colors=diverging_color_cmap(np.linspace(0.15, 0.85, 256)),
        N=256,
    )

    def _plot(
        features_df: pd.DataFrame,
        label: str,
        cmap_diverging: bool,
        require_sum_to_1: bool,
        make_percentage: bool = False,
    ):
        # autosize
        figsize = (features_df.shape[0] * 1.0, features_df.shape[1] / 2.5)

        if require_sum_to_1 and not np.allclose(features_df.sum(axis=1), 1):
            raise ValueError("Sum of feature importances is not 1")
        if make_percentage:
            # Turn fractions into percentages
            if not require_sum_to_1:
                raise ValueError("make_percentage requires require_sum_to_1")
            features_df = features_df * 100

        # Convert any metamodel feature names to friendly names,
        # if they have not already been renamed to friendly names when grouping/summing subsets.
        features_df = features_df.rename(
            columns=lambda feature_name: BlendingMetamodel.convert_feature_name_to_friendly_name(
                feature_name
            )
        )

        fig, ax = plt.subplots(figsize=figsize)

        try:
            # Create dedicated colorbar axis
            colorbar_ax = inset_axes(
                ax,
                width="80%",  # relative unit
                height=0.25,  # in inches
                loc="lower center",
                borderpad=-5,  # create space
            )
            sns.heatmap(
                # plot transpose, so features are on y-axis
                features_df.T,
                center=0 if cmap_diverging else None,
                linewidths=0.5,
                cmap=diverging_color_cmap
                if cmap_diverging
                else "Blues",  # sns.color_palette("vlag", as_cmap=True) is another good diverging
                ax=ax,
                # Put colorbar on bottom
                cbar_kws={"label": label, "orientation": "horizontal"},
                cbar_ax=colorbar_ax,
                # plot all tick labels
                xticklabels=True,
                yticklabels=True,
            )

            # Adjust tick labels
            ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
            ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
            genetools.plots.wrap_tick_labels(
                ax=ax, wrap_x_axis=True, wrap_y_axis=False, wrap_amount=12
            )

            # set global "current axes" back to main axes,
            # so that any calls like plt.title target main ax rather than colorbar_ax
            plt.sca(ax)
            return fig, ax
        except Exception as err:
            # close figure just in case, some Jupyter does not try to display a broken figure
            plt.close(fig)
            # reraise
            raise err

    # Plot mean
    try:
        fig, ax = _plot(
            _sort_plot_features(raw_coefs_mean),
            label="Coefficient mean",
            cmap_diverging=True,
            require_sum_to_1=False,
        )
        ax.set_title(
            f"Feature coefficients, each class versus the rest (mean over {n_folds} folds)"
        )
        yield (f"raw_coefs.mean", fig)
    except Exception as err:
        logger.warning(
            f"Failed to plot {model_name}, {gene_locus}, {target_obs_column}, metamodel flavor {metamodel_flavor} multiclass raw_coefs.mean with error: {err}"
        )

    if raw_coefs_std is not None:
        # Plot std
        try:
            fig, ax = _plot(
                _sort_plot_features(raw_coefs_std),
                label="Coefficient stdev",
                cmap_diverging=False,
                require_sum_to_1=False,
            )
            ax.set_title(
                f"Feature coefficients, each class versus the rest (stdev over {n_folds} folds)"
            )
            yield (f"raw_coefs.stdev", fig)
        except Exception as err:
            logger.warning(
                f"Failed to plot {model_name}, {gene_locus}, {target_obs_column}, metamodel flavor {metamodel_flavor} multiclass raw_coefs.stdev with error: {err}"
            )

        # Plot mean and standard deviation together
        combined = pd.merge(
            raw_coefs_mean.rename_axis(index="class")
            .reset_index()
            .melt(
                id_vars=["class"],
                value_vars=raw_coefs_mean.columns,
                var_name="feature",
                value_name="mean",
            ),
            raw_coefs_std.rename_axis(index="class")
            .reset_index()
            .melt(
                id_vars=["class"],
                value_vars=raw_coefs_std.columns,
                var_name="feature",
                value_name="stdev",
            ),
            on=["class", "feature"],
            how="inner",
            validate="1:1",
        )
        # Convert raw metamodel feature names to friendly names
        combined["feature"] = combined["feature"].apply(
            BlendingMetamodel.convert_feature_name_to_friendly_name
        )

        try:
            fig, ax = plot_mean_and_standard_deviation_heatmap(
                data=combined,
                x_axis_key="class",
                y_axis_key="feature",
                mean_key="mean",
                standard_deviation_key="stdev",
                color_cmap=diverging_color_cmap,
                color_vcenter=0,
            )
            # TODO: make hierarchical y-axis labels (https://stackoverflow.com/questions/19184484/how-to-add-group-labels-for-bar-charts, https://stackoverflow.com/questions/37934242/hierarchical-axis-labeling-in-matplotlib-python)
            ax.set_title(
                f"Feature coefficients, each class versus the rest (over {n_folds} folds)"
            )
            yield (f"raw_coefs", fig)
        except Exception as err:
            logger.warning(
                f"Failed to plot {model_name}, {gene_locus}, {target_obs_column}, metamodel flavor {metamodel_flavor} multiclass raw_coefs (mean+stdev together) with error: {err}"
            )

    ## Report aggregate feature importance of several features in a linear model
    # e.g. I'd like to say something about how much all the language model features contribute to the metamodel, vs all the CDR3 clustering features.
    # I believe you can [sum feature importances](https://stats.stackexchange.com/questions/311488/summing-feature-importance-in-scikit-learn-for-a-set-of-features) for a set of features in a random forest.
    # for a linear model, I suppose I could take the absolute value of the coefs and sum them for something like "overall effect strength from this set of features".

    # Convert to absolute value, and divide by the sum of absolute values of all coefficients for "percent contribution"
    normalized_coefs = genetools.stats.normalize_rows(np.abs(raw_coefs_mean))
    for fig_name, subset_names in get_feature_importance_subsets_to_plot(
        gene_locus
    ).items():
        # sum up by origin of feature importances and replot.
        try:
            logger.debug(f"{model_name} absval_coefs {fig_name} across folds")
            fig, ax = _plot(
                _sum_subsets_of_feature_importances(
                    df=normalized_coefs, subset_names=subset_names
                ),
                label="Percent contribution",  # "Coefficient absval, percent contribution",
                cmap_diverging=False,
                require_sum_to_1=True,
                make_percentage=True,
            )
            plt.title(
                f"{model_name} feature percent contributions\neach class versus the rest\n(averaged over {n_folds} folds)"
            )
            yield (f"absval_coefs.{fig_name}", fig)
        except Exception as err:
            # Skip broken figures
            # One possible cause is that the feature names for this metamodel flavor don't correspond to what get_feature_importance_subsets_to_plot() is producing.
            logger.warning(
                f"Failed to plot {model_name}, {gene_locus}, {target_obs_column}, metamodel flavor {metamodel_flavor} feature percent contributions for figure name absval_coefs.{fig_name}, subset names {subset_names}: {err}"
            )


def analyze_feature_importances(
    model_name: str,
    model_global_performance: model_evaluation.ModelGlobalPerformance,
    gene_locus: GeneLocus,
    target_obs_column: TargetObsColumnEnum,
    metamodel_flavor: str,
    highres_results_output_prefix: Path,
    global_fold_classifier: Optional[BlendingMetamodel],
):
    """Get and analyze feature importances."""
    # First, check if model is binary in each fold
    is_binary = all(
        len(per_fold_output.class_names) == 2
        for per_fold_output in model_global_performance.per_fold_outputs.values()
    )
    if (
        global_fold_classifier is not None
        and (len(global_fold_classifier.classes_) == 2) != is_binary
    ):
        # Sanity check
        logger.warning(
            f"Ignoring global fold classifier for {model_name} because cross validation is_binary={is_binary} does not match global fold classes count = {len(global_fold_classifier.classes_)}"
        )
        global_fold_classifier = None

    # Depending on the model type (tree vs linear model; binary vs multiclass), we will retrieve and plot feature importances differently.
    # (Tree models are always a single model across all classes, regardless of whether classification target is binary or multiclass,
    # whereas multiclass linear models may be trained separately for each class.)
    is_tree = model_name in ["rf_multiclass", "xgboost"]
    is_linear_model = model_name in [
        "linearsvm_ovr",
        "lasso_cv",
        "ridge_cv",
        "elasticnet_cv",
        "lasso_multiclass",
    ]

    if is_tree or (is_linear_model and is_binary):
        # Get feature importances for each fold
        feature_importances_cross_validation_df: Union[
            pd.DataFrame, None
        ] = model_global_performance.feature_importances
        if feature_importances_cross_validation_df is None:
            raise ValueError(f"No feature importances available for {model_name}")
        feature_importances_to_plot = [(feature_importances_cross_validation_df, "")]

        if global_fold_classifier is not None:
            global_fold_feature_importances = (
                model_evaluation._extract_feature_importances(
                    global_fold_classifier._inner
                )
            )
            global_fold_feature_names = model_evaluation._get_feature_names(
                global_fold_classifier._inner
            )
            if global_fold_feature_importances is None:
                raise ValueError(
                    f"No feature importances available for {model_name} (global fold)"
                )
            feature_importances_to_plot.append(
                (
                    pd.Series(
                        global_fold_feature_importances,
                        index=global_fold_feature_names,
                        name=-1,
                    )
                    .to_frame()
                    .T,
                    "_global_fold",
                )
            )

        # Plot feature importances.
        for (
            feature_importances,
            overall_name,
        ) in feature_importances_to_plot:
            if is_tree:
                for (
                    fig_name,
                    subset_names,
                ) in get_feature_importance_subsets_to_plot(gene_locus).items():
                    # sum up by origin of feature importances and replot.
                    try:
                        fig = _plot_feature_importances(
                            plot_df=_sum_subsets_of_feature_importances(
                                df=feature_importances,
                                subset_names=subset_names,
                            ),
                            model_name=model_name,
                            xlabel="Feature importance",
                            # Values are all positive for tree models
                            xmin_at_zero=True,
                        )
                        genetools.plots.savefig(
                            fig,
                            f"{highres_results_output_prefix}.feature_importances{overall_name}.{model_name}.{fig_name}.png",
                            dpi=300,
                        )
                        plt.close(fig)
                    except Exception as err:
                        # Skip broken figures
                        # One possible cause is that the feature names for this metamodel flavor don't correspond to what get_feature_importance_subsets_to_plot() is producing.
                        logger.warning(
                            f"Failed to plot {model_name} feature importances{overall_name} for {gene_locus}, {target_obs_column}, metamodel flavor {metamodel_flavor}, with figure name {fig_name} and subset names {subset_names}: {err}"
                        )

            elif is_linear_model:
                for (
                    feature_importances,
                    overall_name,
                ) in feature_importances_to_plot:
                    # TODO: Add normalization of coefficients and summing of subsets (nontrivial for linear model)
                    # For now only plot all the features - don't group by subset.
                    fig = _plot_feature_importances(
                        plot_df=feature_importances,
                        model_name=model_name,
                        xlabel="Feature coefficient",
                        # coefficients are not necessarily positive
                        xmin_at_zero=False,
                    )
                    genetools.plots.savefig(
                        fig,
                        f"{highres_results_output_prefix}.feature_importances{overall_name}.{model_name}.all.png",
                        dpi=300,
                    )
                    plt.close(fig)

    elif is_linear_model and not is_binary:
        # Many OvR models for each class vs the rest
        raw_coefs: Optional[
            Dict[int, pd.DataFrame]
        ] = model_global_performance.multiclass_feature_importances
        if raw_coefs is None:
            raise ValueError(
                f"No feature importances available for multiclass {model_name}"
            )

        ## Combine multiclass feature importances across folds:
        # The coefs are comparable across folds because the inputs to the model were standardized.

        # Create 3D array from these 2D arrays - making sure that the index and column order is the same across folds.
        first_df = next(iter(raw_coefs.values()))
        try:
            raw_coefs_data: np.ndarray = np.array(
                [df.loc[first_df.index][first_df.columns] for df in raw_coefs.values()]
            )
        except Exception as err:
            logger.warning(
                f"Could not combine feature coefficients across folds for multiclass linear model {model_name} ({gene_locus}, {target_obs_column}, metamodel flavor {metamodel_flavor}), possibly because of missing classes. Skipping feature importance plots with this error: {err}"
            )
            # skip this model
            return

        # Extract mean and standard deviation, and repack in dataframe
        raw_coefs_mean: pd.DataFrame = pd.DataFrame(
            np.mean(raw_coefs_data, axis=0),
            index=first_df.index,
            columns=first_df.columns,
        )
        raw_coefs_std: pd.DataFrame = pd.DataFrame(
            np.std(raw_coefs_data, axis=0),
            index=first_df.index,
            columns=first_df.columns,
        )

        raw_coefs_mean.to_csv(
            f"{highres_results_output_prefix}.feature_importances.{model_name}.raw_coefs_mean.tsv",
            sep="\t",
        )
        raw_coefs_std.to_csv(
            f"{highres_results_output_prefix}.feature_importances.{model_name}.raw_coefs_std.tsv",
            sep="\t",
        )

        for fig_name, fig in plot_multiclass_feature_importances(
            model_name=model_name,
            raw_coefs_mean=raw_coefs_mean,
            raw_coefs_std=raw_coefs_std,
            gene_locus=gene_locus,
            target_obs_column=target_obs_column,
            metamodel_flavor=metamodel_flavor,
            n_folds=len(raw_coefs),
        ):
            fname = f"{highres_results_output_prefix}.feature_importances.{model_name}.{fig_name}.png"
            logger.debug(f"{fig_name} -> {fname}")
            genetools.plots.savefig(
                fig,
                fname,
                dpi=300,
            )
            plt.close(fig)

        if global_fold_classifier is not None:
            # Also plot global fold coefficients on their own. (We will pass them as raw_coefs_mean (without running a mean), with raw_coefs_std set to None)
            global_fold_feature_importances = (
                model_evaluation._extract_multiclass_feature_importances(
                    global_fold_classifier._inner
                )
            )
            global_fold_feature_names = model_evaluation._get_feature_names(
                global_fold_classifier._inner
            )
            if global_fold_feature_importances is None:
                raise ValueError(
                    f"No feature importances available for multiclass {model_name} (global fold)"
                )
            global_fold_feature_importances = pd.DataFrame(
                global_fold_feature_importances,
                index=global_fold_classifier.classes_,
                columns=global_fold_feature_names,
            )
            global_fold_feature_importances.to_csv(
                f"{highres_results_output_prefix}.feature_importances.{model_name}.raw_coefs.global_fold.tsv",
                sep="\t",
            )
            for (fig_name, fig,) in plot_multiclass_feature_importances(
                model_name=model_name,
                raw_coefs_mean=global_fold_feature_importances,
                raw_coefs_std=None,
                gene_locus=gene_locus,
                target_obs_column=target_obs_column,
                metamodel_flavor=metamodel_flavor,
                n_folds=1,
            ):
                fname = f"{highres_results_output_prefix}.feature_importances_global_fold.{model_name}.{fig_name}.png"
                logger.debug(f"{fig_name} -> {fname}")
                genetools.plots.savefig(
                    fig,
                    fname,
                    dpi=300,
                )
                plt.close(fig)
    else:
        logger.warning(
            f"Feature importances not plotted for {model_name}: not a recognized tree or linear model."
        )

# %%
def run_analysis(gene_locus: GeneLocus, target_obs_column: TargetObsColumnEnum):
    base_model_train_fold_name = "train_smaller"
    metamodel_fold_label_train = "validation"

    try:
        flavors = train_metamodel.get_metamodel_flavors(
            gene_locus=gene_locus,
            target_obs_column=target_obs_column,
            fold_id=config.all_fold_ids[0],
            base_model_train_fold_name=base_model_train_fold_name,
        )
    except Exception as err:
        logger.warning(
            f"Failed to generate metamodel flavors for {gene_locus}, {target_obs_column}: {err}"
        )
        return
    for metamodel_flavor, metamodel_config in flavors.items():
        # should already exist:
        metamodels_base_dir = BlendingMetamodel._get_metamodel_base_dir(
            gene_locus=gene_locus,
            target_obs_column=target_obs_column,
            metamodel_flavor=metamodel_flavor,
        )

        _output_suffix = (
            Path(gene_locus.name) / target_obs_column.name / metamodel_flavor
        )
        # might not exist yet:
        output_base_dir = (
            config.paths.second_stage_blending_metamodel_output_dir / _output_suffix
        )
        highres_output_base_dir = (
            config.paths.high_res_outputs_dir / "metamodel" / _output_suffix
        )
        output_base_dir.mkdir(parents=True, exist_ok=True)
        highres_output_base_dir.mkdir(parents=True, exist_ok=True)

        fname_prefix = f"{base_model_train_fold_name}_applied_to_{metamodel_fold_label_train}_model"
        model_prefix = metamodels_base_dir / fname_prefix
        results_output_prefix = output_base_dir / fname_prefix
        highres_results_output_prefix = highres_output_base_dir / fname_prefix

        try:
            # Load and summarize
            experiment_set = model_evaluation.ExperimentSet.load_from_disk(
                output_prefix=model_prefix
            )

            # Note that default y_true from BlendingMetamodel._featurize() is target_obs_column.value.blended_evaluation_column_name
            # Use DROP_INCOMPLETE_FOLDS setting because alternate classification targets might not be well-split in the small validation set of the cross-validation folds that were designed to stratify disease.
            # In the cases of some classification targets, we might need to automatically drop folds that have only a single class in the metamodel training data (i.e. in the validation set).
            experiment_set_global_performance = experiment_set.summarize(
                remove_incomplete_strategy=model_evaluation.RemoveIncompleteStrategy.DROP_INCOMPLETE_FOLDS
            )
            experiment_set_global_performance.export_all_models(
                func_generate_classification_report_fname=lambda model_name: f"{results_output_prefix}.classification_report.test_set_performance.{model_name}.txt",
                func_generate_confusion_matrix_fname=lambda model_name: f"{results_output_prefix}.confusion_matrix.test_set_performance.{model_name}.png",
                dpi=300,
            )
            combined_stats = (
                experiment_set_global_performance.get_model_comparison_stats(sort=True)
            )
            combined_stats.to_csv(
                f"{results_output_prefix}.compare_model_scores.test_set_performance.tsv",
                sep="\t",
            )
            display(
                Markdown(
                    f"## {gene_locus}, {target_obs_column}, metamodel flavor {metamodel_flavor} from {model_prefix} to {results_output_prefix}"
                )
            )
            print(metamodel_config)
            display(combined_stats)

            # Redo, but (potentially) override y_true to pass in e.g. disease with past exposures separated out (delinates past exposures on ground truth axis)
            # For cleaner confusion matrices
            # (But this changes global score metrics)
            experiment_set.summarize(
                global_evaluation_column_name=target_obs_column.value.confusion_matrix_expanded_column_name,
                remove_incomplete_strategy=model_evaluation.RemoveIncompleteStrategy.DROP_INCOMPLETE_FOLDS,
            ).export_all_models(
                func_generate_classification_report_fname=lambda model_name: f"{highres_results_output_prefix}.classification_report.test_set_performance.{model_name}.expanded_confusion_matrix.txt",
                func_generate_confusion_matrix_fname=lambda model_name: f"{highres_results_output_prefix}.confusion_matrix.test_set_performance.{model_name}.expanded_confusion_matrix.png",
                confusion_matrix_true_label="Patient of origin - expanded",
                dpi=300,
            )

            if target_obs_column == TargetObsColumnEnum.disease:
                # Redo, but (potentially) override y_true to pass in disease_subtype for ground truth axis
                # (But this changes global score metrics)
                experiment_set.summarize(
                    global_evaluation_column_name="disease_subtype",
                    remove_incomplete_strategy=model_evaluation.RemoveIncompleteStrategy.DROP_INCOMPLETE_FOLDS,
                ).export_all_models(
                    func_generate_classification_report_fname=lambda model_name: f"{highres_results_output_prefix}.classification_report.test_set_performance.{model_name}.expanded_confusion_matrix_disease_subtype.txt",
                    func_generate_confusion_matrix_fname=lambda model_name: f"{highres_results_output_prefix}.confusion_matrix.test_set_performance.{model_name}.expanded_confusion_matrix_disease_subtype.png",
                    confusion_matrix_true_label="Patient of origin - subtype",
                    dpi=300,
                )

                # Also resummarize by a combined variable of disease + ethnicity
                # But first, fillna on ethnicity column to change nans to "Unknown"
                experiment_set_modified_ethnicity_metadata_column = (
                    # Create a copy of the experiment_set, to not disturb original metadata dataframes
                    experiment_set.copy()
                )
                for (
                    model_single_fold_performance
                ) in (
                    experiment_set_modified_ethnicity_metadata_column.model_outputs.values()
                ):
                    # Modify every model_single_fold_performance's metadata: fillna on the ethnicity_condensed column
                    for df in [
                        model_single_fold_performance.test_metadata,
                        model_single_fold_performance.test_abstention_metadata,
                    ]:
                        if df is None or df.shape[0] == 0:
                            continue
                        df["ethnicity_condensed"].fillna("Unknown", inplace=True)
                experiment_set_modified_ethnicity_metadata_column.summarize(
                    global_evaluation_column_name=[
                        model_evaluation.Y_TRUE_VALUES,
                        "ethnicity_condensed",
                    ],
                    remove_incomplete_strategy=model_evaluation.RemoveIncompleteStrategy.DROP_INCOMPLETE_FOLDS,
                ).export_all_models(
                    func_generate_classification_report_fname=lambda model_name: f"{highres_results_output_prefix}.classification_report.test_set_performance.{model_name}.expanded_confusion_matrix_ethnicity_condensed.txt",
                    func_generate_confusion_matrix_fname=lambda model_name: f"{highres_results_output_prefix}.confusion_matrix.test_set_performance.{model_name}.expanded_confusion_matrix_ethnicity_condensed.png",
                    confusion_matrix_true_label="Patient of origin - ancestry",
                    dpi=300,
                )

                # Also resummarize by a combined variable of disease + age_group_pediatric
                # But first, create this column, because it may not be set on older metamodel runs
                # (TODO: Remove redundant column creation - should be available on new runs. But keep the intelligent fillna behavior.)
                experiment_set_modified_metadata_age_pediatric_column = (
                    # Create a copy of the experiment_set, to not disturb original metadata dataframes
                    experiment_set.copy()
                )
                for (
                    model_single_fold_performance
                ) in (
                    experiment_set_modified_metadata_age_pediatric_column.model_outputs.values()
                ):
                    # Modify every model_single_fold_performance's metadata: create age_group_pediatric column
                    for df in [
                        model_single_fold_performance.test_metadata,
                        model_single_fold_performance.test_abstention_metadata,
                    ]:
                        if df is None or df.shape[0] == 0:
                            continue
                        df.loc[df["age"] < 18, "age_group_pediatric"] = "under 18"
                        df.loc[df["age"] >= 18, "age_group_pediatric"] = "18+"

                        # Fill NaNs intelligently:
                        # We know we have very few children cohorts and they are clearly indicated in the study name.
                        # If study name indicates that this is a pediatric cohort, set to "under 18". Otherwise set to 18+.
                        slice_children = df["study_name"].str.contains(
                            "pediatric|children", regex=True, case=False
                        )
                        df.loc[slice_children, "age_group_pediatric"] = df.loc[
                            slice_children, "age_group_pediatric"
                        ].fillna("under 18")
                        df["age_group_pediatric"].fillna("18+", inplace=True)
                experiment_set_modified_metadata_age_pediatric_column.summarize(
                    global_evaluation_column_name=[
                        model_evaluation.Y_TRUE_VALUES,
                        "age_group_pediatric",
                    ],
                    remove_incomplete_strategy=model_evaluation.RemoveIncompleteStrategy.DROP_INCOMPLETE_FOLDS,
                ).export_all_models(
                    func_generate_classification_report_fname=lambda model_name: f"{highres_results_output_prefix}.classification_report.test_set_performance.{model_name}.expanded_confusion_matrix_age_group_pediatric.txt",
                    func_generate_confusion_matrix_fname=lambda model_name: f"{highres_results_output_prefix}.confusion_matrix.test_set_performance.{model_name}.expanded_confusion_matrix_age_group_pediatric.png",
                    confusion_matrix_true_label="Patient of origin - pediatric vs adult",
                    dpi=300,
                )

            for (
                model_name,
                model_global_performance,
            ) in experiment_set_global_performance.model_global_performances.items():
                # review classification for each specimen
                individual_classifications = model_global_performance.get_all_entries()
                individual_classifications.to_csv(
                    f"{highres_results_output_prefix}.classification_raw_per_specimen.test_set_performance.{model_name}.with_abstention.tsv",
                    sep="\t",
                    index=None,
                )

                # filter to mistakes (including abstentions)
                mistakes = individual_classifications[
                    individual_classifications["y_true"]
                    != individual_classifications["y_pred"]
                ]
                mistakes.to_csv(
                    f"{highres_results_output_prefix}.classification_errors.test_set_performance.{model_name}.with_abstention.tsv",
                    sep="\t",
                    index=None,
                )

                # filter further to abstentions
                abstentions = individual_classifications[
                    individual_classifications["y_pred"]
                    == model_global_performance.abstain_label
                ]
                abstentions.to_csv(
                    f"{highres_results_output_prefix}.classification_abstentions.test_set_performance.{model_name}.with_abstention.tsv",
                    sep="\t",
                    index=None,
                )

                # label correct/incorrect
                individual_classifications["classification_success"] = "Correct"
                individual_classifications.loc[
                    individual_classifications["y_true"]
                    != individual_classifications["y_pred"],
                    "classification_success",
                ] = "Incorrect"

                # Plot difference between top two predicted probabilities, p1 - p2,
                # and difference in logits (log odds) of the top two classes, log(p1/(1-p1)) - log(p2/(1-p2)),
                # to account for the fact that these are probability distributions that sum to 1.
                # (That's the natural log, i.e. log base e.)
                # Alternative considered: difference in log probabilities of top two classes, i.e. log(p1) - log(p2), but that won't distinguish cases like p1=0.5, p2=0.25 from p1=0.4, p2=0.2.
                # difference_between_top_two_predicted_probas was already generated, but we can create the rest ourselves here.
                # TODO: consider other metrics from https://robertmunro.com/uncertainty_sampling_example.html?
                p1, p2 = (
                    individual_classifications["max_predicted_proba"],
                    individual_classifications["second_highest_predicted_proba"],
                )
                epsilon = 1e-8  # avoid log(0) if p=0 or p=1
                individual_classifications[
                    "difference_between_logits_of_top_two_classes"
                ] = (np.log(p1 + epsilon) - np.log(1 - p1 + epsilon)) - (
                    np.log(p2 + epsilon) - np.log(1 - p2 + epsilon)
                )
                for metric, label in [
                    (
                        "difference_between_top_two_predicted_probas",
                        "Difference between\ntop two predicted probabilities",
                    ),
                    (
                        "difference_between_logits_of_top_two_classes",
                        "Difference between log odds\nof top two predicted classes",
                    ),
                ]:
                    fig = plt.figure(figsize=(3, 5))
                    sns.boxplot(
                        data=individual_classifications,
                        x="classification_success",
                        y=metric,
                        order=["Incorrect", "Correct"],
                        palette=sns.color_palette("Paired"),
                    )
                    plt.title(f"Blending metamodel {model_name}")
                    plt.xlabel("Specimen classification")
                    plt.ylabel(label)
                    sns.despine()
                    genetools.plots.savefig(
                        fig,
                        f"{highres_results_output_prefix}.errors_versus_{metric}.test_set_performance.{model_name}.with_abstention.vertical.png",
                        dpi=300,
                    )
                    plt.close(fig)

                try:
                    # Try to load global fold classifier for analysis, too.
                    # It wasn't included in the ExperimentSet, because no .metadata_joblib was generated, since the global fold does not have a test set.
                    # Note that this will only process global fold classifiers for models that were trained for at least one cross validation fold.
                    global_fold_classifier = BlendingMetamodel.from_disk(
                        fold_id=-1,
                        metamodel_name=model_name,
                        gene_locus=gene_locus,
                        target_obs_column=target_obs_column,
                        base_model_train_fold_name=base_model_train_fold_name,
                        metamodel_fold_label_train=metamodel_fold_label_train,
                        metamodel_flavor=metamodel_flavor,
                    )
                except FileNotFoundError as err:
                    logger.warning(
                        f"No global fold classifier found for {model_name}: {err}"
                    )
                    global_fold_classifier = None

                analyze_feature_importances(
                    model_name=model_name,
                    model_global_performance=model_global_performance,
                    gene_locus=gene_locus,
                    target_obs_column=target_obs_column,
                    metamodel_flavor=metamodel_flavor,
                    highres_results_output_prefix=highres_results_output_prefix,
                    global_fold_classifier=global_fold_classifier,
                )

                # Plot additional model diagnostics for models with internal cross validation over a range of hyperparameters
                if model_name in ["lasso_cv", "ridge_cv", "elasticnet_cv"]:

                    def _get_classifiers():
                        # load classifier from disk.
                        for (
                            fold_id,
                            per_fold_performance,
                        ) in model_global_performance.per_fold_outputs.items():
                            yield (fold_id, per_fold_performance.classifier)
                        if global_fold_classifier is not None:
                            yield (-1, global_fold_classifier)

                    for fold_id, clf in _get_classifiers():
                        if isinstance(clf, BlendingMetamodel):
                            # Unwrap if it's a BlendingMetamodel
                            clf = clf._inner

                        # it's probably a Pipeline - unwrap it
                        clf = model_evaluation._get_final_estimator_if_pipeline(clf)

                        if not isinstance(clf, GlmnetLogitNetWrapper):
                            # it should be a GlmnetLogitNetWrapper
                            raise ValueError(
                                f"Expected {model_name} for fold {fold_id} to be of type GlmnetLogitNetWrapper, got {type(clf)}"
                            )

                        # TODO: store the CvScorer enum object in the classifier so we can just use its .name
                        # In internal/nested cross validation, we optimize MCC for metamodel, but AUC for base models. See discussion in core code
                        fig = clf.plot_cross_validation_curve(scorer_name="MCC")
                        genetools.plots.savefig(
                            fig,
                            f"{highres_results_output_prefix}.internal_cross_validation_hyperparameter_diagnostics.{model_name}.fold_{fold_id}.png",
                            dpi=300,
                        )
                        plt.close(fig)

        except Exception as err:
            logger.exception(
                f"{gene_locus}, {target_obs_column}, metamodel flavor {metamodel_flavor}, config {metamodel_config} failed with error: {err}"
            )

# %%
# Individual gene locus
for gene_locus in config.gene_loci_used:
    print(gene_locus)
    GeneLocus.validate_single_value(gene_locus)
    for target_obs_column in config.classification_targets:
        run_analysis(gene_locus=gene_locus, target_obs_column=target_obs_column)
# Out:
# GeneLocus.BCR
# ## GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor default from /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/blending_metamodel/BCR/disease/default/train_smaller_applied_to_validation_model to /users/maximz/code/boyd-immune-repertoire-classification/out/unirep_fine_tuned/blending_metamodel/BCR/disease/default/train_smaller_applied_to_validation_model
# MetamodelConfig(submodels={<GeneLocus.BCR: 1>: {'repertoire_stats': RepertoireClassifier: Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('log1p-scale-PCA_IGHG',
#                                                   Pipeline(steps=[('log1p',
#                                                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                                                        func=<ufunc 'log1p'>,
#                                                                                        validate=True)),
#                                                                   ('scale',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    PCA(n_components=15,
#                                                                        random_state=0))]),
#                                                   <sklearn.compose._column_transformer.make_column...
#                                                                                        func=<ufunc 'log1p'>,
#                                                                                        validate=True)),
#                                                                   ('scale',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    PCA(n_components=15,
#                                                                        random_state=0))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f64c6d4d2b0>)])),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'convergent_cluster_model': ConvergentClusterClassifier: Pipeline(steps=[('matchvariables', MatchVariables()),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'sequence_model': RollupSequenceClassifier(filter_to_high_confidence_subset=False, fold_id=0,
#                          fold_label_train='train_smaller',
#                          gene_locus=<GeneLocus.BCR: 1>,
#                          model_name_sequence_disease='lasso_multiclass',
#                          sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>,
#                          sequence_models_base_dir=PosixPath('/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_...ISOTYPE_USAGE'),
#                          target_obs_column=<TargetObsColumnEnum.disease: TargetObsColumn(obs_column_name='disease', is_target_binary_for_repertoire_composition_classifier=False, limited_to_disease=None, require_metadata_columns_present=None, confusion_matrix_expanded_column_name='disease.separate_past_exposures', blended_evaluation_column_name='disease.rollup')>)}}, extra_metadata_featurizers=None, interaction_terms=None, regress_out_featurizers=None, regress_out_pipeline=None, sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>)
#                     ROC-AUC (weighted OvO) per fold  \
# linearsvm_ovr          0.964 +/- 0.005 (in 3 folds)
# lasso_multiclass       0.960 +/- 0.006 (in 3 folds)
# rf_multiclass          0.959 +/- 0.009 (in 3 folds)
# elasticnet_cv          0.957 +/- 0.008 (in 3 folds)
# xgboost                0.953 +/- 0.005 (in 3 folds)
# lasso_cv               0.949 +/- 0.005 (in 3 folds)
# ridge_cv               0.948 +/- 0.005 (in 3 folds)
# dummy_most_frequent    0.500 +/- 0.000 (in 3 folds)
# dummy_stratified       0.496 +/- 0.011 (in 3 folds)
#
#                      ROC-AUC (macro OvO) per fold  \
# linearsvm_ovr        0.969 +/- 0.006 (in 3 folds)
# lasso_multiclass     0.966 +/- 0.007 (in 3 folds)
# rf_multiclass        0.963 +/- 0.010 (in 3 folds)
# elasticnet_cv        0.962 +/- 0.007 (in 3 folds)
# xgboost              0.956 +/- 0.007 (in 3 folds)
# lasso_cv             0.954 +/- 0.003 (in 3 folds)
# ridge_cv             0.952 +/- 0.004 (in 3 folds)
# dummy_most_frequent  0.500 +/- 0.000 (in 3 folds)
# dummy_stratified     0.499 +/- 0.008 (in 3 folds)
#
#                     au-PRC (weighted OvO) per fold  \
# linearsvm_ovr         0.963 +/- 0.006 (in 3 folds)
# lasso_multiclass      0.959 +/- 0.008 (in 3 folds)
# rf_multiclass         0.954 +/- 0.014 (in 3 folds)
# elasticnet_cv         0.958 +/- 0.009 (in 3 folds)
# xgboost               0.951 +/- 0.009 (in 3 folds)
# lasso_cv              0.954 +/- 0.007 (in 3 folds)
# ridge_cv              0.951 +/- 0.006 (in 3 folds)
# dummy_most_frequent   0.500 +/- 0.000 (in 3 folds)
# dummy_stratified      0.503 +/- 0.001 (in 3 folds)
#
#                       au-PRC (macro OvO) per fold  \
# linearsvm_ovr        0.968 +/- 0.007 (in 3 folds)
# lasso_multiclass     0.965 +/- 0.008 (in 3 folds)
# rf_multiclass        0.960 +/- 0.014 (in 3 folds)
# elasticnet_cv        0.964 +/- 0.008 (in 3 folds)
# xgboost              0.955 +/- 0.010 (in 3 folds)
# lasso_cv             0.959 +/- 0.007 (in 3 folds)
# ridge_cv             0.957 +/- 0.006 (in 3 folds)
# dummy_most_frequent  0.500 +/- 0.000 (in 3 folds)
# dummy_stratified     0.506 +/- 0.001 (in 3 folds)
#
#                                 Accuracy per fold  \
# linearsvm_ovr        0.855 +/- 0.009 (in 3 folds)
# lasso_multiclass     0.846 +/- 0.009 (in 3 folds)
# rf_multiclass        0.850 +/- 0.013 (in 3 folds)
# elasticnet_cv        0.821 +/- 0.024 (in 3 folds)
# xgboost              0.831 +/- 0.014 (in 3 folds)
# lasso_cv             0.819 +/- 0.016 (in 3 folds)
# ridge_cv             0.821 +/- 0.021 (in 3 folds)
# dummy_most_frequent  0.465 +/- 0.010 (in 3 folds)
# dummy_stratified     0.320 +/- 0.018 (in 3 folds)
#
#                                       MCC per fold Accuracy global MCC global  \
# linearsvm_ovr         0.787 +/- 0.014 (in 3 folds)           0.855      0.787
# lasso_multiclass      0.778 +/- 0.017 (in 3 folds)           0.846      0.778
# rf_multiclass         0.781 +/- 0.020 (in 3 folds)           0.851      0.780
# elasticnet_cv         0.740 +/- 0.031 (in 3 folds)           0.821      0.739
# xgboost               0.753 +/- 0.023 (in 3 folds)           0.832      0.752
# lasso_cv              0.735 +/- 0.020 (in 3 folds)           0.819      0.734
# ridge_cv              0.740 +/- 0.025 (in 3 folds)           0.821      0.739
# dummy_most_frequent   0.000 +/- 0.000 (in 3 folds)           0.465      0.000
# dummy_stratified     -0.012 +/- 0.025 (in 3 folds)           0.320     -0.013
#
#                     Accuracy per fold with abstention  \
# linearsvm_ovr            0.835 +/- 0.023 (in 3 folds)
# lasso_multiclass         0.827 +/- 0.034 (in 3 folds)
# rf_multiclass            0.831 +/- 0.035 (in 3 folds)
# elasticnet_cv            0.802 +/- 0.001 (in 3 folds)
# xgboost                  0.812 +/- 0.032 (in 3 folds)
# lasso_cv                 0.800 +/- 0.010 (in 3 folds)
# ridge_cv                 0.802 +/- 0.016 (in 3 folds)
# dummy_most_frequent      0.454 +/- 0.007 (in 3 folds)
# dummy_stratified         0.313 +/- 0.024 (in 3 folds)
#
#                       MCC per fold with abstention  ...  \
# linearsvm_ovr         0.763 +/- 0.032 (in 3 folds)  ...
# lasso_multiclass      0.754 +/- 0.046 (in 3 folds)  ...
# rf_multiclass         0.757 +/- 0.047 (in 3 folds)  ...
# elasticnet_cv         0.715 +/- 0.004 (in 3 folds)  ...
# xgboost               0.730 +/- 0.044 (in 3 folds)  ...
# lasso_cv              0.710 +/- 0.014 (in 3 folds)  ...
# ridge_cv              0.715 +/- 0.024 (in 3 folds)  ...
# dummy_most_frequent   0.024 +/- 0.023 (in 3 folds)  ...
# dummy_stratified     -0.008 +/- 0.022 (in 3 folds)  ...
#
#                     au-PRC (macro OvO) per fold with abstention  \
# linearsvm_ovr                      0.976 +/- 0.000 (in 1 folds)
# lasso_multiclass                   0.974 +/- 0.000 (in 1 folds)
# rf_multiclass                      0.973 +/- 0.000 (in 1 folds)
# elasticnet_cv                      0.974 +/- 0.000 (in 1 folds)
# xgboost                            0.967 +/- 0.000 (in 1 folds)
# lasso_cv                           0.967 +/- 0.000 (in 1 folds)
# ridge_cv                           0.962 +/- 0.000 (in 1 folds)
# dummy_most_frequent                0.500 +/- 0.000 (in 1 folds)
# dummy_stratified                   0.505 +/- 0.000 (in 1 folds)
#
#                     Accuracy global with abstention  \
# linearsvm_ovr                                 0.835
# lasso_multiclass                              0.827
# rf_multiclass                                 0.831
# elasticnet_cv                                 0.802
# xgboost                                       0.812
# lasso_cv                                      0.800
# ridge_cv                                      0.802
# dummy_most_frequent                           0.454
# dummy_stratified                              0.312
#
#                     MCC global with abstention  \
# linearsvm_ovr                            0.762
# lasso_multiclass                         0.753
# rf_multiclass                            0.755
# elasticnet_cv                            0.713
# xgboost                                  0.728
# lasso_cv                                 0.709
# ridge_cv                                 0.713
# dummy_most_frequent                      0.025
# dummy_stratified                        -0.009
#
#                     Unknown/abstention proportion global with abstention  \
# linearsvm_ovr                                                    0.023
# lasso_multiclass                                                 0.023
# rf_multiclass                                                    0.023
# elasticnet_cv                                                    0.023
# xgboost                                                          0.023
# lasso_cv                                                         0.023
# ridge_cv                                                         0.023
# dummy_most_frequent                                              0.023
# dummy_stratified                                                 0.023
#
#                     Abstention label global with abstention sample_size  \
# linearsvm_ovr                                       Unknown         469
# lasso_multiclass                                    Unknown         469
# rf_multiclass                                       Unknown         469
# elasticnet_cv                                       Unknown         469
# xgboost                                             Unknown         469
# lasso_cv                                            Unknown         469
# ridge_cv                                            Unknown         469
# dummy_most_frequent                                 Unknown         469
# dummy_stratified                                    Unknown         469
#
#                     n_abstentions sample_size including abstentions  \
# linearsvm_ovr                  11                               480
# lasso_multiclass               11                               480
# rf_multiclass                  11                               480
# elasticnet_cv                  11                               480
# xgboost                        11                               480
# lasso_cv                       11                               480
# ridge_cv                       11                               480
# dummy_most_frequent            11                               480
# dummy_stratified               11                               480
#
#                     abstention_rate  missing_classes
# linearsvm_ovr              0.022917            False
# lasso_multiclass           0.022917            False
# rf_multiclass              0.022917            False
# elasticnet_cv              0.022917            False
# xgboost                    0.022917            False
# lasso_cv                   0.022917            False
# ridge_cv                   0.022917            False
# dummy_most_frequent        0.022917             True
# dummy_stratified           0.022917            False
#
# [9 rows x 24 columns]
# 2023-01-14 01:07:13,971 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:07:15,913 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:07:20,164 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:07:24,779 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:07:29,254 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:07:29,855 - analyze_metamodels.iypnb - WARNING - Feature importances not plotted for dummy_stratified: not a recognized tree or linear model.
# 2023-01-14 01:07:29,858 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:07:33,540 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:07:37,444 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:07:37,971 - analyze_metamodels.iypnb - WARNING - Feature importances not plotted for dummy_most_frequent: not a recognized tree or linear model.
# 2023-01-14 01:07:37,974 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# ## GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only from /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/blending_metamodel/BCR/disease/isotype_counts_only/train_smaller_applied_to_validation_model to /users/maximz/code/boyd-immune-repertoire-classification/out/unirep_fine_tuned/blending_metamodel/BCR/disease/isotype_counts_only/train_smaller_applied_to_validation_model
# MetamodelConfig(submodels=None, extra_metadata_featurizers={'isotype_counts': <malid.trained_model_wrappers.blending_metamodel.DemographicsFeaturizer object at 0x7f64c6cfb580>}, interaction_terms=None, regress_out_featurizers=None, regress_out_pipeline=None, sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>)
#                     ROC-AUC (weighted OvO) per fold  \
# elasticnet_cv          0.684 +/- 0.020 (in 3 folds)
# lasso_cv               0.676 +/- 0.023 (in 3 folds)
# ridge_cv               0.675 +/- 0.022 (in 3 folds)
# linearsvm_ovr          0.674 +/- 0.020 (in 3 folds)
# rf_multiclass          0.673 +/- 0.030 (in 3 folds)
# lasso_multiclass       0.668 +/- 0.020 (in 3 folds)
# xgboost                0.644 +/- 0.020 (in 3 folds)
# dummy_most_frequent    0.500 +/- 0.000 (in 3 folds)
# dummy_stratified       0.495 +/- 0.033 (in 3 folds)
#
#                      ROC-AUC (macro OvO) per fold  \
# elasticnet_cv        0.641 +/- 0.021 (in 3 folds)
# lasso_cv             0.633 +/- 0.023 (in 3 folds)
# ridge_cv             0.633 +/- 0.022 (in 3 folds)
# linearsvm_ovr        0.629 +/- 0.021 (in 3 folds)
# rf_multiclass        0.637 +/- 0.034 (in 3 folds)
# lasso_multiclass     0.622 +/- 0.019 (in 3 folds)
# xgboost              0.612 +/- 0.017 (in 3 folds)
# dummy_most_frequent  0.500 +/- 0.000 (in 3 folds)
# dummy_stratified     0.496 +/- 0.031 (in 3 folds)
#
#                     au-PRC (weighted OvO) per fold  \
# elasticnet_cv         0.685 +/- 0.026 (in 3 folds)
# lasso_cv              0.681 +/- 0.032 (in 3 folds)
# ridge_cv              0.672 +/- 0.018 (in 3 folds)
# linearsvm_ovr         0.666 +/- 0.020 (in 3 folds)
# rf_multiclass         0.648 +/- 0.029 (in 3 folds)
# lasso_multiclass      0.655 +/- 0.014 (in 3 folds)
# xgboost               0.629 +/- 0.019 (in 3 folds)
# dummy_most_frequent   0.500 +/- 0.000 (in 3 folds)
# dummy_stratified      0.504 +/- 0.016 (in 3 folds)
#
#                       au-PRC (macro OvO) per fold  \
# elasticnet_cv        0.650 +/- 0.025 (in 3 folds)
# lasso_cv             0.644 +/- 0.031 (in 3 folds)
# ridge_cv             0.636 +/- 0.016 (in 3 folds)
# linearsvm_ovr        0.629 +/- 0.019 (in 3 folds)
# rf_multiclass        0.626 +/- 0.029 (in 3 folds)
# lasso_multiclass     0.618 +/- 0.012 (in 3 folds)
# xgboost              0.611 +/- 0.017 (in 3 folds)
# dummy_most_frequent  0.500 +/- 0.000 (in 3 folds)
# dummy_stratified     0.505 +/- 0.016 (in 3 folds)
#
#                                 Accuracy per fold  \
# elasticnet_cv        0.494 +/- 0.017 (in 3 folds)
# lasso_cv             0.508 +/- 0.005 (in 3 folds)
# ridge_cv             0.494 +/- 0.017 (in 3 folds)
# linearsvm_ovr        0.477 +/- 0.016 (in 3 folds)
# rf_multiclass        0.515 +/- 0.015 (in 3 folds)
# lasso_multiclass     0.471 +/- 0.042 (in 3 folds)
# xgboost              0.484 +/- 0.020 (in 3 folds)
# dummy_most_frequent  0.460 +/- 0.006 (in 3 folds)
# dummy_stratified     0.317 +/- 0.053 (in 3 folds)
#
#                                       MCC per fold Accuracy global MCC global  \
# elasticnet_cv         0.190 +/- 0.038 (in 3 folds)           0.494      0.181
# lasso_cv              0.225 +/- 0.020 (in 3 folds)           0.508      0.215
# ridge_cv              0.194 +/- 0.032 (in 3 folds)           0.494      0.183
# linearsvm_ovr         0.201 +/- 0.029 (in 3 folds)           0.477      0.194
# rf_multiclass         0.261 +/- 0.020 (in 3 folds)           0.515      0.259
# lasso_multiclass      0.227 +/- 0.049 (in 3 folds)           0.471      0.223
# xgboost               0.219 +/- 0.029 (in 3 folds)           0.483      0.218
# dummy_most_frequent   0.000 +/- 0.000 (in 3 folds)           0.460      0.000
# dummy_stratified     -0.010 +/- 0.071 (in 3 folds)           0.317     -0.012
#
#                      sample_size  n_abstentions  \
# elasticnet_cv                480              0
# lasso_cv                     480              0
# ridge_cv                     480              0
# linearsvm_ovr                480              0
# rf_multiclass                480              0
# lasso_multiclass             480              0
# xgboost                      480              0
# dummy_most_frequent          480              0
# dummy_stratified             480              0
#
#                      sample_size including abstentions  abstention_rate  \
# elasticnet_cv                                      480              0.0
# lasso_cv                                           480              0.0
# ridge_cv                                           480              0.0
# linearsvm_ovr                                      480              0.0
# rf_multiclass                                      480              0.0
# lasso_multiclass                                   480              0.0
# xgboost                                            480              0.0
# dummy_most_frequent                                480              0.0
# dummy_stratified                                   480              0.0
#
#                      missing_classes
# elasticnet_cv                   True
# lasso_cv                       False
# ridge_cv                        True
# linearsvm_ovr                  False
# rf_multiclass                  False
# lasso_multiclass               False
# xgboost                        False
# dummy_most_frequent             True
# dummy_stratified               False
# 2023-01-14 01:07:57,208 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances for GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_locus and subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:07:57,210 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances for GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_model_component and subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:07:57,211 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances for GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_locus_and_model_component and subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:07:57,297 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances_global_fold for GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_locus and subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:07:57,299 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances_global_fold for GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_model_component and subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:07:57,302 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances_global_fold for GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_locus_and_model_component and subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:07:58,966 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:07:58,969 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:07:58,971 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:07:59,292 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:07:59,294 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:07:59,296 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:00,489 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:00,491 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:00,493 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:00,656 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.all, subset names None: Sum of feature importances is not 1
# 2023-01-14 01:08:00,657 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:00,659 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:00,660 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:02,247 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.all, subset names None: Sum of feature importances is not 1
# 2023-01-14 01:08:02,249 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:02,250 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:02,252 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:02,413 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.all, subset names None: Sum of feature importances is not 1
# 2023-01-14 01:08:02,415 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:02,417 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:02,418 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:03,451 - analyze_metamodels.iypnb - WARNING - Feature importances not plotted for dummy_stratified: not a recognized tree or linear model.
# 2023-01-14 01:08:04,642 - analyze_metamodels.iypnb - WARNING - Failed to plot linearsvm_ovr, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:04,645 - analyze_metamodels.iypnb - WARNING - Failed to plot linearsvm_ovr, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:04,647 - analyze_metamodels.iypnb - WARNING - Failed to plot linearsvm_ovr, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:08:04,974 - analyze_metamodels.iypnb - WARNING - Failed to plot linearsvm_ovr, GeneLocus.BCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# ...
# elasticnet_cv                   3                               165
# ridge_cv                        3                               165
# dummy_stratified                3                               165
# dummy_most_frequent             3                               165
#
#                     abstention_rate  missing_classes
# linearsvm_ovr              0.018182            False
# rf_multiclass              0.018182            False
# lasso_cv                   0.018182            False
# lasso_multiclass           0.018182            False
# xgboost                    0.018182            False
# elasticnet_cv              0.018182            False
# ridge_cv                   0.018182            False
# dummy_stratified           0.018182            False
# dummy_most_frequent        0.018182             True
#
# [9 rows x 24 columns]
# 2023-01-14 01:21:27,784 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:29,076 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:29,932 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:31,401 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:32,905 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:33,307 - analyze_metamodels.iypnb - WARNING - Feature importances not plotted for dummy_stratified: not a recognized tree or linear model.
# 2023-01-14 01:21:33,309 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:34,177 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:35,633 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:36,016 - analyze_metamodels.iypnb - WARNING - Feature importances not plotted for dummy_most_frequent: not a recognized tree or linear model.
# 2023-01-14 01:21:36,019 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# ## GeneLocus.TCR, TargetObsColumnEnum.sex_healthy_only, metamodel flavor default from /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/blending_metamodel/TCR/sex_healthy_only/default/train_smaller_applied_to_validation_model to /users/maximz/code/boyd-immune-repertoire-classification/out/unirep_fine_tuned/blending_metamodel/TCR/sex_healthy_only/default/train_smaller_applied_to_validation_model
# MetamodelConfig(submodels={<GeneLocus.TCR: 2>: {'repertoire_stats': RepertoireClassifier: Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('log1p-scale-PCA_TCRB',
#                                                   Pipeline(steps=[('log1p',
#                                                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                                                        func=<ufunc 'log1p'>,
#                                                                                        validate=True)),
#                                                                   ('scale',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    PCA(n_components=15,
#                                                                        random_state=0))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f6120106370>)])),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'convergent_cluster_model': ConvergentClusterClassifier: Pipeline(steps=[('matchvariables', MatchVariables()),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'sequence_model': RollupSequenceClassifier(filter_to_high_confidence_subset=False, fold_id=0,
#                          fold_label_train='train_smaller',
#                          gene_locus=<GeneLocus.TCR: 2>,
#                          model_name_sequence_disease='lasso_multiclass',
#                          sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>,
#                          sequence_models_base_dir=PosixPath('/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_...
#                          target_obs_column=<TargetObsColumnEnum.sex_healthy_only: TargetObsColumn(obs_column_name='sex', is_target_binary_for_repertoire_composition_classifier=False, limited_to_disease=['Healthy/Background'], require_metadata_columns_present=['age', 'sex', 'ethnicity_condensed', 'age_group'], confusion_matrix_expanded_column_name=None, blended_evaluation_column_name=None)>)}}, extra_metadata_featurizers=None, interaction_terms=None, regress_out_featurizers=None, regress_out_pipeline=None, sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>)
#                     ROC-AUC (weighted OvO) per fold  \
# rf_multiclass          0.562 +/- 0.037 (in 3 folds)
# dummy_stratified       0.532 +/- 0.072 (in 3 folds)
# xgboost                0.516 +/- 0.075 (in 3 folds)
# lasso_cv               0.500 +/- 0.000 (in 3 folds)
# elasticnet_cv          0.500 +/- 0.000 (in 3 folds)
# ridge_cv               0.500 +/- 0.000 (in 3 folds)
# dummy_most_frequent    0.500 +/- 0.000 (in 3 folds)
# lasso_multiclass       0.487 +/- 0.053 (in 3 folds)
# linearsvm_ovr          0.482 +/- 0.043 (in 3 folds)
#
#                      ROC-AUC (macro OvO) per fold  \
# rf_multiclass        0.562 +/- 0.037 (in 3 folds)
# dummy_stratified     0.532 +/- 0.072 (in 3 folds)
# xgboost              0.516 +/- 0.075 (in 3 folds)
# lasso_cv             0.500 +/- 0.000 (in 3 folds)
# elasticnet_cv        0.500 +/- 0.000 (in 3 folds)
# ridge_cv             0.500 +/- 0.000 (in 3 folds)
# dummy_most_frequent  0.500 +/- 0.000 (in 3 folds)
# lasso_multiclass     0.487 +/- 0.053 (in 3 folds)
# linearsvm_ovr        0.482 +/- 0.043 (in 3 folds)
#
#                     au-PRC (weighted OvO) per fold  \
# rf_multiclass         0.646 +/- 0.128 (in 3 folds)
# dummy_stratified      0.578 +/- 0.096 (in 3 folds)
# xgboost               0.603 +/- 0.129 (in 3 folds)
# lasso_cv              0.559 +/- 0.056 (in 3 folds)
# elasticnet_cv         0.559 +/- 0.056 (in 3 folds)
# ridge_cv              0.559 +/- 0.056 (in 3 folds)
# dummy_most_frequent   0.559 +/- 0.056 (in 3 folds)
# lasso_multiclass      0.545 +/- 0.063 (in 3 folds)
# linearsvm_ovr         0.553 +/- 0.050 (in 3 folds)
#
#                       au-PRC (macro OvO) per fold  \
# rf_multiclass        0.646 +/- 0.128 (in 3 folds)
# dummy_stratified     0.578 +/- 0.096 (in 3 folds)
# xgboost              0.603 +/- 0.129 (in 3 folds)
# lasso_cv             0.559 +/- 0.056 (in 3 folds)
# elasticnet_cv        0.559 +/- 0.056 (in 3 folds)
# ridge_cv             0.559 +/- 0.056 (in 3 folds)
# dummy_most_frequent  0.559 +/- 0.056 (in 3 folds)
# lasso_multiclass     0.545 +/- 0.063 (in 3 folds)
# linearsvm_ovr        0.553 +/- 0.050 (in 3 folds)
#
#                                 Accuracy per fold  \
# rf_multiclass        0.546 +/- 0.055 (in 3 folds)
# dummy_stratified     0.527 +/- 0.054 (in 3 folds)
# xgboost              0.525 +/- 0.052 (in 3 folds)
# lasso_cv             0.447 +/- 0.065 (in 3 folds)
# elasticnet_cv        0.447 +/- 0.065 (in 3 folds)
# ridge_cv             0.447 +/- 0.065 (in 3 folds)
# dummy_most_frequent  0.447 +/- 0.065 (in 3 folds)
# lasso_multiclass     0.507 +/- 0.080 (in 3 folds)
# linearsvm_ovr        0.520 +/- 0.045 (in 3 folds)
#
#                                       MCC per fold Accuracy global MCC global  \
# rf_multiclass         0.122 +/- 0.172 (in 3 folds)           0.545      0.082
# dummy_stratified      0.062 +/- 0.146 (in 3 folds)           0.526      0.036
# xgboost               0.079 +/- 0.098 (in 3 folds)           0.526      0.036
# lasso_cv              0.000 +/- 0.000 (in 3 folds)           0.449     -0.070
# elasticnet_cv         0.000 +/- 0.000 (in 3 folds)           0.449     -0.070
# ridge_cv              0.000 +/- 0.000 (in 3 folds)           0.449     -0.070
# dummy_most_frequent   0.000 +/- 0.000 (in 3 folds)           0.449     -0.070
# lasso_multiclass     -0.006 +/- 0.148 (in 3 folds)           0.506     -0.002
# linearsvm_ovr         0.021 +/- 0.069 (in 3 folds)           0.519      0.024
#
#                     Accuracy per fold with abstention  \
# rf_multiclass            0.520 +/- 0.080 (in 3 folds)
# dummy_stratified         0.501 +/- 0.078 (in 3 folds)
# xgboost                  0.498 +/- 0.056 (in 3 folds)
# lasso_cv                 0.422 +/- 0.039 (in 3 folds)
# elasticnet_cv            0.422 +/- 0.039 (in 3 folds)
# ridge_cv                 0.422 +/- 0.039 (in 3 folds)
# dummy_most_frequent      0.422 +/- 0.039 (in 3 folds)
# lasso_multiclass         0.481 +/- 0.084 (in 3 folds)
# linearsvm_ovr            0.494 +/- 0.059 (in 3 folds)
#
#                       MCC per fold with abstention  ...  \
# rf_multiclass         0.128 +/- 0.158 (in 3 folds)  ...
# dummy_stratified      0.073 +/- 0.133 (in 3 folds)  ...
# xgboost               0.087 +/- 0.085 (in 3 folds)  ...
# lasso_cv             -0.023 +/- 0.091 (in 3 folds)  ...
# elasticnet_cv        -0.023 +/- 0.091 (in 3 folds)  ...
# ridge_cv             -0.023 +/- 0.091 (in 3 folds)  ...
# dummy_most_frequent  -0.023 +/- 0.091 (in 3 folds)  ...
# lasso_multiclass     -0.003 +/- 0.132 (in 3 folds)  ...
# linearsvm_ovr         0.021 +/- 0.064 (in 3 folds)  ...
#
#                     au-PRC (macro OvO) per fold with abstention  \
# rf_multiclass                      0.771 +/- 0.000 (in 1 folds)
# dummy_stratified                   0.683 +/- 0.000 (in 1 folds)
# xgboost                            0.702 +/- 0.000 (in 1 folds)
# lasso_cv                           0.620 +/- 0.000 (in 1 folds)
# elasticnet_cv                      0.620 +/- 0.000 (in 1 folds)
# ridge_cv                           0.620 +/- 0.000 (in 1 folds)
# dummy_most_frequent                0.620 +/- 0.000 (in 1 folds)
# lasso_multiclass                   0.615 +/- 0.000 (in 1 folds)
# linearsvm_ovr                      0.610 +/- 0.000 (in 1 folds)
#
#                     Accuracy global with abstention  \
# rf_multiclass                                 0.515
# dummy_stratified                              0.497
# xgboost                                       0.497
# lasso_cv                                      0.424
# elasticnet_cv                                 0.424
# ridge_cv                                      0.424
# dummy_most_frequent                           0.424
# lasso_multiclass                              0.479
# linearsvm_ovr                                 0.491
#
#                     MCC global with abstention  \
# rf_multiclass                            0.076
# dummy_stratified                         0.037
# xgboost                                  0.037
# lasso_cv                                -0.073
# elasticnet_cv                           -0.073
# ridge_cv                                -0.073
# dummy_most_frequent                     -0.073
# lasso_multiclass                         0.002
# linearsvm_ovr                            0.026
#
#                     Unknown/abstention proportion global with abstention  \
# rf_multiclass                                                    0.055
# dummy_stratified                                                 0.055
# xgboost                                                          0.055
# lasso_cv                                                         0.055
# elasticnet_cv                                                    0.055
# ridge_cv                                                         0.055
# dummy_most_frequent                                              0.055
# lasso_multiclass                                                 0.055
# linearsvm_ovr                                                    0.055
#
#                     Abstention label global with abstention sample_size  \
# rf_multiclass                                       Unknown         156
# dummy_stratified                                    Unknown         156
# xgboost                                             Unknown         156
# lasso_cv                                            Unknown         156
# elasticnet_cv                                       Unknown         156
# ridge_cv                                            Unknown         156
# dummy_most_frequent                                 Unknown         156
# lasso_multiclass                                    Unknown         156
# linearsvm_ovr                                       Unknown         156
#
#                     n_abstentions sample_size including abstentions  \
# rf_multiclass                   9                               165
# dummy_stratified                9                               165
# xgboost                         9                               165
# lasso_cv                        9                               165
# elasticnet_cv                   9                               165
# ridge_cv                        9                               165
# dummy_most_frequent             9                               165
# lasso_multiclass                9                               165
# linearsvm_ovr                   9                               165
#
#                     abstention_rate  missing_classes
# rf_multiclass              0.054545            False
# dummy_stratified           0.054545            False
# xgboost                    0.054545            False
# lasso_cv                   0.054545            False
# elasticnet_cv              0.054545            False
# ridge_cv                   0.054545            False
# dummy_most_frequent        0.054545            False
# lasso_multiclass           0.054545            False
# linearsvm_ovr              0.054545            False
#
# [9 rows x 24 columns]
# 2023-01-14 01:21:40,249 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:41,303 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:42,028 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:43,380 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:44,827 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:45,222 - analyze_metamodels.iypnb - WARNING - Feature importances not plotted for dummy_stratified: not a recognized tree or linear model.
# 2023-01-14 01:21:45,224 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:46,077 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:47,452 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:21:47,824 - analyze_metamodels.iypnb - WARNING - Feature importances not plotted for dummy_most_frequent: not a recognized tree or linear model.
# 2023-01-14 01:21:47,826 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown

# %%
# Together in combined metamodel
if len(config.gene_loci_used) > 1:
    print(config.gene_loci_used)
    for target_obs_column in config.classification_targets:
        run_analysis(
            gene_locus=config.gene_loci_used, target_obs_column=target_obs_column
        )
# Out:
# GeneLocus.BCR|TCR
# ## GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor default from /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/blending_metamodel/BCR_TCR/disease/default/train_smaller_applied_to_validation_model to /users/maximz/code/boyd-immune-repertoire-classification/out/unirep_fine_tuned/blending_metamodel/BCR_TCR/disease/default/train_smaller_applied_to_validation_model
# MetamodelConfig(submodels={<GeneLocus.BCR: 1>: {'repertoire_stats': RepertoireClassifier: Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('log1p-scale-PCA_IGHG',
#                                                   Pipeline(steps=[('log1p',
#                                                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                                                        func=<ufunc 'log1p'>,
#                                                                                        validate=True)),
#                                                                   ('scale',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    PCA(n_components=15,
#                                                                        random_state=0))]),
#                                                   <sklearn.compose._column_transformer.make_column...
#                                                                                        func=<ufunc 'log1p'>,
#                                                                                        validate=True)),
#                                                                   ('scale',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    PCA(n_components=15,
#                                                                        random_state=0))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f64c6d44a90>)])),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'convergent_cluster_model': ConvergentClusterClassifier: Pipeline(steps=[('matchvariables', MatchVariables()),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'sequence_model': RollupSequenceClassifier(filter_to_high_confidence_subset=False, fold_id=0,
#                          fold_label_train='train_smaller',
#                          gene_locus=<GeneLocus.BCR: 1>,
#                          model_name_sequence_disease='lasso_multiclass',
#                          sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>,
#                          sequence_models_base_dir=PosixPath('/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_...ISOTYPE_USAGE'),
#                          target_obs_column=<TargetObsColumnEnum.disease: TargetObsColumn(obs_column_name='disease', is_target_binary_for_repertoire_composition_classifier=False, limited_to_disease=None, require_metadata_columns_present=None, confusion_matrix_expanded_column_name='disease.separate_past_exposures', blended_evaluation_column_name='disease.rollup')>)}, <GeneLocus.TCR: 2>: {'repertoire_stats': RepertoireClassifier: Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('log1p-scale-PCA_TCRB',
#                                                   Pipeline(steps=[('log1p',
#                                                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                                                        func=<ufunc 'log1p'>,
#                                                                                        validate=True)),
#                                                                   ('scale',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    PCA(n_components=15,
#                                                                        random_state=0))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f6113c49730>)])),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'convergent_cluster_model': ConvergentClusterClassifier: Pipeline(steps=[('matchvariables', MatchVariables()),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'sequence_model': RollupSequenceClassifier(filter_to_high_confidence_subset=False, fold_id=0,
#                          fold_label_train='train_smaller',
#                          gene_locus=<GeneLocus.TCR: 2>,
#                          model_name_sequence_disease='lasso_multiclass',
#                          sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>,
#                          sequence_models_base_dir=PosixPath('/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_...ISOTYPE_USAGE'),
#                          target_obs_column=<TargetObsColumnEnum.disease: TargetObsColumn(obs_column_name='disease', is_target_binary_for_repertoire_composition_classifier=False, limited_to_disease=None, require_metadata_columns_present=None, confusion_matrix_expanded_column_name='disease.separate_past_exposures', blended_evaluation_column_name='disease.rollup')>)}}, extra_metadata_featurizers=None, interaction_terms=None, regress_out_featurizers=None, regress_out_pipeline=None, sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>)
#                     ROC-AUC (weighted OvO) per fold  \
# lasso_multiclass       0.983 +/- 0.005 (in 3 folds)
# elasticnet_cv          0.982 +/- 0.005 (in 3 folds)
# ridge_cv               0.982 +/- 0.005 (in 3 folds)
# rf_multiclass          0.981 +/- 0.013 (in 3 folds)
# linearsvm_ovr          0.980 +/- 0.003 (in 3 folds)
# lasso_cv               0.976 +/- 0.010 (in 3 folds)
# xgboost                0.973 +/- 0.008 (in 3 folds)
# dummy_stratified       0.516 +/- 0.029 (in 3 folds)
# dummy_most_frequent    0.500 +/- 0.000 (in 3 folds)
#
#                      ROC-AUC (macro OvO) per fold  \
# lasso_multiclass     0.985 +/- 0.005 (in 3 folds)
# elasticnet_cv        0.983 +/- 0.004 (in 3 folds)
# ridge_cv             0.983 +/- 0.005 (in 3 folds)
# rf_multiclass        0.981 +/- 0.014 (in 3 folds)
# linearsvm_ovr        0.982 +/- 0.001 (in 3 folds)
# lasso_cv             0.978 +/- 0.009 (in 3 folds)
# xgboost              0.971 +/- 0.009 (in 3 folds)
# dummy_stratified     0.514 +/- 0.026 (in 3 folds)
# dummy_most_frequent  0.500 +/- 0.000 (in 3 folds)
#
#                     au-PRC (weighted OvO) per fold  \
# lasso_multiclass      0.980 +/- 0.006 (in 3 folds)
# elasticnet_cv         0.979 +/- 0.006 (in 3 folds)
# ridge_cv              0.976 +/- 0.008 (in 3 folds)
# rf_multiclass         0.976 +/- 0.016 (in 3 folds)
# linearsvm_ovr         0.977 +/- 0.005 (in 3 folds)
# lasso_cv              0.975 +/- 0.007 (in 3 folds)
# xgboost               0.971 +/- 0.008 (in 3 folds)
# dummy_stratified      0.516 +/- 0.018 (in 3 folds)
# dummy_most_frequent   0.500 +/- 0.000 (in 3 folds)
#
#                       au-PRC (macro OvO) per fold  \
# lasso_multiclass     0.982 +/- 0.005 (in 3 folds)
# elasticnet_cv        0.981 +/- 0.005 (in 3 folds)
# ridge_cv             0.979 +/- 0.006 (in 3 folds)
# rf_multiclass        0.978 +/- 0.015 (in 3 folds)
# linearsvm_ovr        0.980 +/- 0.003 (in 3 folds)
# lasso_cv             0.978 +/- 0.007 (in 3 folds)
# xgboost              0.971 +/- 0.009 (in 3 folds)
# dummy_stratified     0.516 +/- 0.019 (in 3 folds)
# dummy_most_frequent  0.500 +/- 0.000 (in 3 folds)
#
#                                 Accuracy per fold  \
# lasso_multiclass     0.894 +/- 0.028 (in 3 folds)
# elasticnet_cv        0.899 +/- 0.024 (in 3 folds)
# ridge_cv             0.892 +/- 0.038 (in 3 folds)
# rf_multiclass        0.901 +/- 0.027 (in 3 folds)
# linearsvm_ovr        0.899 +/- 0.004 (in 3 folds)
# lasso_cv             0.897 +/- 0.028 (in 3 folds)
# xgboost              0.889 +/- 0.036 (in 3 folds)
# dummy_stratified     0.359 +/- 0.042 (in 3 folds)
# dummy_most_frequent  0.472 +/- 0.004 (in 3 folds)
#
#                                      MCC per fold Accuracy global MCC global  \
# lasso_multiclass     0.847 +/- 0.038 (in 3 folds)           0.894      0.846
# elasticnet_cv        0.850 +/- 0.036 (in 3 folds)           0.899      0.851
# ridge_cv             0.840 +/- 0.057 (in 3 folds)           0.892      0.840
# rf_multiclass        0.855 +/- 0.041 (in 3 folds)           0.902      0.854
# linearsvm_ovr        0.854 +/- 0.004 (in 3 folds)           0.899      0.852
# lasso_cv             0.847 +/- 0.041 (in 3 folds)           0.897      0.847
# xgboost              0.839 +/- 0.051 (in 3 folds)           0.889      0.837
# dummy_stratified     0.034 +/- 0.064 (in 3 folds)           0.359      0.034
# dummy_most_frequent  0.000 +/- 0.000 (in 3 folds)           0.472      0.000
#
#                     Accuracy per fold with abstention  \
# lasso_multiclass         0.879 +/- 0.048 (in 3 folds)
# elasticnet_cv            0.884 +/- 0.032 (in 3 folds)
# ridge_cv                 0.877 +/- 0.045 (in 3 folds)
# rf_multiclass            0.886 +/- 0.036 (in 3 folds)
# linearsvm_ovr            0.884 +/- 0.024 (in 3 folds)
# lasso_cv                 0.881 +/- 0.034 (in 3 folds)
# xgboost                  0.874 +/- 0.054 (in 3 folds)
# dummy_stratified         0.352 +/- 0.038 (in 3 folds)
# dummy_most_frequent      0.464 +/- 0.009 (in 3 folds)
#
#                      MCC per fold with abstention  ...  \
# lasso_multiclass     0.829 +/- 0.061 (in 3 folds)  ...
# elasticnet_cv        0.830 +/- 0.046 (in 3 folds)  ...
# ridge_cv             0.820 +/- 0.066 (in 3 folds)  ...
# rf_multiclass        0.835 +/- 0.052 (in 3 folds)  ...
# linearsvm_ovr        0.835 +/- 0.029 (in 3 folds)  ...
# lasso_cv             0.827 +/- 0.050 (in 3 folds)  ...
# xgboost              0.820 +/- 0.072 (in 3 folds)  ...
# dummy_stratified     0.035 +/- 0.062 (in 3 folds)  ...
# dummy_most_frequent  0.020 +/- 0.018 (in 3 folds)  ...
#
#                     au-PRC (macro OvO) per fold with abstention  \
# lasso_multiclass                   0.987 +/- 0.000 (in 1 folds)
# elasticnet_cv                      0.983 +/- 0.000 (in 1 folds)
# ridge_cv                           0.985 +/- 0.000 (in 1 folds)
# rf_multiclass                      0.988 +/- 0.000 (in 1 folds)
# linearsvm_ovr                      0.983 +/- 0.000 (in 1 folds)
# lasso_cv                           0.981 +/- 0.000 (in 1 folds)
# xgboost                            0.976 +/- 0.000 (in 1 folds)
# dummy_stratified                   0.534 +/- 0.000 (in 1 folds)
# dummy_most_frequent                0.500 +/- 0.000 (in 1 folds)
#
#                     Accuracy global with abstention  \
# lasso_multiclass                              0.879
# elasticnet_cv                                 0.884
# ridge_cv                                      0.877
# rf_multiclass                                 0.886
# linearsvm_ovr                                 0.884
# lasso_cv                                      0.882
# xgboost                                       0.874
# dummy_stratified                              0.353
# dummy_most_frequent                           0.464
#
#                     MCC global with abstention  \
# lasso_multiclass                         0.826
# elasticnet_cv                            0.830
# ridge_cv                                 0.819
# rf_multiclass                            0.833
# linearsvm_ovr                            0.832
# lasso_cv                                 0.826
# xgboost                                  0.817
# dummy_stratified                         0.036
# dummy_most_frequent                      0.021
#
#                     Unknown/abstention proportion global with abstention  \
# lasso_multiclass                                                 0.017
# elasticnet_cv                                                    0.017
# ridge_cv                                                         0.017
# rf_multiclass                                                    0.017
# linearsvm_ovr                                                    0.017
# lasso_cv                                                         0.017
# xgboost                                                          0.017
# dummy_stratified                                                 0.017
# dummy_most_frequent                                              0.017
#
#                     Abstention label global with abstention sample_size  \
# lasso_multiclass                                    Unknown         407
# elasticnet_cv                                       Unknown         407
# ridge_cv                                            Unknown         407
# rf_multiclass                                       Unknown         407
# linearsvm_ovr                                       Unknown         407
# lasso_cv                                            Unknown         407
# xgboost                                             Unknown         407
# dummy_stratified                                    Unknown         407
# dummy_most_frequent                                 Unknown         407
#
#                     n_abstentions sample_size including abstentions  \
# lasso_multiclass                7                               414
# elasticnet_cv                   7                               414
# ridge_cv                        7                               414
# rf_multiclass                   7                               414
# linearsvm_ovr                   7                               414
# lasso_cv                        7                               414
# xgboost                         7                               414
# dummy_stratified                7                               414
# dummy_most_frequent             7                               414
#
#                     abstention_rate  missing_classes
# lasso_multiclass           0.016908            False
# elasticnet_cv              0.016908            False
# ridge_cv                   0.016908            False
# rf_multiclass              0.016908            False
# linearsvm_ovr              0.016908            False
# lasso_cv                   0.016908            False
# xgboost                    0.016908            False
# dummy_stratified           0.016908            False
# dummy_most_frequent        0.016908             True
#
# [9 rows x 24 columns]
# 2023-01-14 01:22:08,549 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:22:10,478 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:22:15,090 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:22:20,572 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:22:25,714 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:22:26,198 - analyze_metamodels.iypnb - WARNING - Feature importances not plotted for dummy_stratified: not a recognized tree or linear model.
# 2023-01-14 01:22:26,200 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:22:30,763 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:22:35,905 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:22:36,400 - analyze_metamodels.iypnb - WARNING - Feature importances not plotted for dummy_most_frequent: not a recognized tree or linear model.
# 2023-01-14 01:22:36,402 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# ## GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only from /users/maximz/code/boyd-immune-repertoire-classification/data/data_v_20221224/embedded/unirep_fine_tuned/blending_metamodel/BCR_TCR/disease/isotype_counts_only/train_smaller_applied_to_validation_model to /users/maximz/code/boyd-immune-repertoire-classification/out/unirep_fine_tuned/blending_metamodel/BCR_TCR/disease/isotype_counts_only/train_smaller_applied_to_validation_model
# MetamodelConfig(submodels=None, extra_metadata_featurizers={'isotype_counts': <malid.trained_model_wrappers.blending_metamodel.DemographicsFeaturizer object at 0x7f6120801a00>}, interaction_terms=None, regress_out_featurizers=None, regress_out_pipeline=None, sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>)
#                     ROC-AUC (weighted OvO) per fold  \
# lasso_cv               0.707 +/- 0.008 (in 3 folds)
# lasso_multiclass       0.704 +/- 0.023 (in 3 folds)
# rf_multiclass          0.702 +/- 0.019 (in 3 folds)
# elasticnet_cv          0.702 +/- 0.003 (in 3 folds)
# linearsvm_ovr          0.695 +/- 0.020 (in 3 folds)
# ridge_cv               0.691 +/- 0.022 (in 3 folds)
# xgboost                0.667 +/- 0.013 (in 3 folds)
# dummy_stratified       0.512 +/- 0.029 (in 3 folds)
# dummy_most_frequent    0.500 +/- 0.000 (in 3 folds)
#
#                      ROC-AUC (macro OvO) per fold  \
# lasso_cv             0.660 +/- 0.007 (in 3 folds)
# lasso_multiclass     0.664 +/- 0.019 (in 3 folds)
# rf_multiclass        0.666 +/- 0.018 (in 3 folds)
# elasticnet_cv        0.656 +/- 0.003 (in 3 folds)
# linearsvm_ovr        0.647 +/- 0.015 (in 3 folds)
# ridge_cv             0.646 +/- 0.023 (in 3 folds)
# xgboost              0.637 +/- 0.012 (in 3 folds)
# dummy_stratified     0.514 +/- 0.027 (in 3 folds)
# dummy_most_frequent  0.500 +/- 0.000 (in 3 folds)
#
#                     au-PRC (weighted OvO) per fold  \
# lasso_cv              0.713 +/- 0.017 (in 3 folds)
# lasso_multiclass      0.697 +/- 0.014 (in 3 folds)
# rf_multiclass         0.684 +/- 0.017 (in 3 folds)
# elasticnet_cv         0.703 +/- 0.017 (in 3 folds)
# linearsvm_ovr         0.686 +/- 0.015 (in 3 folds)
# ridge_cv              0.683 +/- 0.023 (in 3 folds)
# xgboost               0.662 +/- 0.017 (in 3 folds)
# dummy_stratified      0.513 +/- 0.016 (in 3 folds)
# dummy_most_frequent   0.500 +/- 0.000 (in 3 folds)
#
#                       au-PRC (macro OvO) per fold  \
# lasso_cv             0.673 +/- 0.017 (in 3 folds)
# lasso_multiclass     0.669 +/- 0.010 (in 3 folds)
# rf_multiclass        0.661 +/- 0.015 (in 3 folds)
# elasticnet_cv        0.666 +/- 0.018 (in 3 folds)
# linearsvm_ovr        0.650 +/- 0.012 (in 3 folds)
# ridge_cv             0.649 +/- 0.018 (in 3 folds)
# xgboost              0.643 +/- 0.019 (in 3 folds)
# dummy_stratified     0.515 +/- 0.016 (in 3 folds)
# dummy_most_frequent  0.500 +/- 0.000 (in 3 folds)
#
#                                 Accuracy per fold  \
# lasso_cv             0.544 +/- 0.039 (in 3 folds)
# lasso_multiclass     0.500 +/- 0.046 (in 3 folds)
# rf_multiclass        0.548 +/- 0.008 (in 3 folds)
# elasticnet_cv        0.539 +/- 0.043 (in 3 folds)
# linearsvm_ovr        0.503 +/- 0.046 (in 3 folds)
# ridge_cv             0.522 +/- 0.059 (in 3 folds)
# xgboost              0.512 +/- 0.040 (in 3 folds)
# dummy_stratified     0.348 +/- 0.040 (in 3 folds)
# dummy_most_frequent  0.469 +/- 0.002 (in 3 folds)
#
#                                      MCC per fold Accuracy global MCC global  \
# lasso_cv             0.260 +/- 0.080 (in 3 folds)           0.543      0.261
# lasso_multiclass     0.273 +/- 0.051 (in 3 folds)           0.500      0.268
# rf_multiclass        0.302 +/- 0.021 (in 3 folds)           0.548      0.302
# elasticnet_cv        0.248 +/- 0.090 (in 3 folds)           0.539      0.252
# linearsvm_ovr        0.241 +/- 0.068 (in 3 folds)           0.502      0.234
# ridge_cv             0.212 +/- 0.126 (in 3 folds)           0.522      0.217
# xgboost              0.255 +/- 0.068 (in 3 folds)           0.512      0.256
# dummy_stratified     0.018 +/- 0.061 (in 3 folds)           0.348      0.019
# dummy_most_frequent  0.000 +/- 0.000 (in 3 folds)           0.469      0.000
#
#                      sample_size  n_abstentions  \
# lasso_cv                     414              0
# lasso_multiclass             414              0
# rf_multiclass                414              0
# elasticnet_cv                414              0
# linearsvm_ovr                414              0
# ridge_cv                     414              0
# xgboost                      414              0
# dummy_stratified             414              0
# dummy_most_frequent          414              0
#
#                      sample_size including abstentions  abstention_rate  \
# lasso_cv                                           414              0.0
# lasso_multiclass                                   414              0.0
# rf_multiclass                                      414              0.0
# elasticnet_cv                                      414              0.0
# linearsvm_ovr                                      414              0.0
# ridge_cv                                           414              0.0
# xgboost                                            414              0.0
# dummy_stratified                                   414              0.0
# dummy_most_frequent                                414              0.0
#
#                      missing_classes
# lasso_cv                        True
# lasso_multiclass               False
# rf_multiclass                  False
# elasticnet_cv                   True
# linearsvm_ovr                  False
# ridge_cv                        True
# xgboost                        False
# dummy_stratified               False
# dummy_most_frequent             True
# 2023-01-14 01:22:53,827 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances for GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_locus and subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:22:53,830 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances for GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_model_component and subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:22:53,834 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances for GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_locus_and_model_component and subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:22:53,921 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances_global_fold for GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_locus and subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:22:53,923 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances_global_fold for GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_model_component and subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:22:53,925 - analyze_metamodels.iypnb - WARNING - Failed to plot rf_multiclass feature importances_global_fold for GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only, with figure name by_locus_and_model_component and subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHG',
#        'isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M'],
#       dtype='object')
# 2023-01-14 01:22:55,149 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:55,152 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:55,154 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:55,320 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.all, subset names None: Sum of feature importances is not 1
# 2023-01-14 01:22:55,322 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:55,324 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:55,327 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_multiclass, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:56,346 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.all, subset names None: Sum of feature importances is not 1
# 2023-01-14 01:22:56,349 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:56,351 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:56,353 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:56,683 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:56,685 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:56,687 - analyze_metamodels.iypnb - WARNING - Failed to plot lasso_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:58,304 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.all, subset names None: Sum of feature importances is not 1
# 2023-01-14 01:22:58,306 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:58,308 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_model_component, subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition': '^(?:(?!interaction).)*repertoire_stats', 'CDR3 clustering': '^(?:(?!interaction).)*convergent_cluster_model', 'Language model': '^(?:(?!interaction).)*sequence_model', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:58,310 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus_and_model_component, subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'Repertoire composition (BCR)': '^BCR:repertoire_stats:*', 'Repertoire composition (TCR)': '^TCR:repertoire_stats:*', 'CDR3 clustering (BCR)': '^BCR:convergent_cluster_model:*', 'CDR3 clustering (TCR)': '^TCR:convergent_cluster_model:*', 'Language model (BCR)': '^BCR:sequence_model:*', 'Language model (TCR)': '^TCR:sequence_model:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# 2023-01-14 01:22:58,473 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.all, subset names None: Sum of feature importances is not 1
# 2023-01-14 01:22:58,475 - analyze_metamodels.iypnb - WARNING - Failed to plot elasticnet_cv, GeneLocus.BCR|TCR, TargetObsColumnEnum.disease, metamodel flavor isotype_counts_only feature percent contributions for figure name absval_coefs.by_locus, subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'}: Subset names {'BCR': '^BCR:*', 'TCR': '^TCR:*', 'Demographics': '^demographics', 'Sequence x Demographic feature interactions': '^interaction'} not found in df columns Index(['isotype_counts:isotype_proportion:IGHA',
#        'isotype_counts:isotype_proportion:IGHD-M',
#        'isotype_counts:isotype_proportion:IGHG'],
#       dtype='object')
# ...
#                                                   <sklearn.compose._column_transformer.make_column...
#                                                                                        func=<ufunc 'log1p'>,
#                                                                                        validate=True)),
#                                                                   ('scale',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    PCA(n_components=15,
#                                                                        random_state=0))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f63e791f3a0>)])),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'convergent_cluster_model': ConvergentClusterClassifier: Pipeline(steps=[('matchvariables', MatchVariables()),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'sequence_model': RollupSequenceClassifier(filter_to_high_confidence_subset=False, fold_id=0,
#                          fold_label_train='train_smaller',
#                          gene_locus=<GeneLocus.BCR: 1>,
#                          model_name_sequence_disease='lasso_multiclass',
#                          sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>,
#                          sequence_models_base_dir=PosixPath('/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_...
#                          target_obs_column=<TargetObsColumnEnum.sex_healthy_only: TargetObsColumn(obs_column_name='sex', is_target_binary_for_repertoire_composition_classifier=False, limited_to_disease=['Healthy/Background'], require_metadata_columns_present=['age', 'sex', 'ethnicity_condensed', 'age_group'], confusion_matrix_expanded_column_name=None, blended_evaluation_column_name=None)>)}, <GeneLocus.TCR: 2>: {'repertoire_stats': RepertoireClassifier: Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('log1p-scale-PCA_TCRB',
#                                                   Pipeline(steps=[('log1p',
#                                                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                                                        func=<ufunc 'log1p'>,
#                                                                                        validate=True)),
#                                                                   ('scale',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    PCA(n_components=15,
#                                                                        random_state=0))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f6159ad15b0>)])),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'convergent_cluster_model': ConvergentClusterClassifier: Pipeline(steps=[('matchvariables', MatchVariables()),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced',
#                                     multi_class='multinomial', penalty='l1',
#                                     random_state=0, solver='saga'))]), 'sequence_model': RollupSequenceClassifier(filter_to_high_confidence_subset=False, fold_id=0,
#                          fold_label_train='train_smaller',
#                          gene_locus=<GeneLocus.TCR: 2>,
#                          model_name_sequence_disease='lasso_multiclass',
#                          sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>,
#                          sequence_models_base_dir=PosixPath('/users/maximz/code/boyd-immune-repertoire-classification/data/data_v_...
#                          target_obs_column=<TargetObsColumnEnum.sex_healthy_only: TargetObsColumn(obs_column_name='sex', is_target_binary_for_repertoire_composition_classifier=False, limited_to_disease=['Healthy/Background'], require_metadata_columns_present=['age', 'sex', 'ethnicity_condensed', 'age_group'], confusion_matrix_expanded_column_name=None, blended_evaluation_column_name=None)>)}}, extra_metadata_featurizers=None, interaction_terms=None, regress_out_featurizers=None, regress_out_pipeline=None, sample_weight_strategy=<SampleWeightStrategy.ISOTYPE_USAGE: 3>)
#                     ROC-AUC (weighted OvO) per fold  \
# rf_multiclass          0.546 +/- 0.086 (in 3 folds)
# xgboost                0.542 +/- 0.090 (in 3 folds)
# dummy_stratified       0.506 +/- 0.071 (in 3 folds)
# lasso_cv               0.500 +/- 0.000 (in 3 folds)
# elasticnet_cv          0.500 +/- 0.000 (in 3 folds)
# ridge_cv               0.500 +/- 0.000 (in 3 folds)
# dummy_most_frequent    0.500 +/- 0.000 (in 3 folds)
# linearsvm_ovr          0.471 +/- 0.041 (in 3 folds)
# lasso_multiclass       0.457 +/- 0.055 (in 3 folds)
#
#                      ROC-AUC (macro OvO) per fold  \
# rf_multiclass        0.546 +/- 0.086 (in 3 folds)
# xgboost              0.542 +/- 0.090 (in 3 folds)
# dummy_stratified     0.506 +/- 0.071 (in 3 folds)
# lasso_cv             0.500 +/- 0.000 (in 3 folds)
# elasticnet_cv        0.500 +/- 0.000 (in 3 folds)
# ridge_cv             0.500 +/- 0.000 (in 3 folds)
# dummy_most_frequent  0.500 +/- 0.000 (in 3 folds)
# linearsvm_ovr        0.471 +/- 0.041 (in 3 folds)
# lasso_multiclass     0.457 +/- 0.055 (in 3 folds)
#
#                     au-PRC (weighted OvO) per fold  \
# rf_multiclass         0.586 +/- 0.118 (in 3 folds)
# xgboost               0.595 +/- 0.115 (in 3 folds)
# dummy_stratified      0.563 +/- 0.092 (in 3 folds)
# lasso_cv              0.558 +/- 0.055 (in 3 folds)
# elasticnet_cv         0.558 +/- 0.055 (in 3 folds)
# ridge_cv              0.558 +/- 0.055 (in 3 folds)
# dummy_most_frequent   0.558 +/- 0.055 (in 3 folds)
# linearsvm_ovr         0.564 +/- 0.061 (in 3 folds)
# lasso_multiclass      0.545 +/- 0.083 (in 3 folds)
#
#                       au-PRC (macro OvO) per fold  \
# rf_multiclass        0.586 +/- 0.118 (in 3 folds)
# xgboost              0.595 +/- 0.115 (in 3 folds)
# dummy_stratified     0.563 +/- 0.092 (in 3 folds)
# lasso_cv             0.558 +/- 0.055 (in 3 folds)
# elasticnet_cv        0.558 +/- 0.055 (in 3 folds)
# ridge_cv             0.558 +/- 0.055 (in 3 folds)
# dummy_most_frequent  0.558 +/- 0.055 (in 3 folds)
# linearsvm_ovr        0.564 +/- 0.061 (in 3 folds)
# lasso_multiclass     0.545 +/- 0.083 (in 3 folds)
#
#                                 Accuracy per fold  \
# rf_multiclass        0.507 +/- 0.060 (in 3 folds)
# xgboost              0.508 +/- 0.040 (in 3 folds)
# dummy_stratified     0.499 +/- 0.051 (in 3 folds)
# lasso_cv             0.448 +/- 0.063 (in 3 folds)
# elasticnet_cv        0.448 +/- 0.063 (in 3 folds)
# ridge_cv             0.448 +/- 0.063 (in 3 folds)
# dummy_most_frequent  0.448 +/- 0.063 (in 3 folds)
# linearsvm_ovr        0.511 +/- 0.041 (in 3 folds)
# lasso_multiclass     0.474 +/- 0.089 (in 3 folds)
#
#                                       MCC per fold Accuracy global MCC global  \
# rf_multiclass         0.049 +/- 0.081 (in 3 folds)           0.510      0.006
# xgboost               0.048 +/- 0.033 (in 3 folds)           0.510      0.006
# dummy_stratified      0.008 +/- 0.146 (in 3 folds)           0.497     -0.021
# lasso_cv              0.000 +/- 0.000 (in 3 folds)           0.451     -0.068
# elasticnet_cv         0.000 +/- 0.000 (in 3 folds)           0.451     -0.068
# ridge_cv              0.000 +/- 0.000 (in 3 folds)           0.451     -0.068
# dummy_most_frequent   0.000 +/- 0.000 (in 3 folds)           0.451     -0.068
# linearsvm_ovr         0.025 +/- 0.096 (in 3 folds)           0.510      0.015
# lasso_multiclass     -0.064 +/- 0.172 (in 3 folds)           0.471     -0.074
#
#                     Accuracy per fold with abstention  \
# rf_multiclass            0.471 +/- 0.059 (in 3 folds)
# xgboost                  0.472 +/- 0.041 (in 3 folds)
# dummy_stratified         0.464 +/- 0.057 (in 3 folds)
# lasso_cv                 0.415 +/- 0.050 (in 3 folds)
# elasticnet_cv            0.415 +/- 0.050 (in 3 folds)
# ridge_cv                 0.415 +/- 0.050 (in 3 folds)
# dummy_most_frequent      0.415 +/- 0.050 (in 3 folds)
# linearsvm_ovr            0.475 +/- 0.040 (in 3 folds)
# lasso_multiclass         0.439 +/- 0.081 (in 3 folds)
#
#                       MCC per fold with abstention  \
# rf_multiclass         0.054 +/- 0.062 (in 3 folds)
# xgboost               0.053 +/- 0.027 (in 3 folds)
# dummy_stratified      0.018 +/- 0.120 (in 3 folds)
# lasso_cv             -0.019 +/- 0.092 (in 3 folds)
# elasticnet_cv        -0.019 +/- 0.092 (in 3 folds)
# ridge_cv             -0.019 +/- 0.092 (in 3 folds)
# dummy_most_frequent  -0.019 +/- 0.092 (in 3 folds)
# linearsvm_ovr         0.025 +/- 0.084 (in 3 folds)
# lasso_multiclass     -0.054 +/- 0.153 (in 3 folds)
#
#                     Unknown/abstention proportion per fold with abstention  \
# rf_multiclass                             0.072 +/- 0.026 (in 3 folds)
# xgboost                                   0.072 +/- 0.026 (in 3 folds)
# dummy_stratified                          0.072 +/- 0.026 (in 3 folds)
# lasso_cv                                  0.072 +/- 0.026 (in 3 folds)
# elasticnet_cv                             0.072 +/- 0.026 (in 3 folds)
# ridge_cv                                  0.072 +/- 0.026 (in 3 folds)
# dummy_most_frequent                       0.072 +/- 0.026 (in 3 folds)
# linearsvm_ovr                             0.072 +/- 0.026 (in 3 folds)
# lasso_multiclass                          0.072 +/- 0.026 (in 3 folds)
#
#                     Accuracy global with abstention  \
# rf_multiclass                                 0.473
# xgboost                                       0.473
# dummy_stratified                              0.461
# lasso_cv                                      0.418
# elasticnet_cv                                 0.418
# ridge_cv                                      0.418
# dummy_most_frequent                           0.418
# linearsvm_ovr                                 0.473
# lasso_multiclass                              0.436
#
#                     MCC global with abstention  \
# rf_multiclass                            0.009
# xgboost                                  0.009
# dummy_stratified                        -0.014
# lasso_cv                                -0.067
# elasticnet_cv                           -0.067
# ridge_cv                                -0.067
# dummy_most_frequent                     -0.067
# linearsvm_ovr                            0.014
# lasso_multiclass                        -0.060
#
#                     Unknown/abstention proportion global with abstention  \
# rf_multiclass                                                    0.073
# xgboost                                                          0.073
# dummy_stratified                                                 0.073
# lasso_cv                                                         0.073
# elasticnet_cv                                                    0.073
# ridge_cv                                                         0.073
# dummy_most_frequent                                              0.073
# linearsvm_ovr                                                    0.073
# lasso_multiclass                                                 0.073
#
#                     Abstention label global with abstention  sample_size  \
# rf_multiclass                                       Unknown          153
# xgboost                                             Unknown          153
# dummy_stratified                                    Unknown          153
# lasso_cv                                            Unknown          153
# elasticnet_cv                                       Unknown          153
# ridge_cv                                            Unknown          153
# dummy_most_frequent                                 Unknown          153
# linearsvm_ovr                                       Unknown          153
# lasso_multiclass                                    Unknown          153
#
#                      n_abstentions  sample_size including abstentions  \
# rf_multiclass                   12                                165
# xgboost                         12                                165
# dummy_stratified                12                                165
# lasso_cv                        12                                165
# elasticnet_cv                   12                                165
# ridge_cv                        12                                165
# dummy_most_frequent             12                                165
# linearsvm_ovr                   12                                165
# lasso_multiclass                12                                165
#
#                      abstention_rate  missing_classes
# rf_multiclass               0.072727            False
# xgboost                     0.072727            False
# dummy_stratified            0.072727            False
# lasso_cv                    0.072727            False
# elasticnet_cv               0.072727            False
# ridge_cv                    0.072727            False
# dummy_most_frequent         0.072727            False
# linearsvm_ovr               0.072727            False
# lasso_multiclass            0.072727            False
# 2023-01-14 01:31:57,906 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:31:59,129 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:32:00,028 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:32:01,444 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:32:02,936 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:32:03,341 - analyze_metamodels.iypnb - WARNING - Feature importances not plotted for dummy_stratified: not a recognized tree or linear model.
# 2023-01-14 01:32:03,344 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:32:04,386 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:32:05,964 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
# 2023-01-14 01:32:06,371 - analyze_metamodels.iypnb - WARNING - Feature importances not plotted for dummy_most_frequent: not a recognized tree or linear model.
# 2023-01-14 01:32:06,374 - malid.external.genetools_extras - WARNING - Inserting phantom class: Unknown
