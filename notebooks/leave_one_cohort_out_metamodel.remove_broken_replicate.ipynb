# %% [markdown]
# ## Emulate `analyze_metamodels.ipynb` to follow up on `in_house_peak_disease_leave_one_cohort_out`: exclude the samples where one replicate failed sequencing
#
# We found these samples in `paired_sample_batch_effects.ipynb` by applying our QC min-clone-count filters to the individual replicates.

# %%
import os

os.environ["MALID_CV_SPLIT"] = "in_house_peak_disease_leave_one_cohort_out"

# %%
from pathlib import Path
from typing import Dict, Generator, List, Optional, Tuple, Union
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import itertools
import genetools

# %matplotlib inline
import seaborn as sns
from IPython.display import display, Markdown

from malid import config, logger, helpers
from wrap_glmnet import GlmnetLogitNetWrapper
from malid.train import train_metamodel
import crosseval
from malid.datamodels import (
    DataSource,
    TargetObsColumnEnum,
    GeneLocus,
    healthy_label,
    map_cross_validation_split_strategy_to_default_target_obs_column,
)
from malid.trained_model_wrappers import BlendingMetamodel

# %%
base_model_train_fold_name = "train_smaller"
metamodel_fold_label_train = "validation"
gene_locus = config.gene_loci_used
target_obs_column = TargetObsColumnEnum.disease

# %%
flavors = train_metamodel.get_metamodel_flavors(
    gene_locus=gene_locus,
    target_obs_column=target_obs_column,
    fold_id=config.all_fold_ids[0],
    base_model_train_fold_name=base_model_train_fold_name,
    use_stubs_instead_of_submodels=True,
)

metamodel_flavor = "default"
metamodel_config = flavors["default"]

# %%
# should already exist:
metamodels_base_dir = BlendingMetamodel._get_metamodel_base_dir(
    gene_locus=gene_locus,
    target_obs_column=target_obs_column,
    metamodel_flavor=metamodel_flavor,
)

_output_suffix = Path(gene_locus.name) / target_obs_column.name / metamodel_flavor
# might not exist yet:
output_base_dir = (
    config.paths.second_stage_blending_metamodel_output_dir / _output_suffix
)
highres_output_base_dir = (
    config.paths.high_res_outputs_dir / "metamodel" / _output_suffix
)
output_base_dir.mkdir(parents=True, exist_ok=True)
highres_output_base_dir.mkdir(parents=True, exist_ok=True)

fname_prefix = (
    f"{base_model_train_fold_name}_applied_to_{metamodel_fold_label_train}_model"
)
model_prefix = metamodels_base_dir / fname_prefix
results_output_prefix = output_base_dir / fname_prefix
highres_results_output_prefix = highres_output_base_dir / fname_prefix

computed_abstentions = None

# Load and summarize
experiment_set = crosseval.ExperimentSet.load_from_disk(output_prefix=model_prefix)

# Note that default y_true from BlendingMetamodel._featurize() is target_obs_column.value.blended_evaluation_column_name
# Use DROP_INCOMPLETE_FOLDS setting because alternate classification targets might not be well-split in the small validation set of the cross-validation folds that were designed to stratify disease.
# In the cases of some classification targets, we might need to automatically drop folds that have only a single class in the metamodel training data (i.e. in the validation set).
experiment_set_global_performance = experiment_set.summarize(
    remove_incomplete_strategy=crosseval.RemoveIncompleteStrategy.DROP_INCOMPLETE_FOLDS
)

# %%
model_global_performance = experiment_set_global_performance.model_global_performances[
    "ridge_cv"
]

# %%
# review classification for each specimen
individual_classifications = model_global_performance.get_all_entries()
# Out:
# {"message": "Removing class absent from y_true: Lupus", "time": "2024-02-22T07:03:23.592817"}
# {"message": "Removing class absent from y_true: Influenza", "time": "2024-02-22T07:03:23.596782"}
# {"message": "Removing class absent from y_true: T1D", "time": "2024-02-22T07:03:23.598231"}
# 29             Covid19             Covid19                         Covid19
# 30  Healthy/Background  Healthy/Background              Healthy/Background
# 31             Covid19             Covid19                         Covid19
# 32  Healthy/Background  Healthy/Background              Healthy/Background
# 33  Healthy/Background  Healthy/Background              Healthy/Background
# 34             Covid19             Covid19                         Covid19
# 35  Healthy/Background  Healthy/Background              Healthy/Background
# 36             Covid19             Covid19                         Covid19
# 37  Healthy/Background  Healthy/Background              Healthy/Background
# 38  Healthy/Background  Healthy/Background              Healthy/Background
# 39  Healthy/Background  Healthy/Background              Healthy/Background
#
#    disease_severity                  disease_subtype ethnicity_condensed  \
# 0               NaN        Healthy/Background - CMV+               Asian
# 1               NaN        Healthy/Background - CMV+           Caucasian
# 2               ICU    Covid19 - Sero-positive (ICU)                 NaN
# 3             Admit  Covid19 - Sero-positive (Admit)                 NaN
# 4               NaN        Healthy/Background - CMV+               Asian
# 5               NaN        Healthy/Background - CMV-               Asian
# 6               NaN        Healthy/Background - CMV+           Caucasian
# 7               NaN        Healthy/Background - CMV-           Caucasian
# 8               NaN        Healthy/Background - CMV-           Caucasian
# 9               NaN        Healthy/Background - CMV-           Caucasian
# 10            Admit  Covid19 - Sero-positive (Admit)                 NaN
# 11              NaN        Healthy/Background - CMV+           Caucasian
# 12              NaN        Healthy/Background - CMV+               Asian
# 13              NaN        Healthy/Background - CMV+               Asian
# 14              NaN        Healthy/Background - CMV+           Caucasian
# 15              NaN        Healthy/Background - CMV+               Asian
# 16              NaN        Healthy/Background - CMV-           Caucasian
# 17              NaN        Healthy/Background - CMV+               Asian
# 18              ICU    Covid19 - Sero-positive (ICU)                 NaN
# 19              NaN        Healthy/Background - CMV-           Caucasian
# 20              ICU    Covid19 - Sero-positive (ICU)                 NaN
# 21              ICU    Covid19 - Sero-positive (ICU)                 NaN
# 22              NaN        Healthy/Background - CMV-               Asian
# 23              NaN        Healthy/Background - CMV+           Caucasian
# 24              NaN        Healthy/Background - CMV-     Hispanic/Latino
# 25              NaN        Healthy/Background - CMV-           Caucasian
# 26              NaN        Healthy/Background - CMV-           Caucasian
# 27              NaN        Healthy/Background - CMV+           Caucasian
# 28              NaN        Healthy/Background - CMV-           Caucasian
# 29            Admit  Covid19 - Sero-positive (Admit)                 NaN
# 30              NaN        Healthy/Background - CMV-               Asian
# 31              ICU    Covid19 - Sero-positive (ICU)                 NaN
# 32              NaN        Healthy/Background - CMV+           Caucasian
# 33              NaN        Healthy/Background - CMV-               Asian
# 34              ICU    Covid19 - Sero-positive (ICU)                 NaN
# 35              NaN        Healthy/Background - CMV+           Caucasian
# 36              ICU    Covid19 - Sero-positive (ICU)                 NaN
# 37              NaN        Healthy/Background - CMV-           Caucasian
# 38              NaN        Healthy/Background - CMV+               Asian
# 39              NaN        Healthy/Background - CMV-           Caucasian
#
#     isotype_proportion:IGHA  isotype_proportion:IGHD-M  \
# 0                  0.116510                   0.816248
# 1                  0.055499                   0.925711
# 2                  0.198567                   0.577210
# 3                  0.107579                   0.601890
# 4                  0.052188                   0.877930
# 5                  0.112299                   0.837525
# 6                  0.003738                   0.939253
# 7                  0.088505                   0.829384
# 8                  0.184208                   0.731000
# 9                  0.053370                   0.917168
# 10                 0.283706                   0.591165
# 11                 0.151143                   0.705169
# 12                 0.119946                   0.779775
# 13                 0.105866                   0.843011
# 14                 0.250425                   0.689433
# 15                 0.143978                   0.818248
# 16                 0.105174                   0.805455
# 17                 0.090751                   0.876827
# 18                 0.107749                   0.813130
# 19                 0.084900                   0.872555
# 20                 0.084795                   0.794605
# 21                 0.223082                   0.460302
# 22                 0.177764                   0.773137
# 23                 0.115474                   0.825839
# 24                 0.140702                   0.808022
# 25                 0.051544                   0.911108
# 26                 0.062152                   0.905859
# 27                 0.061636                   0.849898
# 28                 0.094446                   0.862165
# 29                 0.218636                   0.609033
# 30                 0.082814                   0.879598
# 31                 0.021591                   0.933982
# 32                 0.084706                   0.879209
# 33                 0.148991                   0.736639
# 34                 0.151762                   0.630298
# 35                 0.061731                   0.901767
# 36                 0.152434                   0.587124
# 37                 0.087443                   0.843073
# 38                 0.105189                   0.822149
# 39                 0.070563                   0.880759
#
#     isotype_proportion:IGHG participant_label  past_exposure sex  \
# 0                  0.067242       BFI-0003124          False   F
# 1                  0.018790       BFI-0003082          False   M
# 2                  0.224223       BFI-0007450          False   F
# 3                  0.290531       BFI-0007483          False   F
# 4                  0.069881       BFI-0003093          False   M
# 5                  0.050176       BFI-0003114          False   M
# 6                  0.057008       BFI-0003129          False   M
# 7                  0.082111       BFI-0003133          False   M
# 8                  0.084793       BFI-0003142          False   M
# 9                  0.029462       BFI-0003087          False   M
# 10                 0.125128       BFI-0007482          False   F
# 11                 0.143688       BFI-0003136          False   M
# 12                 0.100280       BFI-0003117          False   M
# 13                 0.051123       BFI-0003140          False   M
# 14                 0.060143       BFI-0003112          False   F
# 15                 0.037774       BFI-0003109          False   M
# 16                 0.089371       BFI-0003122          False   M
# 17                 0.032421       BFI-0003110          False   F
# 18                 0.079121       BFI-0007481          False   M
# 19                 0.042544       BFI-0003097          False   F
# 20                 0.120600       BFI-0007455          False   M
# 21                 0.316616       BFI-0007484          False   M
# 22                 0.049099       BFI-0003086          False   M
# 23                 0.058687       BFI-0003106          False   F
# 24                 0.051276       BFI-0003130          False   M
# 25                 0.037348       BFI-0003100          False   F
# 26                 0.031989       BFI-0003092          False   F
# 27                 0.088465       BFI-0003101          False   M
# 28                 0.043389       BFI-0003113          False   M
# 29                 0.172330       BFI-0007486          False   F
# 30                 0.037589       BFI-0003061          False   F
# 31                 0.044427       BFI-0007485          False   F
# 32                 0.036085       BFI-0003146          False   F
# 33                 0.114369       BFI-0003118          False   M
# 34                 0.217940       BFI-0007480          False   F
# 35                 0.036502       BFI-0003084          False   F
# 36                 0.260442       BFI-0007453          False   M
# 37                 0.069484       BFI-0003104          False   F
# 38                 0.072663       BFI-0003103          False   F
# 39                 0.048679       BFI-0003098          False   M
#
#                                            study_name
# 0   Healthy-StanfordBloodCenter_included-in-resequ...
# 1   Healthy-StanfordBloodCenter_included-in-resequ...
# 2                                   Covid19-buffycoat
# 3                                   Covid19-buffycoat
# 4   Healthy-StanfordBloodCenter_included-in-resequ...
# 5   Healthy-StanfordBloodCenter_included-in-resequ...
# 6   Healthy-StanfordBloodCenter_included-in-resequ...
# 7   Healthy-StanfordBloodCenter_included-in-resequ...
# 8   Healthy-StanfordBloodCenter_included-in-resequ...
# 9   Healthy-StanfordBloodCenter_included-in-resequ...
# 10                                  Covid19-buffycoat
# 11  Healthy-StanfordBloodCenter_included-in-resequ...
# 12  Healthy-StanfordBloodCenter_included-in-resequ...
# 13  Healthy-StanfordBloodCenter_included-in-resequ...
# 14  Healthy-StanfordBloodCenter_included-in-resequ...
# 15  Healthy-StanfordBloodCenter_included-in-resequ...
# 16  Healthy-StanfordBloodCenter_included-in-resequ...
# 17  Healthy-StanfordBloodCenter_included-in-resequ...
# 18                                  Covid19-buffycoat
# 19  Healthy-StanfordBloodCenter_included-in-resequ...
# 20                                  Covid19-buffycoat
# 21                                  Covid19-buffycoat
# 22  Healthy-StanfordBloodCenter_included-in-resequ...
# 23  Healthy-StanfordBloodCenter_included-in-resequ...
# 24  Healthy-StanfordBloodCenter_included-in-resequ...
# 25  Healthy-StanfordBloodCenter_included-in-resequ...
# 26  Healthy-StanfordBloodCenter_included-in-resequ...
# 27  Healthy-StanfordBloodCenter_included-in-resequ...
# 28  Healthy-StanfordBloodCenter_included-in-resequ...
# 29                                  Covid19-buffycoat
# 30  Healthy-StanfordBloodCenter_included-in-resequ...
# 31                                  Covid19-buffycoat
# 32  Healthy-StanfordBloodCenter_included-in-resequ...
# 33  Healthy-StanfordBloodCenter_included-in-resequ...
# 34                                  Covid19-buffycoat
# 35  Healthy-StanfordBloodCenter_included-in-resequ...
# 36                                  Covid19-buffycoat
# 37  Healthy-StanfordBloodCenter_included-in-resequ...
# 38  Healthy-StanfordBloodCenter_included-in-resequ...
# 39  Healthy-StanfordBloodCenter_included-in-resequ...

# %%
# Load the list of rejected specimens (where at least one replicate failed QC)
bad_specimens = pd.read_csv(
    config.paths.base_output_dir_for_selected_cross_validation_strategy
    / "rejected_specimens_because_some_replicates_failed_qc.txt",
    header=None,
)[0].values
bad_specimens
# Out:
# array(['M64-012', 'M64-033', 'M64-035', 'M64-037', 'M64-043', 'M64-049',
#        'M64-051', 'M64-052', 'M64-055', 'M64-057', 'M64-060', 'M64-063',
#        'M64-064', 'M64-073', 'M64-075', 'M64-080', 'M64-097'],
#       dtype=object)

# %%
# Filter out healthy samples that underwent replicate sequencing but failed
# See the other notebook mentioned above for details.
print(individual_classifications.shape)

individual_classifications_filtered = individual_classifications[
    (~individual_classifications["specimen_label"].isin(bad_specimens))
]
individual_classifications_filtered.shape
# Out:
# (40, 20)
# (23, 20)

# %%
# Of the remainder: what was the accuracy?
for y_true, grp in individual_classifications_filtered.groupby("y_true"):
    print(f"For y_true={y_true}, predictions are:")
    print(grp["y_pred"].value_counts())
    print()
# Out:
# For y_true=Covid19, predictions are:
# Covid19    10
# Name: y_pred, dtype: int64
#
# For y_true=Healthy/Background, predictions are:
# Healthy/Background    13
# Name: y_pred, dtype: int64
